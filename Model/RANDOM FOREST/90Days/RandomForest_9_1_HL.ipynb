# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=1, out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(data, test_n):
    predictions = []
    train, test = train_test_split(data, test_n)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'halong_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series.values, In=6)

# %%
# Split the data
train_size = int(len(data) * 0.9)
train, test = train_test_split(data, len(data) - train_size)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(data, len(test))
# Out:
# expected=55.0, predicted=52.74764366275696
# expected=85.0, predicted=54.37541196858374
# expected=79.0, predicted=68.54431619353142
# expected=55.0, predicted=62.31151795820463
# expected=81.0, predicted=58.25671853020527
# expected=96.0, predicted=61.14633657441475
# expected=94.0, predicted=73.1968678264946
# expected=47.0, predicted=74.00702772863534
# expected=43.0, predicted=58.33211900942349
# expected=66.0, predicted=58.3894780684148
# expected=78.0, predicted=53.30288465499273
# expected=58.0, predicted=51.26332092521229
# expected=31.0, predicted=55.49863755089464
# expected=48.0, predicted=41.56470386645753
# expected=52.0, predicted=45.139387882981836
# expected=49.0, predicted=47.45036531283209
# expected=46.0, predicted=48.62050992323074
# expected=36.0, predicted=42.42621455340184
# expected=36.0, predicted=34.86820807921554
# expected=37.0, predicted=39.11153384072436
# expected=68.0, predicted=37.87007974528882
# expected=40.0, predicted=45.71008444593165
# expected=25.0, predicted=43.698837595908735
# expected=25.0, predicted=34.808900774748594
# expected=29.0, predicted=31.406946456249493
# expected=46.0, predicted=35.98659064560358
# expected=27.0, predicted=43.439057259839004
# expected=35.0, predicted=36.09552908998569
# expected=50.0, predicted=33.580788395902644
# expected=68.0, predicted=41.856041829267205
# expected=79.0, predicted=47.832631017324246
# expected=68.0, predicted=48.723704062660765
# expected=53.0, predicted=54.07023858531193
# expected=84.0, predicted=57.09597563333234
# expected=96.0, predicted=69.03618681375293
# expected=85.0, predicted=80.83803798459168
# expected=71.0, predicted=64.71629718657923
# expected=54.0, predicted=58.75533902963316
# expected=60.0, predicted=63.920517380775216
# expected=46.0, predicted=52.90699903537995
# expected=63.0, predicted=50.425960414239206
# expected=39.0, predicted=50.96850209351297
# expected=52.0, predicted=43.367971792754936
# expected=76.0, predicted=50.04278827785331
# expected=54.0, predicted=45.94992313501877
# expected=57.0, predicted=51.530321327516475
# expected=47.0, predicted=48.461907203578605
# expected=41.0, predicted=49.41246225734639
# expected=54.0, predicted=45.449777980559965
# expected=60.0, predicted=46.545719368515776
# expected=47.0, predicted=49.952175254635705
# expected=53.0, predicted=45.06842565243707
# expected=49.0, predicted=47.8914277272733
# expected=30.0, predicted=48.0357539772967
# expected=29.0, predicted=36.23859385907305
# expected=39.0, predicted=33.34992948095476
# expected=33.0, predicted=43.6295393585695
# expected=20.0, predicted=41.230779902257474
# expected=29.0, predicted=36.37271880244744
# expected=17.0, predicted=28.580875867891287
# expected=13.0, predicted=33.45386715416841
# expected=58.0, predicted=22.46174011523743
# expected=5.0, predicted=37.377593282417685
# expected=57.0, predicted=28.505753313781153
# expected=61.0, predicted=39.61540280883505
# expected=63.0, predicted=42.846971529175036
# expected=60.0, predicted=47.25872546975467
# expected=49.0, predicted=44.724749609575966
# expected=46.0, predicted=52.955179586967006
# expected=5.0, predicted=50.37957183052426
# expected=27.0, predicted=38.280442498160845
# expected=29.0, predicted=58.17803399167711
# expected=77.0, predicted=37.20662178333938
# expected=37.0, predicted=35.817746326251225
# expected=46.0, predicted=43.78403571959914
# expected=26.0, predicted=50.214576163191374
# expected=46.0, predicted=38.59520473444108
# expected=51.0, predicted=47.09393572242897
# expected=42.0, predicted=45.17025444219751
# expected=56.0, predicted=40.36525019768108
# expected=27.0, predicted=48.91223304066436
# expected=52.0, predicted=34.98403360074096
# expected=64.0, predicted=44.40058085986136
# expected=47.0, predicted=39.96894364269291
# expected=6.0, predicted=49.05396673653603
# expected=28.0, predicted=39.223290461010514
# expected=7.0, predicted=53.26605156503579
# expected=44.0, predicted=38.48772565167848
# expected=24.0, predicted=37.775651611838725
# expected=54.0, predicted=34.389085714524576
# expected=48.0, predicted=40.2251748090814
# expected=16.0, predicted=48.71687794456408
# expected=5.0, predicted=28.052420781607015
# expected=72.0, predicted=42.04959537130364
# expected=34.0, predicted=33.25639317082949
# expected=43.0, predicted=44.344791243102726
# expected=24.0, predicted=42.34079793888334
# expected=39.0, predicted=50.68950188757614
# expected=64.0, predicted=37.15141446875101
# expected=5.0, predicted=41.50855784435024
# expected=31.0, predicted=47.93761518879548
# expected=66.0, predicted=38.3448784050188
# expected=62.0, predicted=39.87243539232886
# expected=46.0, predicted=43.12379553891911
# expected=57.0, predicted=40.61999689002427
# expected=57.0, predicted=48.9278694620291
# expected=47.0, predicted=48.269578753408815
# expected=5.0, predicted=46.87073130242298
# expected=72.0, predicted=35.20811621646967
# expected=55.0, predicted=39.773202669978225
# expected=41.0, predicted=49.32695691092885
# expected=8.0, predicted=40.561006650893795
# expected=41.0, predicted=46.56403236766503
# expected=69.0, predicted=44.77387911664327
# expected=66.0, predicted=38.67241296936041
# expected=17.0, predicted=45.85066758065012
# expected=49.0, predicted=35.07012116146075
# expected=43.0, predicted=42.12758273168838
# expected=37.0, predicted=43.72681262917975
# expected=8.0, predicted=43.28554549091266
# expected=46.0, predicted=36.47951933174369
# expected=5.0, predicted=43.1862257537638
# expected=51.0, predicted=39.78419060543593
# expected=47.0, predicted=38.6903179872678
# expected=39.0, predicted=43.455174805375975
# expected=56.0, predicted=33.37791478327518
# expected=61.0, predicted=43.318583714081136
# expected=46.0, predicted=54.87180849715076
# expected=43.0, predicted=40.93529010989735
# expected=38.0, predicted=42.58358170090426
# expected=38.0, predicted=43.28510635002506
# expected=38.0, predicted=40.950808903568415
# expected=37.0, predicted=39.622687184856396
# expected=37.0, predicted=37.75023462176137
# expected=46.0, predicted=37.91511088821586
# expected=50.0, predicted=43.455477438016224
# expected=43.0, predicted=45.065113117731606
# expected=24.0, predicted=42.300991137486925
# expected=32.0, predicted=33.174345306088306
# expected=39.0, predicted=36.6454407363162
# expected=38.0, predicted=43.27588758055365
# expected=41.0, predicted=40.04909922140486
# expected=34.0, predicted=43.569711210301506
# expected=36.0, predicted=35.13980116160709
# expected=34.0, predicted=36.46504293162707
# expected=33.0, predicted=37.978041908603444
# expected=36.0, predicted=36.36485445892791
# expected=29.0, predicted=39.16171277363807
# expected=41.0, predicted=33.538049926432066
# expected=52.0, predicted=40.7752668655663
# expected=45.0, predicted=43.99276972803809
# expected=27.0, predicted=43.01483840106519
# expected=39.0, predicted=36.03696569872757
# expected=37.0, predicted=36.84033389392068
# expected=54.0, predicted=41.27364403160371
# expected=81.0, predicted=48.979221938555
# expected=83.0, predicted=44.47747169386411
# expected=56.0, predicted=57.796174438010596
# expected=47.0, predicted=56.47320979057203
# expected=49.0, predicted=52.65284883488756
# expected=41.0, predicted=56.71663690865974
# expected=61.0, predicted=49.91749096900807
# expected=56.0, predicted=50.37106702813782
# expected=21.0, predicted=49.43578903609871
# expected=79.0, predicted=36.89349464885263
# expected=64.0, predicted=47.8510935310707
# expected=51.0, predicted=48.47032839525251
# expected=56.0, predicted=48.68767234033151
# expected=45.0, predicted=47.36731852100165
# expected=59.0, predicted=51.18527855871369
# expected=63.0, predicted=47.44292940350631
# expected=38.0, predicted=51.72341108941035
# expected=37.0, predicted=37.33162907706602
# expected=37.0, predicted=36.25899638162384
# expected=29.0, predicted=44.08469282385258
# expected=47.0, predicted=36.18476517239636
# expected=26.0, predicted=41.375235075726074
# expected=55.0, predicted=33.80899091981311
# expected=44.0, predicted=46.72490312173919
# expected=32.0, predicted=41.61439548568135
# expected=33.0, predicted=37.67503454445949
# expected=40.0, predicted=38.61987495119707
# expected=33.0, predicted=44.42211840809589
# expected=67.0, predicted=37.40761581441846
# expected=26.0, predicted=47.02619099431845
# expected=16.0, predicted=37.54937494075533
# expected=92.0, predicted=34.47652272323548
# expected=64.0, predicted=37.81705638652043
# expected=47.0, predicted=52.775227693577534
# expected=40.0, predicted=42.70373748734277
# expected=12.0, predicted=36.53838038704105
# expected=37.0, predicted=36.88644484143677

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 13.86073287482008
# RMSE: 18.17937077963092
# MAPE: 62.67150375577623

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(train_index, [x[-1] for x in train], color='black', label='Train')
plt.plot(test_index, y, color='blue', label='Test')
plt.plot(test_index, yhat, color='magenta', label='Predict')
plt.plot(forecast_index, forecast, color='cyan', label='Predict 90 days')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 9:1')
plt.show()

# %%
plt.figure(figsize=(14, 7))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['orange', 'green', 'red']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 9:1')
plt.show()
