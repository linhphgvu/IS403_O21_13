# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'halong_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.9

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_3508\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=61.0, predicted=57.16697406028784
# expected=68.0, predicted=55.95371409409187
# expected=72.0, predicted=58.86226461459075
# expected=69.8, predicted=69.97113333333334
# expected=71.0, predicted=61.2590655884421
# expected=79.2, predicted=68.26943793077261
# expected=81.0, predicted=78.06824188034184
# expected=74.6, predicted=78.55895436507933
# expected=72.2, predicted=72.94152173029764
# expected=69.2, predicted=71.61975497835499
# expected=65.6, predicted=62.80610007742259
# expected=58.4, predicted=64.25973631592656
# expected=55.2, predicted=53.38823104787785
# expected=56.2, predicted=51.11418343196191
# expected=53.4, predicted=52.686625492336034
# expected=47.6, predicted=52.22699302592257
# expected=45.2, predicted=45.00209131283989
# expected=46.2, predicted=43.64796903979943
# expected=43.8, predicted=44.70479127281462
# expected=40.8, predicted=44.07890169444301
# expected=44.6, predicted=41.997230492659966
# expected=43.4, predicted=46.112358474042175
# expected=41.2, predicted=45.10811333263246
# expected=39.0, predicted=41.87039755726479
# expected=37.4, predicted=36.692748246583236
# expected=33.0, predicted=36.18311237710541
# expected=30.4, predicted=35.10805970977429
# expected=32.4, predicted=33.57683393629247
# expected=37.4, predicted=33.924720996399934
# expected=45.2, predicted=38.319212964758385
# expected=51.8, predicted=46.32299188565604
# expected=60.0, predicted=54.25403852262268
# expected=63.6, predicted=62.05667100075259
# expected=70.4, predicted=61.80058886382179
# expected=76.0, predicted=65.54921169396562
# expected=77.2, predicted=71.89025479082319
# expected=77.8, predicted=73.25363188200684
# expected=78.0, predicted=76.09523747216835
# expected=73.2, predicted=76.73098247765304
# expected=63.2, predicted=72.26370687874216
# expected=58.8, predicted=58.84124156507515
# expected=52.4, predicted=54.79319961368073
# expected=52.0, predicted=50.67541380644948
# expected=55.2, predicted=51.12133434605709
# expected=56.8, predicted=53.83080799330086
# expected=55.6, predicted=54.27183458226031
# expected=57.2, predicted=53.19430353659752
# expected=55.0, predicted=54.156183393379344
# expected=50.6, predicted=52.68454179642615
# expected=51.8, predicted=49.393552974208866
# expected=49.8, predicted=53.71387783141024
# expected=51.0, predicted=49.57621228253622
# expected=52.6, predicted=51.99687058513509
# expected=47.8, predicted=53.01508685744416
# expected=41.6, predicted=48.81354315927204
# expected=40.0, predicted=40.17444582502259
# expected=36.0, predicted=39.53447529376244
# expected=30.2, predicted=35.19571886547017
# expected=30.0, predicted=32.889508186740485
# expected=27.6, predicted=32.777260534706976
# expected=22.4, predicted=32.394431216675656
# expected=27.4, predicted=28.171187072396975
# expected=24.4, predicted=30.08514550855825
# expected=30.0, predicted=29.514022663057013
# expected=38.8, predicted=32.75723244120386
# expected=48.8, predicted=39.999765030909586
# expected=49.2, predicted=53.28699678273384
# expected=58.0, predicted=50.27400089970199
# expected=55.8, predicted=60.896808385405464
# expected=44.6, predicted=51.92750548927238
# expected=37.4, predicted=38.29868150368318
# expected=31.2, predicted=34.85681735477275
# expected=36.8, predicted=32.71520948789203
# expected=35.0, predicted=39.21360456829938
# expected=43.2, predicted=36.08068766624618
# expected=43.0, predicted=44.65769483089412
# expected=46.4, predicted=43.69858766670909
# expected=41.2, predicted=44.32873341617697
# expected=42.2, predicted=41.79692752453357
# expected=44.2, predicted=40.0284274276411
# expected=44.4, predicted=41.87053766015674
# expected=45.6, predicted=42.51499734109002
# expected=48.2, predicted=44.76797711420049
# expected=49.2, predicted=47.26317157247429
# expected=39.2, predicted=47.41605275105933
# expected=39.4, predicted=37.46715631330994
# expected=30.4, predicted=38.76303740444307
# expected=26.4, predicted=30.955340363635642
# expected=21.8, predicted=28.242616355673178
# expected=31.4, predicted=26.033691613143223
# expected=35.4, predicted=32.761951190998026
# expected=37.2, predicted=37.86639636264327
# expected=29.4, predicted=39.59516524099064
# expected=39.0, predicted=33.70621889677833
# expected=35.0, predicted=38.400722453796796
# expected=34.0, predicted=36.50682184728323
# expected=35.6, predicted=36.43691610022444
# expected=42.4, predicted=38.088145358137574
# expected=40.8, predicted=40.20196094706142
# expected=35.0, predicted=43.186232427861796
# expected=32.6, predicted=36.06134283929856
# expected=41.0, predicted=34.76262950563286
# expected=45.6, predicted=40.5350015779717
# expected=42.0, predicted=45.75566900524615
# expected=52.4, predicted=44.12809529991854
# expected=57.6, predicted=51.48751607251188
# expected=53.8, predicted=56.72176722120431
# expected=42.4, predicted=50.20732181735762
# expected=47.6, predicted=39.156299850673406
# expected=47.2, predicted=43.62321920402744
# expected=44.0, predicted=45.04922585304894
# expected=36.2, predicted=41.62374287115362
# expected=43.4, predicted=36.917997688994376
# expected=42.8, predicted=42.201863332596375
# expected=45.0, predicted=42.43854896042858
# expected=40.2, predicted=44.76015735941448
# expected=48.4, predicted=42.158649911872224
# expected=48.8, predicted=48.69308079579094
# expected=42.4, predicted=49.129710936552236
# expected=30.8, predicted=41.879744325625886
# expected=36.6, predicted=31.01437250806862
# expected=27.8, predicted=36.552620527445704
# expected=29.4, predicted=27.69500596064524
# expected=31.4, predicted=34.036070118961966
# expected=37.6, predicted=34.84122915843569
# expected=39.6, predicted=39.72270689213149
# expected=50.8, predicted=41.490070782173724
# expected=49.8, predicted=54.352418916893846
# expected=49.0, predicted=49.72237407041494
# expected=48.8, predicted=47.372464085831716
# expected=45.2, predicted=49.45285796610635
# expected=40.6, predicted=38.641926279215745
# expected=38.8, predicted=39.87264797466352
# expected=37.6, predicted=37.41339965171597
# expected=39.2, predicted=36.79539587175659
# expected=41.6, predicted=39.33276264709427
# expected=42.6, predicted=42.17990558709556
# expected=40.0, predicted=42.0266613828557
# expected=39.0, predicted=41.53284172391554
# expected=37.6, predicted=36.4551182242882
# expected=35.2, predicted=36.7421627038382
# expected=34.8, predicted=35.52753400799681
# expected=36.8, predicted=37.3773909802409
# expected=37.6, predicted=38.17770599406206
# expected=36.6, predicted=38.94088340812866
# expected=35.6, predicted=38.37279963739584
# expected=34.6, predicted=36.153639035784224
# expected=33.6, predicted=35.97229092311463
# expected=34.6, predicted=35.456355691938874
# expected=38.2, predicted=35.460250854812394
# expected=40.6, predicted=38.74912519047098
# expected=38.8, predicted=42.1429476130815
# expected=40.8, predicted=37.7275641449247
# expected=40.0, predicted=41.76253132319175
# expected=40.4, predicted=40.638623050094
# expected=47.6, predicted=41.00598486957613
# expected=58.8, predicted=47.29117565027428
# expected=62.2, predicted=58.18957228713349
# expected=64.2, predicted=62.67038995995433
# expected=63.2, predicted=62.05622444351356
# expected=55.2, predicted=59.88487298348888
# expected=50.8, predicted=49.6662898104448
# expected=50.8, predicted=49.02873102901734
# expected=45.6, predicted=50.23998144573093
# expected=51.6, predicted=43.33332368930965
# expected=56.2, predicted=50.41784225788294
# expected=54.2, predicted=53.42392465039429
# expected=54.2, predicted=51.15810493244414
# expected=59.0, predicted=51.852555962361755
# expected=55.0, predicted=56.318443365013245
# expected=54.8, predicted=51.95629900922372
# expected=52.2, predicted=53.38571142867129
# expected=48.4, predicted=50.81266227028432
# expected=46.8, predicted=46.951183171757
# expected=40.8, predicted=43.71458761455984
# expected=37.6, predicted=40.68549568028825
# expected=35.2, predicted=36.546833126171784
# expected=38.8, predicted=35.422491511024376
# expected=40.2, predicted=39.20442077223501
# expected=40.8, predicted=41.09240864661617
# expected=38.0, predicted=41.95116905257699
# expected=40.8, predicted=37.64071195022582
# expected=36.4, predicted=39.505151552342184
# expected=41.0, predicted=35.75441601815267
# expected=39.8, predicted=40.17856916070094
# expected=36.4, predicted=40.278424779824036
# expected=46.8, predicted=36.73580770939716
# expected=53.0, predicted=47.13417062416771
# expected=49.0, predicted=51.43812575432765
# expected=51.8, predicted=50.955817611398146
# expected=51.0, predicted=51.68008611564508
# expected=40.0, predicted=49.03401982276455

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 3.742444077988855
# RMSE: 4.705408886506923
# MAPE: 8.611768278229553
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_3508\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
forecast_series = pd.Series(forecast)
forecast_smoothed = smoothed(forecast_series)
forecast_smoothed = forecast_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_3508\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast_smoothed[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 9:1')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast_smoothed[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 9:1')
plt.show()
