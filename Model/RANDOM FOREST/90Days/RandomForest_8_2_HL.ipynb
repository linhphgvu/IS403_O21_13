# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'halong_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.8

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_484\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=47.4, predicted=44.921435944397075
# expected=47.2, predicted=47.22084969789669
# expected=48.6, predicted=45.46363014831797
# expected=58.8, predicted=49.17131583972117
# expected=58.6, predicted=54.121557245924
# expected=58.0, predicted=55.241025170757595
# expected=56.4, predicted=53.97526395387009
# expected=52.6, predicted=50.62729813447062
# expected=49.4, predicted=47.89850283747095
# expected=45.2, predicted=46.74208349887002
# expected=46.6, predicted=41.34102144267229
# expected=35.2, predicted=44.670849293034316
# expected=26.0, predicted=33.432280265306694
# expected=24.8, predicted=31.56220085741652
# expected=29.0, predicted=30.32697038492178
# expected=28.8, predicted=36.21947146083134
# expected=33.2, predicted=32.67806040837063
# expected=42.4, predicted=37.361766084099195
# expected=38.6, predicted=44.463638102203134
# expected=38.6, predicted=36.93388630567508
# expected=34.6, predicted=38.74105464070856
# expected=35.0, predicted=34.9593679206483
# expected=38.4, predicted=35.62347986014922
# expected=32.8, predicted=36.960396249380786
# expected=41.8, predicted=35.60764971291247
# expected=50.6, predicted=43.77150545964554
# expected=52.2, predicted=47.60957290203666
# expected=50.0, predicted=52.84299033590859
# expected=61.6, predicted=50.429341822312715
# expected=64.4, predicted=58.57621016193814
# expected=58.6, predicted=59.974743492290365
# expected=60.2, predicted=55.281565872298124
# expected=56.0, predicted=57.23811097845215
# expected=44.4, predicted=51.979758747909145
# expected=32.6, predicted=41.403849061463276
# expected=25.8, predicted=33.40812608743333
# expected=29.8, predicted=29.019273289260582
# expected=27.6, predicted=32.10044991406228
# expected=30.8, predicted=32.59449708640122
# expected=28.6, predicted=34.235805749795695
# expected=30.6, predicted=30.643008214213413
# expected=20.2, predicted=33.887691559096915
# expected=18.0, predicted=26.29243595848193
# expected=18.2, predicted=21.46909005953789
# expected=17.8, predicted=22.8566718848403
# expected=19.2, predicted=20.202783756903578
# expected=25.2, predicted=22.303299728801377
# expected=29.0, predicted=30.024708123888946
# expected=28.8, predicted=33.180409737492525
# expected=26.8, predicted=30.521464238668674
# expected=24.6, predicted=29.21050246743571
# expected=17.4, predicted=26.735604288695807
# expected=14.6, predicted=17.806132604923686
# expected=15.2, predicted=15.598952700926532
# expected=16.8, predicted=17.18213693555548
# expected=19.0, predicted=17.911572012925674
# expected=22.8, predicted=20.50455072470372
# expected=23.2, predicted=28.001893887172155
# expected=22.2, predicted=24.444390136244422
# expected=24.4, predicted=23.182322537350757
# expected=25.4, predicted=27.283159366445094
# expected=28.6, predicted=26.888961047625095
# expected=38.2, predicted=27.572557908859007
# expected=43.6, predicted=38.460559158448966
# expected=44.6, predicted=45.85209057059128
# expected=47.4, predicted=45.40625503639623
# expected=42.8, predicted=46.90353814794623
# expected=31.6, predicted=43.67495036901005
# expected=25.4, predicted=29.539010893121027
# expected=26.8, predicted=26.867747502765873
# expected=32.8, predicted=28.74429937912826
# expected=32.6, predicted=36.508305897358035
# expected=35.4, predicted=35.36883110176223
# expected=35.4, predicted=36.641460068204495
# expected=37.2, predicted=35.10603440673364
# expected=45.2, predicted=38.108636978715296
# expected=47.4, predicted=46.59275884659484
# expected=45.8, predicted=46.78086862896913
# expected=47.6, predicted=46.26718367147688
# expected=41.8, predicted=46.9961019572939
# expected=23.2, predicted=40.49062349450709
# expected=22.0, predicted=24.531395997339168
# expected=20.4, predicted=23.546734293356415
# expected=17.0, predicted=22.931169740482627
# expected=14.0, predicted=19.57174499666999
# expected=11.8, predicted=15.764451375798695
# expected=9.0, predicted=13.791408080808074
# expected=13.0, predicted=10.22716071428571
# expected=15.6, predicted=15.212829797979799
# expected=18.4, predicted=15.694138227895873
# expected=25.6, predicted=19.804785745931405
# expected=29.8, predicted=30.907186634566397
# expected=28.0, predicted=33.82167796071929
# expected=32.0, predicted=28.979460678800685
# expected=35.4, predicted=31.98521762037202
# expected=36.4, predicted=34.777246972370705
# expected=43.0, predicted=36.0493429209342
# expected=46.4, predicted=44.61348350776393
# expected=43.2, predicted=45.39715509556467
# expected=40.2, predicted=44.17354121663769
# expected=39.2, predicted=43.08688677356193
# expected=32.2, predicted=39.65565605600801
# expected=30.0, predicted=34.09334297676129
# expected=35.8, predicted=32.30743258403865
# expected=38.8, predicted=36.897633459166016
# expected=36.4, predicted=39.6621150062028
# expected=34.8, predicted=39.609292838053676
# expected=36.0, predicted=34.53148132796454
# expected=35.2, predicted=35.91719057094362
# expected=37.6, predicted=33.24042564209055
# expected=39.4, predicted=40.30847686886711
# expected=39.2, predicted=41.19182260027941
# expected=35.6, predicted=39.44198647266664
# expected=31.2, predicted=35.787870466849874
# expected=30.4, predicted=31.15545570922841
# expected=34.2, predicted=30.25985919081695
# expected=40.0, predicted=34.018018784365275
# expected=46.0, predicted=42.113902901231796
# expected=48.8, predicted=46.96707438329739
# expected=49.2, predicted=49.78595990142897
# expected=45.4, predicted=48.86910594782684
# expected=38.8, predicted=41.688012739836466
# expected=31.2, predicted=35.48731315683645
# expected=25.8, predicted=30.904577957103264
# expected=19.2, predicted=27.200363086429725
# expected=16.6, predicted=24.068291741756525
# expected=16.4, predicted=18.927420238095234
# expected=17.0, predicted=16.661692849307556
# expected=18.4, predicted=17.777890840620756
# expected=19.2, predicted=21.883076445539622
# expected=18.4, predicted=21.54598120606069
# expected=20.2, predicted=20.511600872635395
# expected=24.6, predicted=21.671089008423124
# expected=25.2, predicted=27.677560166102705
# expected=25.6, predicted=27.718676589784494
# expected=24.8, predicted=27.159037227952
# expected=25.0, predicted=26.95742385473201
# expected=23.4, predicted=26.36742348746403
# expected=24.6, predicted=23.7018126129314
# expected=26.2, predicted=26.34648516080076
# expected=29.0, predicted=27.927202507992348
# expected=31.8, predicted=31.3665107576878
# expected=33.6, predicted=32.010352224848546
# expected=34.8, predicted=36.024682608017116
# expected=38.0, predicted=35.315339991623034
# expected=41.6, predicted=40.93461556441247
# expected=38.4, predicted=45.186908501852464
# expected=36.2, predicted=39.46143197036835
# expected=34.8, predicted=37.22621996289767
# expected=29.4, predicted=35.065848506023556
# expected=25.2, predicted=30.546393562756467
# expected=27.8, predicted=26.397096195227753
# expected=36.2, predicted=28.810055129855577
# expected=39.4, predicted=36.392157760092225
# expected=46.0, predicted=41.410423728107816
# expected=51.8, predicted=46.78885550970319
# expected=55.0, predicted=50.30800119495581
# expected=46.2, predicted=50.56861717214873
# expected=40.6, predicted=43.31089714918094
# expected=33.4, predicted=38.163996336068976
# expected=24.4, predicted=30.033137187458486
# expected=21.8, predicted=24.642087754005015
# expected=24.2, predicted=22.81365352790267
# expected=29.2, predicted=26.726760587592594
# expected=35.0, predicted=35.25175065100487
# expected=42.6, predicted=36.66506725361327
# expected=42.4, predicted=43.10035734185881
# expected=43.6, predicted=43.977963423860814
# expected=38.6, predicted=44.379560605690166
# expected=37.2, predicted=37.4152875570704
# expected=38.6, predicted=35.975792317051294
# expected=43.0, predicted=36.709175661983615
# expected=42.6, predicted=42.6386319293912
# expected=45.0, predicted=42.75372567231449
# expected=42.4, predicted=45.142687275880135
# expected=37.2, predicted=41.69512988741983
# expected=33.2, predicted=36.81059129437426
# expected=34.4, predicted=33.52902180084567
# expected=31.8, predicted=34.177230838498105
# expected=28.6, predicted=32.874445691126496
# expected=26.2, predicted=28.544328107921757
# expected=25.6, predicted=26.97619684712627
# expected=21.8, predicted=26.948371417783356
# expected=24.4, predicted=24.37012964498654
# expected=32.6, predicted=25.82435092072368
# expected=33.8, predicted=35.89446693253858
# expected=31.8, predicted=35.579816149933045
# expected=35.0, predicted=31.423836451645414
# expected=39.2, predicted=34.823283343845944
# expected=40.6, predicted=37.857329641640554
# expected=48.4, predicted=43.29896886595643
# expected=58.0, predicted=47.817059049699026
# expected=61.0, predicted=58.125942561360226
# expected=68.0, predicted=55.96849834899401
# expected=72.0, predicted=56.79997469126783
# expected=69.8, predicted=69.27469957983195
# expected=71.0, predicted=61.88062769950262
# expected=79.2, predicted=68.50945040036592
# expected=81.0, predicted=76.48623961038956
# expected=74.6, predicted=80.25328538324418
# expected=72.2, predicted=73.2587339105339
# expected=69.2, predicted=71.82791111111109
# expected=65.6, predicted=61.16062864697338
# expected=58.4, predicted=63.024952616423825
# expected=55.2, predicted=53.840963400919044
# expected=56.2, predicted=50.72285680734858
# expected=53.4, predicted=53.111813945536625
# expected=47.6, predicted=52.26302055920455
# expected=45.2, predicted=46.45810602203284
# expected=46.2, predicted=43.952213304064024
# expected=43.8, predicted=44.828847125975116
# expected=40.8, predicted=43.61154637230729
# expected=44.6, predicted=42.54899859707692
# expected=43.4, predicted=45.267707822311
# expected=41.2, predicted=42.761301058380425
# expected=39.0, predicted=42.451965847758345
# expected=37.4, predicted=36.880072482655876
# expected=33.0, predicted=36.32472743176054
# expected=30.4, predicted=35.71921215201287
# expected=32.4, predicted=34.12956103690883
# expected=37.4, predicted=34.91095227779688
# expected=45.2, predicted=38.86649850021814
# expected=51.8, predicted=47.227256377703014
# expected=60.0, predicted=53.48612184315452
# expected=63.6, predicted=62.82357107952432
# expected=70.4, predicted=61.852507314092726
# expected=76.0, predicted=66.85728648216232
# expected=77.2, predicted=72.84691666666666
# expected=77.8, predicted=73.330971023421
# expected=78.0, predicted=77.4635089851325
# expected=73.2, predicted=76.7186166476419
# expected=63.2, predicted=72.36531031191029
# expected=58.8, predicted=59.12517010173455
# expected=52.4, predicted=55.28453213339821
# expected=52.0, predicted=50.90416350675195
# expected=55.2, predicted=50.87250325400428
# expected=56.8, predicted=53.36039953259589
# expected=55.6, predicted=53.798734604338286
# expected=57.2, predicted=53.10180835750104
# expected=55.0, predicted=54.55827548829405
# expected=50.6, predicted=52.69630459618419
# expected=51.8, predicted=49.211267523978776
# expected=49.8, predicted=52.84341621213391
# expected=51.0, predicted=50.60983264214234
# expected=52.6, predicted=52.38661962944947
# expected=47.8, predicted=54.56212121775829
# expected=41.6, predicted=48.452790850570985
# expected=40.0, predicted=40.3623497007606
# expected=36.0, predicted=40.216762875786856
# expected=30.2, predicted=34.52010528240733
# expected=30.0, predicted=32.54215317719035
# expected=27.6, predicted=33.754919514532396
# expected=22.4, predicted=33.34363649117239
# expected=27.4, predicted=28.34347720827766
# expected=24.4, predicted=30.008247139832143
# expected=30.0, predicted=29.57784735041888
# expected=38.8, predicted=32.53090616492535
# expected=48.8, predicted=40.669755829361755
# expected=49.2, predicted=52.94425630743945
# expected=58.0, predicted=50.67486134326573
# expected=55.8, predicted=61.9600927263075
# expected=44.6, predicted=51.52249604938571
# expected=37.4, predicted=38.641416239592715
# expected=31.2, predicted=35.53479968725213
# expected=36.8, predicted=31.638891338752547
# expected=35.0, predicted=38.65195411746285
# expected=43.2, predicted=35.84266446642747
# expected=43.0, predicted=44.45372561904942
# expected=46.4, predicted=43.693853244899294
# expected=41.2, predicted=43.97687116502044
# expected=42.2, predicted=40.90795472749372
# expected=44.2, predicted=38.82883781576403
# expected=44.4, predicted=42.51698365952504
# expected=45.6, predicted=42.67105559755564
# expected=48.2, predicted=44.84311459960535
# expected=49.2, predicted=47.37740005213227
# expected=39.2, predicted=48.00139847395174
# expected=39.4, predicted=36.30159268166306
# expected=30.4, predicted=39.843148244725825
# expected=26.4, predicted=30.067568126853697
# expected=21.8, predicted=27.45198958338186
# expected=31.4, predicted=25.300124316851587
# expected=35.4, predicted=32.74947082747468
# expected=37.2, predicted=37.589018671204705
# expected=29.4, predicted=39.20240056324736
# expected=39.0, predicted=31.731597164008154
# expected=35.0, predicted=38.77703677700838
# expected=34.0, predicted=35.93170731258616
# expected=35.6, predicted=36.4347923768054
# expected=42.4, predicted=37.69512831199272
# expected=40.8, predicted=41.26936320495892
# expected=35.0, predicted=42.73987335935867
# expected=32.6, predicted=35.953400198926566
# expected=41.0, predicted=34.39350908939695
# expected=45.6, predicted=40.547478681246034
# expected=42.0, predicted=45.02048299644338
# expected=52.4, predicted=43.46032374754276
# expected=57.6, predicted=50.66089219791145
# expected=53.8, predicted=55.67783967858866
# expected=42.4, predicted=50.615221475384836
# expected=47.6, predicted=39.98403706095266
# expected=47.2, predicted=43.58748902613417
# expected=44.0, predicted=44.63906911132027
# expected=36.2, predicted=42.968044690539024
# expected=43.4, predicted=36.47838328813497
# expected=42.8, predicted=41.78577014654277
# expected=45.0, predicted=42.52924079067937
# expected=40.2, predicted=44.75769844768428
# expected=48.4, predicted=42.23377452514891
# expected=48.8, predicted=48.20402970805279
# expected=42.4, predicted=48.63254173486111
# expected=30.8, predicted=41.309445753837736
# expected=36.6, predicted=31.481049575703135
# expected=27.8, predicted=37.03716495963568
# expected=29.4, predicted=28.456340206320284
# expected=31.4, predicted=32.7336841708184
# expected=37.6, predicted=35.5910769460153
# expected=39.6, predicted=40.837691262701384
# expected=50.8, predicted=42.36034027990919
# expected=49.8, predicted=53.8377004295786
# expected=49.0, predicted=50.004529487077534
# expected=48.8, predicted=48.77510523361212
# expected=45.2, predicted=49.80719643882814
# expected=40.6, predicted=38.719193808443
# expected=38.8, predicted=40.1854821239889
# expected=37.6, predicted=37.368068659606266
# expected=39.2, predicted=36.02398812958995
# expected=41.6, predicted=39.18062381228017
# expected=42.6, predicted=42.118862186881245
# expected=40.0, predicted=42.445511646182055
# expected=39.0, predicted=41.4968449220521
# expected=37.6, predicted=37.739712630679975
# expected=35.2, predicted=36.93117044234432
# expected=34.8, predicted=34.53710536833763
# expected=36.8, predicted=37.30634471303388
# expected=37.6, predicted=37.32723973521822
# expected=36.6, predicted=40.16852568445091
# expected=35.6, predicted=38.45523668962155
# expected=34.6, predicted=36.43601971021713
# expected=33.6, predicted=36.05978034452963
# expected=34.6, predicted=35.343268016203595
# expected=38.2, predicted=35.28691590967217
# expected=40.6, predicted=38.68985879366104
# expected=38.8, predicted=42.37349991823644
# expected=40.8, predicted=38.74822155809646
# expected=40.0, predicted=42.05125577510495
# expected=40.4, predicted=40.67145955645849
# expected=47.6, predicted=41.60999421723345
# expected=58.8, predicted=47.51872374289767
# expected=62.2, predicted=57.69515395185719
# expected=64.2, predicted=61.49344325996539
# expected=63.2, predicted=61.00644939186914
# expected=55.2, predicted=60.071902606323455
# expected=50.8, predicted=49.845721386719795
# expected=50.8, predicted=49.51461966353203
# expected=45.6, predicted=49.78079640901924
# expected=51.6, predicted=42.890963639826424
# expected=56.2, predicted=49.67787328828103
# expected=54.2, predicted=53.009603541364996
# expected=54.2, predicted=51.17711945081353
# expected=59.0, predicted=50.74586325445415
# expected=55.0, predicted=58.119524129230214
# expected=54.8, predicted=52.04596906086366
# expected=52.2, predicted=53.131717219070175
# expected=48.4, predicted=51.33822745532331
# expected=46.8, predicted=47.63678190220941
# expected=40.8, predicted=44.15204203253343
# expected=37.6, predicted=39.60750226848336
# expected=35.2, predicted=36.03397570772962
# expected=38.8, predicted=34.850876575633855
# expected=40.2, predicted=38.394824179978386
# expected=40.8, predicted=41.517854080164064
# expected=38.0, predicted=41.188653739025085
# expected=40.8, predicted=37.436182713108565
# expected=36.4, predicted=39.35291698707184
# expected=41.0, predicted=35.94536354445218
# expected=39.8, predicted=40.627038843006474
# expected=36.4, predicted=40.40141787665554
# expected=46.8, predicted=36.27963686169425
# expected=53.0, predicted=45.59215322739823
# expected=49.0, predicted=52.373002880742
# expected=51.8, predicted=51.99890097130307
# expected=51.0, predicted=52.19315226929482
# expected=40.0, predicted=49.32067633966583

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_484\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 3.70608700147365
# RMSE: 4.673059489672813
# MAPE: 10.405906487896646
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
# forecast_series = pd.Series(forecast)
# forecast_smoothed = smoothed(forecast_series)
# forecast_smoothed = forecast_smoothed.to_numpy()

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 8:2')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 8:2')
plt.show()
