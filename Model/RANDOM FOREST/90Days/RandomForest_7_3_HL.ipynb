# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'halong_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.7

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_5340\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=37.0, predicted=43.431268666036694
# expected=31.8, predicted=38.24217991128966
# expected=35.8, predicted=32.99876801628639
# expected=34.8, predicted=35.23950475123649
# expected=31.6, predicted=34.61558763276907
# expected=38.8, predicted=34.33731907308386
# expected=37.4, predicted=39.65204034122984
# expected=51.4, predicted=38.776784171617095
# expected=59.6, predicted=55.709520979192675
# expected=18.4, predicted=17.466790989745878
# expected=19.2, predicted=21.460357766244428
# expected=18.4, predicted=21.804431962307554
# expected=20.2, predicted=20.435727168102424
# expected=24.6, predicted=21.552725826418413
# expected=25.2, predicted=28.08527595451143
# expected=25.6, predicted=27.147918906005643
# expected=24.8, predicted=27.57365212285158
# expected=25.0, predicted=26.594657964550933
# expected=23.4, predicted=26.63696962663254
# expected=24.6, predicted=23.073490375449165
# expected=26.2, predicted=25.71071005942216
# expected=29.0, predicted=27.66702316515612
# expected=31.8, predicted=30.613346541515238
# expected=33.6, predicted=32.26370903639771
# expected=34.8, predicted=35.552706844497955
# expected=38.0, predicted=35.043093954711615
# expected=41.6, predicted=40.245701343602605
# expected=38.4, predicted=43.76373828247536
# expected=36.2, predicted=40.139660755462614
# expected=34.8, predicted=35.89523081289218
# expected=29.4, predicted=35.05680270017494
# expected=25.2, predicted=30.46394433940818
# expected=27.8, predicted=25.951887783269072
# expected=36.2, predicted=29.092747570152063
# expected=39.4, predicted=37.30598395213972
# expected=46.0, predicted=41.404117048911495
# expected=51.8, predicted=45.87536607045223
# expected=55.0, predicted=51.13859863592411
# expected=46.2, predicted=50.594478407187
# expected=40.6, predicted=42.71321543927801
# expected=33.4, predicted=36.52130551989243
# expected=24.4, predicted=29.788294283410668
# expected=21.8, predicted=24.112551187568588
# expected=24.2, predicted=23.689348282115517
# expected=29.2, predicted=27.92523917371279
# expected=35.0, predicted=33.757753530900324
# expected=42.6, predicted=36.15726800221189
# expected=42.4, predicted=44.5582183086739
# expected=43.6, predicted=43.2627865685049
# expected=38.6, predicted=44.471924746235025
# expected=37.2, predicted=37.75345932667325
# expected=38.6, predicted=36.84424772822622
# expected=43.0, predicted=37.64421932924894
# expected=42.6, predicted=42.30878249436544
# expected=45.0, predicted=42.80759953362177
# expected=42.4, predicted=44.584411457619865
# expected=37.2, predicted=42.45448090740306
# expected=33.2, predicted=37.49628818379905
# expected=34.4, predicted=33.67048481401349
# expected=31.8, predicted=34.68604029423406
# expected=28.6, predicted=33.041563292950016
# expected=26.2, predicted=28.649906978319322
# expected=25.6, predicted=26.701875588411003
# expected=21.8, predicted=26.486443505879738
# expected=24.4, predicted=24.480189045179074
# expected=32.6, predicted=25.60637532783182
# expected=33.8, predicted=36.43695719324447
# expected=31.8, predicted=35.43968854631744
# expected=35.0, predicted=32.932562013692085
# expected=39.2, predicted=34.799091398666214
# expected=40.6, predicted=37.732793312754595
# expected=48.4, predicted=42.661638026680876
# expected=58.0, predicted=47.137476029896895
# expected=61.0, predicted=57.2063721173398
# expected=68.0, predicted=56.28871311564252
# expected=72.0, predicted=57.49725427099872
# expected=69.8, predicted=71.24386666666666
# expected=71.0, predicted=61.620487607164094
# expected=79.2, predicted=68.82676052018161
# expected=81.0, predicted=76.72077777777774
# expected=74.6, predicted=79.60321507936504
# expected=72.2, predicted=74.02877914862917
# expected=69.2, predicted=72.49010769230767
# expected=65.6, predicted=62.51320285296963
# expected=58.4, predicted=63.39631942326682
# expected=55.2, predicted=54.57305014227496
# expected=56.2, predicted=50.95529730053281
# expected=53.4, predicted=53.036350714255335
# expected=47.6, predicted=51.6469475306797
# expected=45.2, predicted=47.42890422492438
# expected=46.2, predicted=42.6369455978888
# expected=43.8, predicted=45.28812549082354
# expected=40.8, predicted=43.38207887627858
# expected=44.6, predicted=41.77536795177812
# expected=43.4, predicted=44.45421463072519
# expected=41.2, predicted=44.20629106278037
# expected=39.0, predicted=41.7769566478269
# expected=37.4, predicted=37.30455834650119
# expected=33.0, predicted=36.41666019549327
# expected=30.4, predicted=34.446436352007396
# expected=32.4, predicted=34.37986768651043
# expected=37.4, predicted=34.697986828165824
# expected=45.2, predicted=38.16980034998048
# expected=51.8, predicted=46.390280586365265
# expected=60.0, predicted=54.37821572442594
# expected=63.6, predicted=62.33452620843211
# expected=70.4, predicted=62.02944680507201
# expected=76.0, predicted=66.36039374039872
# expected=77.2, predicted=73.66691662226663
# expected=77.8, predicted=73.44616518807987
# expected=78.0, predicted=76.55325097402597
# expected=73.2, predicted=76.56340918297388
# expected=63.2, predicted=72.07674406570503
# expected=58.8, predicted=58.39179595938988
# expected=52.4, predicted=55.16642082538754
# expected=52.0, predicted=51.13783899008002
# expected=55.2, predicted=50.7292318956736
# expected=56.8, predicted=52.91289392228155
# expected=55.6, predicted=54.52409165809929
# expected=57.2, predicted=52.87109103000802
# expected=55.0, predicted=54.520596121937835
# expected=50.6, predicted=52.540401986482294
# expected=51.8, predicted=50.12895351616502
# expected=49.8, predicted=52.88160707913029
# expected=51.0, predicted=49.25363289275378
# expected=52.6, predicted=52.98920915226732
# expected=47.8, predicted=53.111257894572184
# expected=41.6, predicted=47.877504737578874
# expected=40.0, predicted=40.18089871420981
# expected=36.0, predicted=39.57321931034099
# expected=30.2, predicted=34.700099164681404
# expected=30.0, predicted=32.859171178517784
# expected=27.6, predicted=32.963336644787944
# expected=22.4, predicted=31.72928742701975
# expected=27.4, predicted=27.873809444150623
# expected=24.4, predicted=29.849722340955537
# expected=30.0, predicted=29.22527449870514
# expected=38.8, predicted=31.206397208003427
# expected=48.8, predicted=40.06569523224996
# expected=49.2, predicted=52.7364579393746
# expected=58.0, predicted=51.04379592435068
# expected=55.8, predicted=60.21950281116797
# expected=44.6, predicted=51.851220813151464
# expected=37.4, predicted=37.4164030746837
# expected=31.2, predicted=35.69652882029453
# expected=36.8, predicted=31.216512432327267
# expected=35.0, predicted=39.86146050312682
# expected=43.2, predicted=34.99650072054505
# expected=43.0, predicted=44.97665595290564
# expected=46.4, predicted=42.9981127442701
# expected=41.2, predicted=44.65909681555122
# expected=42.2, predicted=41.026993540153974
# expected=44.2, predicted=39.11431244926056
# expected=44.4, predicted=42.44813568720774
# expected=45.6, predicted=42.245384714688846
# expected=48.2, predicted=44.486120472888054
# expected=49.2, predicted=47.94671200819244
# expected=39.2, predicted=47.952707540776075
# expected=39.4, predicted=36.95108510974118
# expected=30.4, predicted=38.64644664020892
# expected=26.4, predicted=30.544596622997037
# expected=21.8, predicted=28.105454055708865
# expected=31.4, predicted=24.92059682716609
# expected=35.4, predicted=33.22521701927842
# expected=37.2, predicted=38.072061595959134
# expected=29.4, predicted=39.84907274434501
# expected=39.0, predicted=33.32496899415339
# expected=35.0, predicted=38.58610003099323
# expected=34.0, predicted=35.772975731117896
# expected=35.6, predicted=36.72483902838385
# expected=42.4, predicted=38.42006781797862
# expected=40.8, predicted=40.75062831036021
# expected=35.0, predicted=42.90149476144621
# expected=32.6, predicted=36.57263002478904
# expected=41.0, predicted=34.44450018760469
# expected=45.6, predicted=41.42438321270126
# expected=42.0, predicted=44.579384714920685
# expected=52.4, predicted=43.93271898331987
# expected=57.6, predicted=51.081538260457926
# expected=53.8, predicted=56.939867270961415
# expected=42.4, predicted=50.26314470737315
# expected=47.6, predicted=39.60996456774198
# expected=47.2, predicted=43.624020413829385
# expected=44.0, predicted=44.63190006601938
# expected=36.2, predicted=41.683836663576294
# expected=43.4, predicted=35.147105768067355
# expected=42.8, predicted=41.92443458278971
# expected=45.0, predicted=41.86221163327854
# expected=40.2, predicted=44.77302478576066
# expected=48.4, predicted=41.803558261605474
# expected=48.8, predicted=47.91389679235574
# expected=42.4, predicted=48.76643282603287
# expected=30.8, predicted=42.08250756131576
# expected=36.6, predicted=30.757275689717716
# expected=27.8, predicted=36.954557077003
# expected=29.4, predicted=27.535388743056636
# expected=31.4, predicted=33.72358187350617
# expected=37.6, predicted=34.7068569291588
# expected=39.6, predicted=40.31819096615863
# expected=50.8, predicted=41.417839078326466
# expected=49.8, predicted=54.59035296678775
# expected=49.0, predicted=50.04964941835703
# expected=48.8, predicted=48.762060454306564
# expected=45.2, predicted=48.3636076319556
# expected=40.6, predicted=38.36008056927667
# expected=38.8, predicted=39.51472552606907
# expected=37.6, predicted=36.85363024481323
# expected=39.2, predicted=36.84245880874159
# expected=41.6, predicted=38.61792387604835
# expected=42.6, predicted=42.31651560302442
# expected=40.0, predicted=42.02416984838036
# expected=39.0, predicted=41.0416935244823
# expected=37.6, predicted=36.81223642911095
# expected=35.2, predicted=37.05057836750213
# expected=34.8, predicted=35.81730254012031
# expected=36.8, predicted=37.469497954612166
# expected=37.6, predicted=37.8611505631408
# expected=36.6, predicted=39.55958841050622
# expected=35.6, predicted=38.07688220473681
# expected=34.6, predicted=36.458755304462784
# expected=33.6, predicted=35.68314945150643
# expected=34.6, predicted=35.27809334357044
# expected=38.2, predicted=36.06945838751157
# expected=40.6, predicted=38.6993165834231
# expected=38.8, predicted=41.84993525345187
# expected=40.8, predicted=38.793685752527566
# expected=40.0, predicted=41.96313041589743
# expected=40.4, predicted=40.951425360701435
# expected=47.6, predicted=40.970430392567295
# expected=58.8, predicted=47.40097919540228
# expected=62.2, predicted=58.18536860490184
# expected=64.2, predicted=60.80167097425917
# expected=63.2, predicted=60.85491453157614
# expected=55.2, predicted=59.88944392077091
# expected=50.8, predicted=49.96172215359885
# expected=50.8, predicted=48.31576795477722
# expected=45.6, predicted=50.04163096780315
# expected=51.6, predicted=42.89301620292119
# expected=56.2, predicted=50.11733592587165
# expected=54.2, predicted=52.94028967916444
# expected=54.2, predicted=51.205917554893176
# expected=59.0, predicted=50.6493066866589
# expected=55.0, predicted=57.09059754793543
# expected=54.8, predicted=52.13222040602309
# expected=52.2, predicted=53.00542359946034
# expected=48.4, predicted=50.46236172794946
# expected=46.8, predicted=47.49677193935341
# expected=40.8, predicted=43.85524681871776
# expected=37.6, predicted=39.95567084664264
# expected=35.2, predicted=36.63401893822154
# expected=38.8, predicted=35.0913422474967
# expected=40.2, predicted=39.84234116387964
# expected=40.8, predicted=41.607016830493386
# expected=38.0, predicted=42.154520744923936
# expected=40.8, predicted=37.19708901296603
# expected=36.4, predicted=39.914923463811
# expected=41.0, predicted=35.5276576735565
# expected=39.8, predicted=41.019931030336394
# expected=36.4, predicted=40.38395352934785
# expected=46.8, predicted=36.264475271225066
# expected=53.0, predicted=46.54741767202956
# expected=49.0, predicted=51.94278379833787
# expected=51.8, predicted=52.343801668284
# expected=51.0, predicted=52.17462649902428
# expected=40.0, predicted=49.04877759714587

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_5340\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 4.199505853454031
# RMSE: 5.258356606014681
# MAPE: 11.603393170081358
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 7:3')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 7:3')
plt.show()
