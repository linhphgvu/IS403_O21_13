# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'viettri_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.9

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_14972\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=76.4, predicted=66.9550736603108
# expected=85.8, predicted=77.3234944977094
# expected=91.0, predicted=88.71789166922574
# expected=88.6, predicted=89.733832992008
# expected=85.8, predicted=88.03249889979304
# expected=89.4, predicted=84.94838810323162
# expected=94.0, predicted=88.77418401097339
# expected=98.6, predicted=92.3203887360774
# expected=90.6, predicted=100.36925961032439
# expected=83.4, predicted=86.93557543859646
# expected=76.6, predicted=83.35890138822528
# expected=60.2, predicted=74.35489427809097
# expected=45.8, predicted=56.785654374668496
# expected=46.4, predicted=45.70350682954509
# expected=44.0, predicted=48.01901419248192
# expected=48.0, predicted=42.328977020653454
# expected=58.6, predicted=49.289694502534054
# expected=70.6, predicted=59.03945419894157
# expected=83.2, predicted=77.12599078230184
# expected=92.4, predicted=86.77290617353663
# expected=88.6, predicted=92.67249741612017
# expected=86.0, predicted=85.51013196248195
# expected=78.6, predicted=86.30116417790519
# expected=70.0, predicted=74.26804617359407
# expected=59.8, predicted=68.9952173364747
# expected=53.8, predicted=53.414079067452775
# expected=44.4, predicted=48.40916468670767
# expected=35.6, predicted=42.5719107691556
# expected=32.8, predicted=36.57758624856822
# expected=36.8, predicted=34.85066451271745
# expected=40.6, predicted=38.53935170885889
# expected=48.2, predicted=42.91311571991043
# expected=57.2, predicted=50.94678361704066
# expected=66.6, predicted=62.9469731083664
# expected=74.4, predicted=64.50476668644347
# expected=78.8, predicted=76.61920820053773
# expected=84.2, predicted=77.16099980897154
# expected=89.0, predicted=87.6092281257958
# expected=84.0, predicted=89.28713054589375
# expected=80.6, predicted=82.90280002407658
# expected=80.8, predicted=76.95334513441941
# expected=71.4, predicted=75.21773424690167
# expected=66.2, predicted=67.14030001110004
# expected=64.2, predicted=60.781420003932766
# expected=60.2, predicted=61.09953086604356
# expected=58.0, predicted=53.05325584926725
# expected=62.0, predicted=52.38856575104701
# expected=61.4, predicted=56.683490135515484
# expected=57.6, predicted=58.254649101987255
# expected=50.2, predicted=55.0772915029008
# expected=38.2, predicted=47.36258548838895
# expected=28.6, predicted=38.529942718903726
# expected=24.0, predicted=28.53632358150514
# expected=28.2, predicted=27.57167293266796
# expected=34.0, predicted=31.50691064042059
# expected=39.2, predicted=38.554710084121396
# expected=58.6, predicted=42.918430554238164
# expected=51.6, predicted=62.92358181225423
# expected=40.4, predicted=51.76596634974431
# expected=44.6, predicted=40.7725173116459
# expected=53.4, predicted=42.13450334876754
# expected=30.6, predicted=51.5090067464933
# expected=40.8, predicted=34.236972847370836
# expected=51.2, predicted=41.10042076157029
# expected=49.4, predicted=52.01919799029954
# expected=46.0, predicted=49.91793173099751
# expected=54.8, predicted=45.8957926295839
# expected=54.4, predicted=54.877773275145024
# expected=57.4, predicted=54.43203117552547
# expected=53.4, predicted=56.771602141587415
# expected=47.2, predicted=52.704984742747904
# expected=47.6, predicted=44.88033476726335
# expected=49.2, predicted=47.85306941799757
# expected=45.4, predicted=49.16098577868693
# expected=49.0, predicted=46.31855637966756
# expected=58.4, predicted=47.76982791534822
# expected=62.0, predicted=54.10212707158278
# expected=55.2, predicted=58.10490013738294
# expected=50.2, predicted=52.431290260640374
# expected=49.4, predicted=48.24784644032675
# expected=38.6, predicted=47.14653157409617
# expected=35.2, predicted=36.27981479335221
# expected=40.0, predicted=33.789346737395746
# expected=43.8, predicted=40.32611622338127
# expected=41.4, predicted=42.1751076369443
# expected=51.0, predicted=42.357683358684326
# expected=54.4, predicted=55.6332058232119
# expected=54.8, predicted=53.74122691955449
# expected=56.0, predicted=53.8171277730833
# expected=63.0, predicted=53.79276381371002
# expected=62.4, predicted=60.33596036371668
# expected=59.8, predicted=60.96446721285658
# expected=59.6, predicted=54.81625664597286
# expected=52.6, predicted=53.59335940134025
# expected=40.4, predicted=48.28685940816229
# expected=32.6, predicted=38.14824089302574
# expected=25.4, predicted=36.27614301217858
# expected=22.8, predicted=26.896198669427235
# expected=24.2, predicted=22.738227699042184
# expected=25.2, predicted=28.14131409199469
# expected=26.2, predicted=28.87665793036582
# expected=39.4, predicted=30.77998801869142
# expected=45.2, predicted=46.51181524112833
# expected=57.0, predicted=49.437689386766685
# expected=75.0, predicted=55.22280198752174
# expected=83.2, predicted=81.32839606726984
# expected=89.8, predicted=84.85470774398114
# expected=98.0, predicted=86.90984043419047
# expected=88.0, predicted=96.86991360597956
# expected=71.0, predicted=86.81337263906227
# expected=69.8, predicted=65.03665549362071
# expected=60.0, predicted=67.06122693430528
# expected=43.6, predicted=54.27771512556978
# expected=49.2, predicted=41.86211917210815
# expected=57.0, predicted=47.614655689654235
# expected=58.6, predicted=55.937331130285166
# expected=58.2, predicted=59.1016923611957
# expected=59.2, predicted=59.76587848970555
# expected=52.4, predicted=58.55917852998151
# expected=50.0, predicted=49.908276068595505
# expected=51.2, predicted=47.89491031658381
# expected=50.2, predicted=48.855509112583114
# expected=55.6, predicted=48.09341659928963
# expected=61.6, predicted=56.81825237992755
# expected=60.6, predicted=57.67434790886949
# expected=58.8, predicted=55.590268817469166
# expected=57.4, predicted=53.3707646438453
# expected=54.6, predicted=52.8817768959165
# expected=54.6, predicted=51.19875801792448
# expected=60.2, predicted=52.65825235780548
# expected=61.6, predicted=56.398241143892186
# expected=64.2, predicted=57.20462339980667
# expected=69.6, predicted=62.476544226242346
# expected=74.2, predicted=68.41164509915971
# expected=69.6, predicted=76.5690991524208
# expected=61.6, predicted=69.69487269549276
# expected=58.8, predicted=53.95601562946776
# expected=49.6, predicted=52.522251656738234
# expected=40.2, predicted=45.90789346385344
# expected=44.8, predicted=39.108252989340066
# expected=50.6, predicted=43.704790739035836
# expected=51.2, predicted=50.30225047463228
# expected=55.8, predicted=52.07819070070946
# expected=61.8, predicted=58.16551673557294
# expected=58.8, predicted=57.75429609873592
# expected=52.8, predicted=57.93063353614693
# expected=53.0, predicted=49.89512944435552
# expected=55.0, predicted=49.999926893937584
# expected=54.4, predicted=55.045158321013375
# expected=52.6, predicted=55.67168011108237
# expected=54.2, predicted=50.87854700054544
# expected=53.0, predicted=51.143350480879796
# expected=49.8, predicted=50.875426660889914
# expected=45.0, predicted=48.11273666762405
# expected=45.0, predicted=44.75615902575538
# expected=48.2, predicted=46.19526920038245
# expected=52.2, predicted=49.962584543765296
# expected=57.0, predicted=54.4965557549396
# expected=62.0, predicted=58.27145629141393
# expected=63.4, predicted=58.6064924234311
# expected=56.8, predicted=61.87742140465657
# expected=49.2, predicted=54.336398227227555
# expected=41.6, predicted=45.43376443856976
# expected=37.2, predicted=41.20953012946679
# expected=32.0, predicted=36.249429914743445
# expected=30.2, predicted=35.42036869648443
# expected=29.4, predicted=32.84418347822026
# expected=31.2, predicted=30.48523258972417
# expected=27.6, predicted=32.23400479579325
# expected=27.8, predicted=30.416174642946597
# expected=28.0, predicted=30.151420124559774
# expected=28.8, predicted=29.79551295416167
# expected=25.8, predicted=30.60570091060319
# expected=27.0, predicted=29.591700119539027
# expected=28.0, predicted=30.549466052601293
# expected=26.4, predicted=29.998881387092723
# expected=24.2, predicted=28.350360823911288
# expected=25.4, predicted=25.75466723842685
# expected=25.2, predicted=26.51824112996668
# expected=19.8, predicted=25.797511915400875
# expected=20.8, predicted=20.329990768817023
# expected=21.2, predicted=21.199549248038544
# expected=21.4, predicted=21.387130340141915
# expected=24.4, predicted=21.868824014664124
# expected=25.6, predicted=27.294535946425825
# expected=23.4, predicted=27.66326593895675
# expected=23.6, predicted=25.238245597411783
# expected=25.6, predicted=25.307944931470384
# expected=25.4, predicted=25.17465952077527
# expected=27.6, predicted=25.605670148685633
# expected=27.8, predicted=28.929519453510917
# expected=27.4, predicted=28.663351333260493

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_14972\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 4.6436120199886535
# RMSE: 5.897967643673675
# MAPE: 9.488056352067169
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
# forecast_series = pd.Series(forecast)
# forecast_smoothed = smoothed(forecast_series)
# forecast_smoothed = forecast_smoothed.to_numpy()

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Việt Trì - 9:1')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Việt Trì - 9:1')
plt.show()
