# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=1, out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(data, test_n):
    predictions = []
    train, test = train_test_split(data, test_n)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'viettri_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series.values, In=6)

# %%
# Split the data
train_size = int(len(data) * 0.9)
train, test = train_test_split(data, len(data) - train_size)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(data, len(test))
# Out:
# expected=84.0, predicted=85.22267826347525
# expected=94.0, predicted=67.26532467377702
# expected=90.0, predicted=88.67378657352575
# expected=75.0, predicted=79.1871371515408
# expected=86.0, predicted=65.4124112149605
# expected=102.0, predicted=76.51656978540997
# expected=117.0, predicted=87.18296016001995
# expected=113.0, predicted=117.90632374325023
# expected=35.0, predicted=93.75055625073497
# expected=50.0, predicted=52.94360451975743
# expected=68.0, predicted=62.442481578649804
# expected=35.0, predicted=53.60835297148505
# expected=41.0, predicted=42.81646492085415
# expected=38.0, predicted=42.88048113022156
# expected=38.0, predicted=40.77558115835101
# expected=88.0, predicted=44.5738476540909
# expected=88.0, predicted=43.85994142942776
# expected=101.0, predicted=77.01311275348688
# expected=101.0, predicted=93.76234679061876
# expected=84.0, predicted=95.6737586652975
# expected=69.0, predicted=71.60205738124128
# expected=75.0, predicted=67.75824386716944
# expected=64.0, predicted=70.88543582199456
# expected=58.0, predicted=66.51986455465402
# expected=33.0, predicted=61.75401081918309
# expected=39.0, predicted=40.540779191688465
# expected=28.0, predicted=50.04821796229764
# expected=20.0, predicted=38.93596617327881
# expected=44.0, predicted=25.91959417317295
# expected=53.0, predicted=42.38904888668879
# expected=58.0, predicted=47.911946033782115
# expected=66.0, predicted=45.812588759509936
# expected=65.0, predicted=52.111956583909105
# expected=91.0, predicted=60.24951693253807
# expected=92.0, predicted=75.23480908553245
# expected=80.0, predicted=86.42442424404682
# expected=93.0, predicted=75.01095072598024
# expected=89.0, predicted=85.40452183981257
# expected=66.0, predicted=89.19777845319946
# expected=75.0, predicted=68.32367481153442
# expected=81.0, predicted=74.89760764853295
# expected=46.0, predicted=65.93299104567488
# expected=63.0, predicted=53.75769016533232
# expected=56.0, predicted=55.848983540861354
# expected=55.0, predicted=53.61428234714143
# expected=70.0, predicted=54.045919750672354
# expected=66.0, predicted=66.13343634451275
# expected=60.0, predicted=67.4746273278155
# expected=37.0, predicted=58.423862071700725
# expected=18.0, predicted=35.46912181687282
# expected=10.0, predicted=35.662557013670124
# expected=18.0, predicted=29.812923690681878
# expected=37.0, predicted=39.652458766265546
# expected=58.0, predicted=39.1076086255772
# expected=47.0, predicted=47.1218033173651
# expected=36.0, predicted=50.85480440750562
# expected=115.0, predicted=31.911508779912413
# expected=2.0, predicted=71.89941851411578
# expected=2.0, predicted=35.255351471804346
# expected=68.0, predicted=41.82917824809519
# expected=80.0, predicted=38.74517012403919
# expected=1.0, predicted=46.743219718387024
# expected=53.0, predicted=41.02769499408244
# expected=54.0, predicted=46.011874417093374
# expected=59.0, predicted=52.14611736736177
# expected=63.0, predicted=45.85030123349359
# expected=45.0, predicted=52.72495984979616
# expected=51.0, predicted=37.31996641901199
# expected=69.0, predicted=49.93809345750126
# expected=39.0, predicted=55.93049243752206
# expected=32.0, predicted=47.80289854451302
# expected=47.0, predicted=32.46110688945907
# expected=59.0, predicted=44.06849416912107
# expected=50.0, predicted=51.58434715412986
# expected=57.0, predicted=50.34038562159692
# expected=79.0, predicted=50.39764535427017
# expected=65.0, predicted=59.12493387996513
# expected=25.0, predicted=59.469259981063196
# expected=25.0, predicted=31.518736680783586
# expected=53.0, predicted=32.05140704699422
# expected=25.0, predicted=53.522904078297
# expected=48.0, predicted=32.938631326345416
# expected=49.0, predicted=42.88757170897948
# expected=44.0, predicted=49.11959831422528
# expected=41.0, predicted=44.246089788179255
# expected=73.0, predicted=41.712731219606596
# expected=65.0, predicted=54.470464856517786
# expected=51.0, predicted=52.64563941884769
# expected=50.0, predicted=50.81739478773209
# expected=76.0, predicted=51.23014235237779
# expected=70.0, predicted=56.01420420928641
# expected=52.0, predicted=62.03392579769946
# expected=50.0, predicted=53.56365150609178
# expected=15.0, predicted=55.558395930092395
# expected=15.0, predicted=35.89063803084549
# expected=31.0, predicted=27.38562815860216
# expected=16.0, predicted=34.24848079542085
# expected=37.0, predicted=26.733022390966095
# expected=22.0, predicted=38.63144124417637
# expected=20.0, predicted=25.08310492142524
# expected=36.0, predicted=26.560648924808742
# expected=82.0, predicted=38.32983334647427
# expected=66.0, predicted=48.69767472171842
# expected=81.0, predicted=56.27872638898785
# expected=110.0, predicted=56.6535122151816
# expected=77.0, predicted=91.61560697424292
# expected=115.0, predicted=63.74146763364869
# expected=107.0, predicted=103.67275894617791
# expected=31.0, predicted=84.01729187324507
# expected=25.0, predicted=45.06759059597478
# expected=71.0, predicted=43.97686353806214
# expected=66.0, predicted=46.564081661901156
# expected=25.0, predicted=58.57082216569041
# expected=59.0, predicted=27.62243862140591
# expected=64.0, predicted=38.37598397807802
# expected=79.0, predicted=58.1257608826295
# expected=64.0, predicted=61.54723205976272
# expected=30.0, predicted=52.79617989607918
# expected=25.0, predicted=39.4389346371883
# expected=52.0, predicted=38.729199913237714
# expected=85.0, predicted=46.128373798721995
# expected=59.0, predicted=47.0814378653947
# expected=57.0, predicted=51.94094188631646
# expected=55.0, predicted=54.14008529863964
# expected=47.0, predicted=54.692156267273106
# expected=76.0, predicted=52.20035950543846
# expected=52.0, predicted=63.92040403896751
# expected=43.0, predicted=48.41031657439476
# expected=55.0, predicted=46.06648810608644
# expected=75.0, predicted=48.83533221880996
# expected=83.0, predicted=58.26748483532034
# expected=65.0, predicted=64.6048170899557
# expected=70.0, predicted=54.15067631669627
# expected=78.0, predicted=64.00032218541148
# expected=52.0, predicted=65.74629738544512
# expected=43.0, predicted=53.292420633715665
# expected=51.0, predicted=49.660514284324265
# expected=24.0, predicted=52.12550558155675
# expected=31.0, predicted=34.27760580280446
# expected=75.0, predicted=33.61100384938448
# expected=72.0, predicted=45.432418031979005
# expected=54.0, predicted=62.698759393842465
# expected=47.0, predicted=53.22908211108215
# expected=61.0, predicted=48.64141469895822
# expected=60.0, predicted=55.96891767360669
# expected=42.0, predicted=58.067006449264284
# expected=55.0, predicted=47.72046991339978
# expected=57.0, predicted=52.764383634894905
# expected=58.0, predicted=55.59837148505655
# expected=51.0, predicted=54.04166970009598
# expected=50.0, predicted=54.18421861636566
# expected=49.0, predicted=51.101971724133556
# expected=41.0, predicted=49.82839298687529
# expected=34.0, predicted=43.056709621093276
# expected=51.0, predicted=36.00957332730493
# expected=66.0, predicted=48.740436549194946
# expected=69.0, predicted=55.74723318323435
# expected=65.0, predicted=58.9991123847428
# expected=59.0, predicted=55.80940592564926
# expected=58.0, predicted=56.334036441359395
# expected=33.0, predicted=56.48936578945739
# expected=31.0, predicted=37.18621385769582
# expected=27.0, predicted=36.32589025173907
# expected=37.0, predicted=31.01997568973929
# expected=32.0, predicted=37.63927070089797
# expected=24.0, predicted=30.85873990958393
# expected=27.0, predicted=26.792414362778413
# expected=36.0, predicted=27.46101154153343
# expected=19.0, predicted=37.606197840084626
# expected=33.0, predicted=25.861829216985683
# expected=25.0, predicted=38.39015639910555
# expected=31.0, predicted=26.843108852534456
# expected=21.0, predicted=29.627500465272874
# expected=25.0, predicted=26.07957471158368
# expected=38.0, predicted=26.704495240839123
# expected=17.0, predicted=39.217814394739285
# expected=20.0, predicted=25.03991377790341
# expected=27.0, predicted=24.705841687136036
# expected=24.0, predicted=26.203677161096937
# expected=11.0, predicted=25.921994308025432
# expected=22.0, predicted=21.843290758930124
# expected=22.0, predicted=24.74828317953628
# expected=28.0, predicted=24.37501607497815
# expected=39.0, predicted=25.311936732347185
# expected=17.0, predicted=34.81860179473834
# expected=11.0, predicted=24.41666881616972
# expected=23.0, predicted=20.788805583769282
# expected=38.0, predicted=29.477839381139948
# expected=38.0, predicted=43.009191025057326
# expected=28.0, predicted=36.6876979726917
# expected=12.0, predicted=25.315871986587766
# expected=21.0, predicted=22.14461523730461

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 14.803098081725551
# RMSE: 20.059151096398644
# MAPE: 84.71545081667888

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(train_index, [x[-1] for x in train], color='black', label='Train')
plt.plot(test_index, y, color='blue', label='Test')
plt.plot(test_index, yhat, color='magenta', label='Predict')
plt.plot(forecast_index, forecast, color='cyan', label='Predict 90 days')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 9:1')
plt.show()

# %%
plt.figure(figsize=(14, 7))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['orange', 'green', 'red']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hạ Long - 9:1')
plt.show()
