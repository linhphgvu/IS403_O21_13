# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'hanoi_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.9

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_2348\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=132.0, predicted=130.11798333333337
# expected=132.0, predicted=122.05183302351244
# expected=126.6, predicted=119.00587050264558
# expected=153.2, predicted=121.17416570210835
# expected=147.8, predicted=150.4675237429237
# expected=150.2, predicted=144.1768761904763
# expected=157.6, predicted=147.61825992785
# expected=164.0, predicted=152.50438780108792
# expected=149.6, predicted=157.79406311858077
# expected=138.2, predicted=149.94006666666675
# expected=126.8, predicted=124.79878513708519
# expected=103.2, predicted=118.60730498716967
# expected=91.2, predicted=97.81578640948425
# expected=100.0, predicted=82.92690622205316
# expected=103.2, predicted=102.39109829637165
# expected=108.4, predicted=106.15645562936639
# expected=122.8, predicted=110.19711944798959
# expected=116.2, predicted=127.66232622920937
# expected=112.0, predicted=110.12631001999299
# expected=108.6, predicted=107.40252108112045
# expected=97.8, predicted=106.12263679221495
# expected=87.0, predicted=95.00966483915376
# expected=86.2, predicted=80.58869946260691
# expected=83.2, predicted=87.4334269646825
# expected=71.8, predicted=81.13673869421376
# expected=78.6, predicted=69.2217343455015
# expected=72.6, predicted=81.96959579480587
# expected=69.0, predicted=73.81500683096417
# expected=74.4, predicted=68.73724058921296
# expected=85.0, predicted=78.06366686172645
# expected=89.2, predicted=82.34989786964847
# expected=109.2, predicted=100.34305565835582
# expected=111.6, predicted=115.00240776190775
# expected=106.8, predicted=115.91472631147087
# expected=92.0, predicted=105.31457213946186
# expected=80.6, predicted=86.76474722452075
# expected=85.6, predicted=70.06765301298
# expected=110.2, predicted=82.58468369307906
# expected=118.6, predicted=114.38059527951386
# expected=141.8, predicted=123.36939130036627
# expected=146.0, predicted=138.37525590781766
# expected=123.6, predicted=145.8373214319994
# expected=109.6, predicted=120.670241069633
# expected=116.4, predicted=96.5727427298192
# expected=109.6, predicted=111.85675036901253
# expected=109.0, predicted=109.45612441733167
# expected=113.0, predicted=105.03479763445182
# expected=105.0, predicted=113.63781169189431
# expected=91.2, predicted=100.48571874375777
# expected=80.2, predicted=87.85130530814364
# expected=67.4, predicted=69.35136207793545
# expected=65.8, predicted=65.32628057652248
# expected=72.6, predicted=66.65242038768505
# expected=77.6, predicted=80.84863828229567
# expected=87.4, predicted=82.56265810055143
# expected=103.6, predicted=92.25310476731535
# expected=98.4, predicted=109.31261530018975
# expected=96.8, predicted=96.91508788063318
# expected=79.8, predicted=99.13543083158734
# expected=73.6, predicted=69.78518303498954
# expected=71.8, predicted=69.05664230151724
# expected=83.2, predicted=70.71046407006506
# expected=75.4, predicted=86.87556904993227
# expected=88.8, predicted=75.10723242589252
# expected=98.2, predicted=94.2813387559702
# expected=100.0, predicted=102.01844483449368
# expected=95.2, predicted=98.66796102244162
# expected=104.8, predicted=88.70538036098989
# expected=118.8, predicted=108.40359871408002
# expected=130.6, predicted=127.35683830613829
# expected=142.2, predicted=129.79417302279413
# expected=153.4, predicted=141.13589021720026
# expected=142.8, predicted=153.53373016297422
# expected=122.8, predicted=140.41148159242198
# expected=101.0, predicted=116.50595549213429
# expected=82.8, predicted=95.50030838298647
# expected=69.0, predicted=73.71835363894276
# expected=68.0, predicted=67.23921411122078
# expected=69.0, predicted=66.43353802398642
# expected=84.2, predicted=71.35662281175556
# expected=86.6, predicted=89.25588537058943
# expected=94.0, predicted=87.62408324370136
# expected=94.8, predicted=98.47402865582697
# expected=93.6, predicted=91.46521814590069
# expected=81.6, predicted=90.94963999761971
# expected=87.0, predicted=71.87794639834647
# expected=82.2, predicted=89.0573927163131
# expected=83.2, predicted=80.04526624814928
# expected=82.8, predicted=80.86826311432418
# expected=81.4, predicted=80.5143703179569
# expected=73.4, predicted=79.34473225747442
# expected=69.6, predicted=71.74543279728194
# expected=75.2, predicted=70.38712282191055
# expected=71.4, predicted=79.70713009904561
# expected=64.0, predicted=72.7391387951588
# expected=60.8, predicted=65.65603044672234
# expected=56.2, predicted=61.96385961396109
# expected=54.2, predicted=58.49107825852849
# expected=57.6, predicted=57.24262780493109
# expected=59.2, predicted=61.76765217518599
# expected=63.6, predicted=63.53707241454084
# expected=79.6, predicted=67.81303331819434
# expected=91.4, predicted=92.68286745719266
# expected=119.8, predicted=104.19164617275308
# expected=144.0, predicted=128.66918426252113
# expected=153.4, predicted=146.76959083512273
# expected=162.0, predicted=148.55652359307354
# expected=163.8, predicted=157.41374783549784
# expected=137.4, predicted=157.20540448717935
# expected=118.8, predicted=131.94567023809523
# expected=122.2, predicted=113.86208239909233
# expected=111.8, predicted=119.29804458925013
# expected=97.6, predicted=103.50583957708957
# expected=106.4, predicted=90.03995347959712
# expected=106.2, predicted=110.11874894949987
# expected=92.6, predicted=105.1282263235223
# expected=82.6, predicted=87.4709964421691
# expected=79.0, predicted=74.98627679641187
# expected=74.8, predicted=74.30006678090683
# expected=86.2, predicted=73.24919379302227
# expected=92.6, predicted=92.09781194919691
# expected=94.2, predicted=102.37230554812983
# expected=95.6, predicted=91.03739528910762
# expected=92.4, predicted=93.082770048266
# expected=81.0, predicted=84.24293780530384
# expected=77.2, predicted=76.27395769684959
# expected=79.8, predicted=73.03505792290088
# expected=86.2, predicted=77.80794612797924
# expected=92.4, predicted=88.05047859755658
# expected=99.6, predicted=96.23950692965283
# expected=104.6, predicted=98.26717269003075
# expected=107.4, predicted=109.39071474525946
# expected=109.0, predicted=102.74046921786942
# expected=108.4, predicted=105.76213406156111
# expected=100.4, predicted=104.23996668140552
# expected=89.4, predicted=93.98214732412642
# expected=81.8, predicted=86.98903085660159
# expected=68.4, predicted=78.62473289946718
# expected=64.2, predicted=67.72312207426377
# expected=70.2, predicted=65.49501437489086
# expected=74.8, predicted=72.81646587726878
# expected=76.2, predicted=79.58099119222292
# expected=78.2, predicted=80.3382335826014
# expected=75.2, predicted=79.07226210505846
# expected=60.2, predicted=76.75626379089071
# expected=75.4, predicted=60.65325857362655
# expected=66.2, predicted=82.58857617559617
# expected=61.6, predicted=65.43917266803606
# expected=68.0, predicted=64.47612977347754
# expected=86.4, predicted=70.58086613123179
# expected=67.8, predicted=91.75209008321112
# expected=77.0, predicted=66.83223719234549
# expected=71.0, predicted=81.99645724647463
# expected=79.0, predicted=70.55137019546798
# expected=76.8, predicted=76.13101950711228
# expected=85.8, predicted=74.08141919506805
# expected=95.4, predicted=83.58647686277227
# expected=101.8, predicted=99.44281491074813
# expected=97.2, predicted=98.50234076615268
# expected=90.4, predicted=94.90399766920629
# expected=75.8, predicted=86.0016405085152
# expected=55.4, predicted=65.7923783536592
# expected=61.0, predicted=51.15292421924489
# expected=66.0, predicted=63.99067960823131
# expected=56.2, predicted=69.29363221975386
# expected=69.2, predicted=56.24339866727814
# expected=83.4, predicted=76.49381899748933
# expected=84.0, predicted=85.24699760819374
# expected=67.0, predicted=81.78230678824666
# expected=78.2, predicted=65.90292788870684
# expected=68.8, predicted=79.5117438510155
# expected=61.8, predicted=69.96025171540705
# expected=57.8, predicted=62.73091304334295
# expected=63.6, predicted=57.83754830063509
# expected=60.0, predicted=65.5688402627654
# expected=66.0, predicted=61.14191665235092
# expected=71.2, predicted=66.7595095701003
# expected=71.8, predicted=75.15411162931701
# expected=64.8, predicted=74.82460141489959
# expected=65.2, predicted=65.73444424419226
# expected=65.6, predicted=66.76911102692833
# expected=67.4, predicted=64.67978840158786
# expected=76.2, predicted=65.90174652119224
# expected=86.6, predicted=80.10613648138397
# expected=82.0, predicted=87.8925330435202
# expected=69.8, predicted=76.78653374718535
# expected=63.8, predicted=69.12307144224332
# expected=62.4, predicted=63.61836039023329
# expected=54.2, predicted=58.88352150445729
# expected=55.8, predicted=53.90413296818168
# expected=59.4, predicted=58.41486309482498
# expected=67.2, predicted=61.84988561446549

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 7.512872890129887
# RMSE: 9.346264537330393
# MAPE: 8.393195700657447
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
# forecast_series = pd.Series(forecast)
# forecast_smoothed = smoothed(forecast_series)
# forecast_smoothed = forecast_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_2348\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 9:1')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 9:1')
plt.show()
