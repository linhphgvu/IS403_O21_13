# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=1, out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(data, test_n):
    predictions = []
    train, test = train_test_split(data, test_n)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'hanoi_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series.values, In=6)

# %%
# Split the data
train_size = int(len(data) * 0.9)
train, test = train_test_split(data, len(data) - train_size)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(data, len(test))
# Out:
# expected=152.0, predicted=165.16333333333333
# expected=150.0, predicted=84.21482324729968
# expected=140.0, predicted=76.25701879798186
# expected=137.0, predicted=112.80597991301785
# expected=160.0, predicted=147.82244009553287
# expected=164.0, predicted=159.78186456625835
# expected=187.0, predicted=160.33297135374931
# expected=172.0, predicted=165.80339652730308
# expected=65.0, predicted=141.42518828021676
# expected=103.0, predicted=110.68765613388997
# expected=107.0, predicted=98.68443988391795
# expected=69.0, predicted=93.29689210523604
# expected=112.0, predicted=82.31920439241854
# expected=109.0, predicted=107.01757056833536
# expected=119.0, predicted=92.40351874218305
# expected=133.0, predicted=100.35237075576092
# expected=141.0, predicted=118.88621766556088
# expected=79.0, predicted=135.6591891311082
# expected=88.0, predicted=80.57221200237879
# expected=102.0, predicted=94.44905512042546
# expected=79.0, predicted=91.03005175566511
# expected=87.0, predicted=79.0720356330723
# expected=75.0, predicted=94.64518320665273
# expected=73.0, predicted=78.32099095637479
# expected=45.0, predicted=82.19426616756931
# expected=113.0, predicted=60.74318520908754
# expected=57.0, predicted=98.66711368738271
# expected=57.0, predicted=62.2204855927505
# expected=100.0, predicted=58.91398715809898
# expected=98.0, predicted=83.16178214549589
# expected=134.0, predicted=75.10471442097099
# expected=157.0, predicted=116.8922485393882
# expected=69.0, predicted=134.78859234162152
# expected=76.0, predicted=75.80565979314353
# expected=24.0, predicted=84.50132915183518
# expected=77.0, predicted=56.2401844085206
# expected=182.0, predicted=80.562120433843
# expected=192.0, predicted=131.19955555555555
# expected=118.0, predicted=130.00738095238094
# expected=140.0, predicted=74.4073627950092
# expected=98.0, predicted=143.86474426699428
# expected=70.0, predicted=82.94479052482524
# expected=122.0, predicted=87.51379913065043
# expected=152.0, predicted=114.77631891822458
# expected=106.0, predicted=127.99957760693438
# expected=95.0, predicted=91.19764285157457
# expected=90.0, predicted=82.23393966349403
# expected=82.0, predicted=88.10756374763112
# expected=83.0, predicted=86.29209185528583
# expected=51.0, predicted=88.34422996898824
# expected=31.0, predicted=62.20515750633614
# expected=82.0, predicted=52.36785384682717
# expected=116.0, predicted=78.0216267757222
# expected=108.0, predicted=87.6215348090301
# expected=100.0, predicted=83.24625580401654
# expected=112.0, predicted=86.87283416226943
# expected=56.0, predicted=92.58681770584357
# expected=108.0, predicted=53.0713085607348
# expected=23.0, predicted=106.38447441321959
# expected=69.0, predicted=42.00196054854196
# expected=103.0, predicted=85.72613497146249
# expected=113.0, predicted=88.65063535298414
# expected=69.0, predicted=82.64059009563644
# expected=90.0, predicted=77.43464372094853
# expected=116.0, predicted=79.33199045081481
# expected=112.0, predicted=106.86941865910408
# expected=89.0, predicted=99.7448546161535
# expected=117.0, predicted=81.23635097741163
# expected=160.0, predicted=101.30082228378133
# expected=175.0, predicted=152.69704186598204
# expected=170.0, predicted=157.77777310730193
# expected=145.0, predicted=120.52775708369188
# expected=64.0, predicted=116.50898350667104
# expected=60.0, predicted=106.65904355575678
# expected=66.0, predicted=80.97407049175919
# expected=79.0, predicted=81.448954683098
# expected=76.0, predicted=87.27252094454948
# expected=59.0, predicted=77.1502533264192
# expected=65.0, predicted=61.84259180574841
# expected=142.0, predicted=64.1324568861252
# expected=91.0, predicted=135.92705772582084
# expected=113.0, predicted=75.62992145666621
# expected=63.0, predicted=94.53754218559305
# expected=59.0, predicted=66.68596939925554
# expected=82.0, predicted=71.31224263576088
# expected=118.0, predicted=80.89790062071374
# expected=89.0, predicted=103.58841876162211
# expected=68.0, predicted=80.7645284203143
# expected=57.0, predicted=68.47612764753933
# expected=75.0, predicted=64.37664821149536
# expected=78.0, predicted=73.07008273934646
# expected=70.0, predicted=77.05152581267666
# expected=96.0, predicted=69.20377081446873
# expected=38.0, predicted=92.70585266115918
# expected=38.0, predicted=33.99430536847752
# expected=62.0, predicted=45.305416856018844
# expected=47.0, predicted=66.20261199442365
# expected=86.0, predicted=46.58000969028075
# expected=55.0, predicted=87.40562281128497
# expected=46.0, predicted=56.26739795498364
# expected=84.0, predicted=52.01086197685592
# expected=127.0, predicted=75.02662193872726
# expected=145.0, predicted=136.98724663760825
# expected=197.0, predicted=119.44675626283218
# expected=167.0, predicted=165.63109090909091
# expected=131.0, predicted=138.41714364418908
# expected=170.0, predicted=106.19757389686815
# expected=154.0, predicted=128.10554680523987
# expected=65.0, predicted=128.240592830001
# expected=74.0, predicted=92.24441972336218
# expected=148.0, predicted=82.2533097838989
# expected=118.0, predicted=124.61489283897937
# expected=83.0, predicted=101.12140825617006
# expected=109.0, predicted=91.66876821650372
# expected=73.0, predicted=82.72190682788334
# expected=80.0, predicted=86.0658456458328
# expected=68.0, predicted=81.08494204318467
# expected=65.0, predicted=75.86607881687371
# expected=88.0, predicted=78.286500757403
# expected=130.0, predicted=85.70698121478597
# expected=112.0, predicted=123.37878294340337
# expected=76.0, predicted=84.32307380951111
# expected=72.0, predicted=77.11896750104387
# expected=72.0, predicted=73.5980776517022
# expected=73.0, predicted=84.41055797127339
# expected=93.0, predicted=77.30921546217874
# expected=89.0, predicted=87.31882949094943
# expected=104.0, predicted=81.68817532764194
# expected=103.0, predicted=84.55840722057829
# expected=109.0, predicted=87.68979905592848
# expected=118.0, predicted=89.26810517422805
# expected=103.0, predicted=106.78853505571787
# expected=112.0, predicted=87.01652999523911
# expected=100.0, predicted=93.70386441305834
# expected=69.0, predicted=84.12102706836238
# expected=63.0, predicted=74.5216624346411
# expected=65.0, predicted=63.845601011645876
# expected=45.0, predicted=69.85273695428764
# expected=79.0, predicted=61.37969017513856
# expected=99.0, predicted=82.87330467296901
# expected=86.0, predicted=86.37756087447964
# expected=72.0, predicted=78.1639280007255
# expected=55.0, predicted=71.47179759709331
# expected=64.0, predicted=66.74412944645226
# expected=24.0, predicted=68.51733454549269
# expected=162.0, predicted=51.74296737806273
# expected=26.0, predicted=149.07275737255014
# expected=32.0, predicted=65.38915502112401
# expected=96.0, predicted=68.52928218510023
# expected=116.0, predicted=72.31228860679845
# expected=69.0, predicted=87.52197570758455
# expected=72.0, predicted=79.1556776539852
# expected=2.0, predicted=73.58966728226282
# expected=136.0, predicted=49.373280681799876
# expected=105.0, predicted=78.24585636427108
# expected=114.0, predicted=76.79304104088952
# expected=120.0, predicted=62.27978744411027
# expected=34.0, predicted=77.80270560790366
# expected=113.0, predicted=42.12874432901328
# expected=71.0, predicted=91.40428482166259
# expected=41.0, predicted=72.43381442189995
# expected=18.0, predicted=62.340014319682126
# expected=62.0, predicted=51.65450710921625
# expected=138.0, predicted=51.480458493717876
# expected=22.0, predicted=98.84848616421513
# expected=106.0, predicted=41.91686397273459
# expected=89.0, predicted=52.454336520222114
# expected=65.0, predicted=76.47585995908526
# expected=53.0, predicted=63.78341650160038
# expected=78.0, predicted=62.6171944600684
# expected=59.0, predicted=69.99877456015139
# expected=54.0, predicted=68.29625791270337
# expected=45.0, predicted=66.04681349585522
# expected=82.0, predicted=47.41182844200086
# expected=60.0, predicted=87.04433424302388
# expected=89.0, predicted=60.68726503774714
# expected=80.0, predicted=85.33011669760468
# expected=48.0, predicted=74.98430152905327
# expected=47.0, predicted=58.60662283353317
# expected=62.0, predicted=65.2800372583174
# expected=91.0, predicted=65.39839661741713
# expected=89.0, predicted=92.02607964645838
# expected=92.0, predicted=73.94150437683459
# expected=99.0, predicted=90.04100834034662
# expected=39.0, predicted=87.11529728845677
# expected=30.0, predicted=35.92132812154261
# expected=59.0, predicted=49.94724997991887
# expected=85.0, predicted=69.44836273414819
# expected=58.0, predicted=89.99310988210138
# expected=47.0, predicted=59.29433717836781
# expected=48.0, predicted=49.53917051872115
# expected=98.0, predicted=54.56377203723904

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 27.144995513343193
# RMSE: 35.7364502163971
# MAPE: 56.74132979530714

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(train_index, [x[-1] for x in train], color='black', label='Train')
plt.plot(test_index, y, color='blue', label='Test')
plt.plot(test_index, yhat, color='magenta', label='Predict')
plt.plot(forecast_index, forecast, color='cyan', label='Predict 90 days')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 9:1')
plt.show()

# %%
plt.figure(figsize=(14, 7))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['orange', 'green', 'red']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 9:1')
plt.show()
