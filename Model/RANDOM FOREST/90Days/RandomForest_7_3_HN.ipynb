# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=1, out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(data, test_n):
    predictions = []
    train, test = train_test_split(data, test_n)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'hanoi_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series.values, In=6)

# %%
# Split the data
train_size = int(len(data) * 0.7)
train, test = train_test_split(data, len(data) - train_size)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(data, len(test))
# Out:
# expected=8.0, predicted=28.802217245575648
# expected=9.0, predicted=23.960155105554005
# expected=43.0, predicted=29.869104475786074
# expected=101.0, predicted=55.005745169376745
# expected=92.0, predicted=80.41742646945002
# expected=77.0, predicted=81.52964501192263
# expected=66.0, predicted=74.37353109238084
# expected=44.0, predicted=67.31827538204146
# expected=60.0, predicted=48.84077213159396
# expected=53.0, predicted=71.43142088534012
# expected=47.0, predicted=59.18151109714085
# expected=34.0, predicted=46.28087157184733
# expected=25.0, predicted=38.52582699735196
# expected=29.0, predicted=34.746753953349504
# expected=33.0, predicted=39.598002308197394
# expected=42.0, predicted=35.68443391649691
# expected=67.0, predicted=41.81044593025133
# expected=73.0, predicted=61.03448021466924
# expected=62.0, predicted=62.06889043218825
# expected=38.0, predicted=59.276694159183734
# expected=40.0, predicted=40.49722495252051
# expected=45.0, predicted=47.2431995757621
# expected=26.0, predicted=46.30413792591785
# expected=21.0, predicted=32.71017787843748
# expected=28.0, predicted=29.96973907851627
# expected=19.0, predicted=29.434744185573944
# expected=3.0, predicted=28.847904648333774
# expected=22.0, predicted=29.613474569596523
# expected=38.0, predicted=36.06118422422913
# expected=30.0, predicted=33.95283312161648
# expected=20.0, predicted=32.88672167304846
# expected=58.0, predicted=31.161230335642095
# expected=71.0, predicted=60.831769576679044
# expected=50.0, predicted=64.04557723658829
# expected=49.0, predicted=46.427736081318216
# expected=43.0, predicted=49.006572414472586
# expected=57.0, predicted=41.467004612474
# expected=64.0, predicted=60.38371426424828
# expected=56.0, predicted=59.75623283424817
# expected=53.0, predicted=49.08179056110426
# expected=59.0, predicted=52.47348559188003
# expected=72.0, predicted=56.28219655219098
# expected=31.0, predicted=68.19954108277716
# expected=21.0, predicted=47.87208465137149
# expected=52.0, predicted=41.677753387621244
# expected=70.0, predicted=54.60360043513704
# expected=49.0, predicted=68.408329582501
# expected=71.0, predicted=46.247750537596765
# expected=49.0, predicted=61.79962674018146
# expected=39.0, predicted=50.5133520956855
# expected=36.0, predicted=42.60313824897941
# expected=23.0, predicted=38.04633788099806
# expected=19.0, predicted=32.4050586208045
# expected=20.0, predicted=30.34585619015818
# expected=53.0, predicted=21.899698621002972
# expected=94.0, predicted=48.55004230764722
# expected=129.0, predicted=78.5936357311614
# expected=144.0, predicted=102.00963235247454
# expected=164.0, predicted=128.88347033672034
# expected=123.0, predicted=147.66023488482622
# expected=173.0, predicted=84.05818333103085
# expected=153.0, predicted=141.80375899652375
# expected=97.0, predicted=145.89231334218755
# expected=137.0, predicted=67.15523821801432
# expected=197.0, predicted=112.4348435262994
# expected=195.0, predicted=152.74155095270226
# expected=178.0, predicted=157.01533333333336
# expected=148.0, predicted=155.36947408963587
# expected=98.0, predicted=123.4125867667357
# expected=108.0, predicted=92.11040639786033
# expected=136.0, predicted=87.27457289843129
# expected=107.0, predicted=127.78059254469703
# expected=50.0, predicted=92.88141062814124
# expected=102.0, predicted=60.92746771325565
# expected=108.0, predicted=96.49074596066735
# expected=160.0, predicted=80.51999413815676
# expected=177.0, predicted=148.53645038777648
# expected=197.0, predicted=155.12759118116185
# expected=207.0, predicted=144.4258975191475
# expected=151.0, predicted=154.97193434343433
# expected=68.0, predicted=125.21980252100839
# expected=112.0, predicted=103.70457723058358
# expected=143.0, predicted=97.03939649716713
# expected=127.0, predicted=106.6217178362573
# expected=107.0, predicted=104.67629420251937
# expected=150.0, predicted=77.08718555918271
# expected=187.0, predicted=136.00853205023105
# expected=155.0, predicted=172.95163408521302
# expected=136.0, predicted=138.7360566684949
# expected=107.0, predicted=110.54463395999424
# expected=83.0, predicted=93.21584654684962
# expected=78.0, predicted=86.97675275797596
# expected=120.0, predicted=79.40469610110725
# expected=105.0, predicted=110.26006057139071
# expected=72.0, predicted=84.81052152625334
# expected=121.0, predicted=75.27968217392795
# expected=57.0, predicted=107.6152367253047
# expected=57.0, predicted=58.01150649774228
# expected=52.0, predicted=72.7325683901677
# expected=68.0, predicted=63.61952707607196
# expected=88.0, predicted=64.10799959363241
# expected=71.0, predicted=88.13405193500903
# expected=100.0, predicted=59.39114959369866
# expected=130.0, predicted=91.19871792843321
# expected=179.0, predicted=123.80298108746149
# expected=129.0, predicted=164.0877179171616
# expected=145.0, predicted=104.35342529804983
# expected=121.0, predicted=133.0067238664042
# expected=149.0, predicted=86.54678091743621
# expected=99.0, predicted=146.49499041258977
# expected=99.0, predicted=91.1510419003589
# expected=47.0, predicted=86.22925715788186
# expected=70.0, predicted=51.22050058332889
# expected=123.0, predicted=76.14938693175051
# expected=159.0, predicted=106.9053401167709
# expected=151.0, predicted=149.7823851152965
# expected=123.0, predicted=127.77971083727215
# expected=183.0, predicted=118.50283662098263
# expected=172.0, predicted=169.34198584643013
# expected=128.0, predicted=140.69243287088776
# expected=167.0, predicted=120.0385545838825
# expected=143.0, predicted=155.30723810294273
# expected=98.0, predicted=119.25683264057625
# expected=88.0, predicted=92.91145177938559
# expected=148.0, predicted=93.05282852938917
# expected=133.0, predicted=128.63168491473368
# expected=104.0, predicted=106.26627828567547
# expected=122.0, predicted=89.79446752829503
# expected=67.0, predicted=121.74400045892851
# expected=118.0, predicted=89.54888434155953
# expected=136.0, predicted=114.5085222387385
# expected=76.0, predicted=128.82458123474487
# expected=65.0, predicted=86.15320560994472
# expected=64.0, predicted=84.19595933472229
# expected=60.0, predicted=72.18406763646679
# expected=66.0, predicted=64.59095296910847
# expected=87.0, predicted=72.30858736444736
# expected=132.0, predicted=87.26904867662378
# expected=117.0, predicted=123.59186169063032
# expected=120.0, predicted=107.5509710288626
# expected=90.0, predicted=90.19579683417533
# expected=56.0, predicted=88.59321140223004
# expected=54.0, predicted=61.606306142607124
# expected=67.0, predicted=57.80163216821218
# expected=69.0, predicted=80.3530913293518
# expected=79.0, predicted=76.17142609472572
# expected=135.0, predicted=84.31242113527591
# expected=104.0, predicted=121.129315047168
# expected=69.0, predicted=100.7117014069293
# expected=72.0, predicted=82.7538900711912
# expected=95.0, predicted=86.78511734354855
# expected=121.0, predicted=92.73171855001853
# expected=105.0, predicted=115.89633944043494
# expected=91.0, predicted=88.95611501956385
# expected=103.0, predicted=78.26466179498155
# expected=108.0, predicted=81.04382638754522
# expected=99.0, predicted=95.8439050687928
# expected=101.0, predicted=80.84562551363732
# expected=94.0, predicted=87.84593306745305
# expected=61.0, predicted=88.65015875515053
# expected=71.0, predicted=61.54875525776954
# expected=105.0, predicted=86.37802793315066
# expected=99.0, predicted=97.41329291531433
# expected=100.0, predicted=91.20300789105137
# expected=84.0, predicted=93.30196198101119
# expected=122.0, predicted=88.04377030602535
# expected=127.0, predicted=107.41897851898246
# expected=130.0, predicted=113.4167619558532
# expected=109.0, predicted=122.73156751130051
# expected=83.0, predicted=88.42962253827115
# expected=72.0, predicted=82.7734748637326
# expected=42.0, predicted=90.16156524653836
# expected=68.0, predicted=55.74993837920959
# expected=96.0, predicted=79.07022998444448
# expected=58.0, predicted=92.14922443805641
# expected=41.0, predicted=57.20035945858146
# expected=53.0, predicted=46.42308757531172
# expected=100.0, predicted=61.02208775927109
# expected=70.0, predicted=87.52913656080709
# expected=45.0, predicted=72.75874251617483
# expected=60.0, predicted=45.11653138805446
# expected=77.0, predicted=59.68932064355125
# expected=99.0, predicted=79.35658643253248
# expected=90.0, predicted=87.10360429260606
# expected=51.0, predicted=84.35261342488465
# expected=83.0, predicted=58.90831057575974
# expected=74.0, predicted=93.32420410561352
# expected=40.0, predicted=75.78648604818302
# expected=41.0, predicted=64.05035132196038
# expected=35.0, predicted=51.126669939057244
# expected=56.0, predicted=38.71991700300397
# expected=67.0, predicted=50.1589724039446
# expected=65.0, predicted=63.722550625584326
# expected=103.0, predicted=56.99539150869029
# expected=122.0, predicted=93.8217625785716
# expected=96.0, predicted=124.11951803211345
# expected=104.0, predicted=82.93269705974384
# expected=92.0, predicted=85.79574904846783
# expected=95.0, predicted=89.02941889022597
# expected=91.0, predicted=87.40879949744121
# expected=90.0, predicted=85.64690520244604
# expected=59.0, predicted=88.89288678823264
# expected=56.0, predicted=60.55854129665022
# expected=49.0, predicted=61.84099871454311
# expected=46.0, predicted=54.68531363800491
# expected=62.0, predicted=51.56933893520124
# expected=69.0, predicted=74.20409997293301
# expected=86.0, predicted=63.57666107746575
# expected=95.0, predicted=83.8010235512721
# expected=82.0, predicted=91.35426123988289
# expected=72.0, predicted=87.18481069696253
# expected=75.0, predicted=81.53198001234229
# expected=83.0, predicted=78.84002953481199
# expected=77.0, predicted=85.99933895804465
# expected=75.0, predicted=75.67882007437753
# expected=114.0, predicted=80.06090882988389
# expected=47.0, predicted=101.71561717678014
# expected=89.0, predicted=50.517796244064876
# expected=115.0, predicted=93.83008145969467
# expected=101.0, predicted=93.77550312248312
# expected=78.0, predicted=76.10133962554819
# expected=42.0, predicted=70.27013801983767
# expected=51.0, predicted=65.5397322561323
# expected=58.0, predicted=57.350191704264915
# expected=47.0, predicted=63.3346224807239
# expected=41.0, predicted=51.22018054098763
# expected=54.0, predicted=42.119627814219115
# expected=66.0, predicted=55.0545720560613
# expected=62.0, predicted=64.41118724853922
# expected=78.0, predicted=59.44045398418598
# expected=49.0, predicted=74.08117750835619
# expected=45.0, predicted=50.37195431292977
# expected=25.0, predicted=46.26714923943664
# expected=60.0, predicted=31.58632470473416
# expected=57.0, predicted=59.05478254473388
# expected=36.0, predicted=47.92946229040176
# expected=41.0, predicted=41.974264705828766
# expected=50.0, predicted=45.72796185805003
# expected=61.0, predicted=52.99630340147025
# expected=56.0, predicted=54.650739482015695
# expected=64.0, predicted=52.20689137352733
# expected=57.0, predicted=59.46425224192802
# expected=51.0, predicted=54.95471445830042
# expected=41.0, predicted=56.38767336572364
# expected=34.0, predicted=42.648219133979865
# expected=35.0, predicted=38.7764939216319
# expected=30.0, predicted=40.18191753548996
# expected=46.0, predicted=35.80285583311933
# expected=48.0, predicted=48.18848800642714
# expected=42.0, predicted=44.8713943090948
# expected=56.0, predicted=41.01962357000164
# expected=52.0, predicted=50.58078812668404
# expected=68.0, predicted=49.12938301489441
# expected=79.0, predicted=58.50421717941272
# expected=105.0, predicted=78.9473002134045
# expected=82.0, predicted=98.26999691399696
# expected=60.0, predicted=84.0135268790954
# expected=81.0, predicted=63.05688195499498
# expected=74.0, predicted=87.4593023611686
# expected=48.0, predicted=77.19011421636068
# expected=33.0, predicted=51.862518481290465
# expected=42.0, predicted=40.99744386099112
# expected=39.0, predicted=48.0018310182079
# expected=55.0, predicted=40.61980181407526
# expected=76.0, predicted=48.241238187071495
# expected=64.0, predicted=65.48547608701938
# expected=77.0, predicted=59.1556965408039
# expected=71.0, predicted=65.40033429899117
# expected=60.0, predicted=68.28441703585182
# expected=55.0, predicted=65.66202492160998
# expected=67.0, predicted=57.97459093502055
# expected=58.0, predicted=73.41905733990743
# expected=43.0, predicted=61.0268381033696
# expected=52.0, predicted=42.53862591537117
# expected=43.0, predicted=59.37723889721166
# expected=50.0, predicted=43.99724801623259
# expected=53.0, predicted=51.76864889137401
# expected=68.0, predicted=55.01192136371901
# expected=76.0, predicted=61.306907798420234
# expected=94.0, predicted=67.31297756835437
# expected=73.0, predicted=83.87592940506309
# expected=75.0, predicted=70.02869629800081
# expected=54.0, predicted=84.06268522606999
# expected=58.0, predicted=63.08659184289546
# expected=80.0, predicted=61.634603714047735
# expected=86.0, predicted=85.06297892897317
# expected=63.0, predicted=81.71389979204945
# expected=92.0, predicted=64.61815612291991
# expected=57.0, predicted=99.23304037443545
# expected=67.0, predicted=64.50037309039354
# expected=63.0, predicted=78.51240136975451
# expected=70.0, predicted=86.5259590101808
# expected=59.0, predicted=63.598406914345276
# expected=79.0, predicted=61.3383049055513
# expected=50.0, predicted=84.49098008722642
# expected=71.0, predicted=55.25897493436385
# expected=45.0, predicted=70.07845026129318
# expected=62.0, predicted=49.116326350323305
# expected=53.0, predicted=63.40975224589167
# expected=88.0, predicted=52.714774475870335
# expected=104.0, predicted=86.40929466088318
# expected=104.0, predicted=88.56449702583313
# expected=81.0, predicted=89.8324990191798
# expected=37.0, predicted=79.07870301968582
# expected=57.0, predicted=46.82154920219231
# expected=98.0, predicted=63.05415586856276
# expected=92.0, predicted=88.79666876620811
# expected=59.0, predicted=80.72371898842827
# expected=70.0, predicted=63.538826388107545
# expected=98.0, predicted=69.42965825798022
# expected=90.0, predicted=90.21772109285426
# expected=93.0, predicted=76.46717182594872
# expected=43.0, predicted=85.39544568190715
# expected=31.0, predicted=58.69610834961759
# expected=51.0, predicted=43.81553953628648
# expected=77.0, predicted=61.01407227193206
# expected=78.0, predicted=82.84926501209685
# expected=65.0, predicted=75.37529955354489
# expected=50.0, predicted=61.720309203981536
# expected=31.0, predicted=53.61821976998074
# expected=35.0, predicted=41.02990211448596
# expected=35.0, predicted=36.73532393728808
# expected=37.0, predicted=38.08932841057817
# expected=58.0, predicted=38.95307237744699
# expected=86.0, predicted=57.402328566601085
# expected=77.0, predicted=88.38506095115865
# expected=34.0, predicted=68.51054657392116
# expected=43.0, predicted=39.40855112420141
# expected=81.0, predicted=47.48650117545318
# expected=105.0, predicted=82.82258147044182
# expected=70.0, predicted=84.99050860944193
# expected=77.0, predicted=63.28842464636105
# expected=91.0, predicted=71.59370936700613
# expected=90.0, predicted=85.91228966136123
# expected=71.0, predicted=82.7347875585934
# expected=67.0, predicted=78.81742470095429
# expected=60.0, predicted=72.3825363013675
# expected=41.0, predicted=63.31224139581513
# expected=63.0, predicted=44.224266571838186
# expected=50.0, predicted=78.36380391659182
# expected=66.0, predicted=49.59983893247284
# expected=57.0, predicted=63.264298733357094
# expected=80.0, predicted=56.184697583402794
# expected=96.0, predicted=82.13665422059508
# expected=50.0, predicted=81.59504244579915
# expected=107.0, predicted=48.88250245391307
# expected=127.0, predicted=95.68265517922937
# expected=140.0, predicted=128.82242665813462
# expected=132.0, predicted=129.85121798444916
# expected=70.0, predicted=121.36465422987236
# expected=49.0, predicted=87.39201025979219
# expected=76.0, predicted=69.24815894799191
# expected=117.0, predicted=84.7826223663618
# expected=133.0, predicted=109.5156419377387
# expected=148.0, predicted=118.9402941407712
# expected=98.0, predicted=122.67289884577401
# expected=155.0, predicted=77.9609046224235
# expected=77.0, predicted=150.48502513509771
# expected=67.0, predicted=91.27487270615921
# expected=50.0, predicted=86.96163777285852
# expected=113.0, predicted=61.649182553542204
# expected=124.0, predicted=101.48586379073063
# expected=142.0, predicted=111.80018702095593
# expected=98.0, predicted=129.34218445701296
# expected=52.0, predicted=85.95008268259497
# expected=52.0, predicted=64.36688426433659
# expected=63.0, predicted=61.896319286167994
# expected=45.0, predicted=73.61867369002732
# expected=107.0, predicted=48.221237468460046
# expected=80.0, predicted=100.2917168309279
# expected=76.0, predicted=75.18061226728543
# expected=59.0, predicted=74.10769944062348
# expected=68.0, predicted=58.304672209118145
# expected=24.0, predicted=69.76591872254276
# expected=37.0, predicted=49.16090516951847
# expected=106.0, predicted=49.59557420742115
# expected=62.0, predicted=88.62184358369365
# expected=66.0, predicted=51.04135581954318
# expected=140.0, predicted=65.77375523400725
# expected=150.0, predicted=132.18464091462252
# expected=167.0, predicted=141.02746664786838
# expected=4.0, predicted=153.43450942476505
# expected=187.0, predicted=49.21266125541127
# expected=152.0, predicted=161.25038339920948
# expected=150.0, predicted=88.49790307207415
# expected=140.0, predicted=82.81464074884556
# expected=137.0, predicted=116.53145385885765
# expected=160.0, predicted=137.7530630602727
# expected=164.0, predicted=162.60352950461936
# expected=187.0, predicted=158.95690568197872
# expected=172.0, predicted=163.33970443285799
# expected=65.0, predicted=141.7853169214009
# expected=103.0, predicted=102.7976353664928
# expected=107.0, predicted=103.3565192492925
# expected=69.0, predicted=91.40453656439787
# expected=112.0, predicted=83.57652122349172
# expected=109.0, predicted=107.99244350775437
# expected=119.0, predicted=92.4032649401479
# expected=133.0, predicted=105.85882282659377
# expected=141.0, predicted=122.36938543590594
# expected=79.0, predicted=132.0384531163246
# expected=88.0, predicted=74.83141129190155
# expected=102.0, predicted=91.72800394906164
# expected=79.0, predicted=94.13191272945487
# expected=87.0, predicted=77.76417382764943
# expected=75.0, predicted=97.55140320946106
# expected=73.0, predicted=73.35068762745821
# expected=45.0, predicted=80.31644905349427
# expected=113.0, predicted=54.99664216996437
# expected=57.0, predicted=93.7475518087202
# expected=57.0, predicted=62.08437606854117
# expected=100.0, predicted=56.456393736770195
# expected=98.0, predicted=79.71548054258932
# expected=134.0, predicted=76.04999340312308
# expected=157.0, predicted=116.43253767617549
# expected=69.0, predicted=136.53677451629198
# expected=76.0, predicted=70.10656450428306
# expected=24.0, predicted=85.36101353890918
# expected=77.0, predicted=51.91173917419646
# expected=182.0, predicted=76.91265625033896
# expected=192.0, predicted=134.37623529411766
# expected=118.0, predicted=132.15416666666667
# expected=140.0, predicted=80.80286096374363
# expected=98.0, predicted=137.33248165654902
# expected=70.0, predicted=84.64246322583276
# expected=122.0, predicted=85.36633679221033
# expected=152.0, predicted=117.43873291882
# expected=106.0, predicted=133.54259105625403
# expected=95.0, predicted=85.1756800620746
# expected=90.0, predicted=83.80172791687828
# expected=82.0, predicted=91.79188535454671
# expected=83.0, predicted=81.13406052453132
# expected=51.0, predicted=84.5674983778672
# expected=31.0, predicted=63.485528766071276
# expected=82.0, predicted=50.73341465503765
# expected=116.0, predicted=68.58107769621573
# expected=108.0, predicted=93.08838840983857
# expected=100.0, predicted=72.40141588368053
# expected=112.0, predicted=83.30573174440654
# expected=56.0, predicted=93.79894547328173
# expected=108.0, predicted=54.56966672315586
# expected=23.0, predicted=99.45160288878357
# expected=69.0, predicted=46.19836261217782
# expected=103.0, predicted=90.36308449825316
# expected=113.0, predicted=85.42219777728509
# expected=69.0, predicted=78.35938948335034
# expected=90.0, predicted=83.66066438619556
# expected=116.0, predicted=77.44003998528733
# expected=112.0, predicted=105.2022487569998
# expected=89.0, predicted=94.87993491760889
# expected=117.0, predicted=78.93778528290868
# expected=160.0, predicted=104.59535844474703
# expected=175.0, predicted=154.7640416715177
# expected=170.0, predicted=158.56047929847932
# expected=145.0, predicted=122.65116256640167
# expected=64.0, predicted=118.2315663775438
# expected=60.0, predicted=104.4260694949787
# expected=66.0, predicted=81.09323600625471
# expected=79.0, predicted=83.50542227683363
# expected=76.0, predicted=83.0870167450892
# expected=59.0, predicted=76.10891334102752
# expected=65.0, predicted=63.84052126147328
# expected=142.0, predicted=65.0532399350579
# expected=91.0, predicted=132.6884899883793
# expected=113.0, predicted=80.91849067818592
# expected=63.0, predicted=83.28375674469434
# expected=59.0, predicted=61.83611580788375
# expected=82.0, predicted=66.90297075271576
# expected=118.0, predicted=78.66946269063837
# expected=89.0, predicted=102.09752713994818
# expected=68.0, predicted=84.71796952961483
# expected=57.0, predicted=72.40685648429002
# expected=75.0, predicted=61.87277623955228
# expected=78.0, predicted=77.74442537111926
# expected=70.0, predicted=78.33234458514268
# expected=96.0, predicted=74.75611352500825
# expected=38.0, predicted=93.13996692427469
# expected=38.0, predicted=32.70390598749631
# expected=62.0, predicted=46.93579427721224
# expected=47.0, predicted=69.31401127034103
# expected=86.0, predicted=46.63652302510673
# expected=55.0, predicted=92.28166260541734
# expected=46.0, predicted=55.528679363661574
# expected=84.0, predicted=49.24567343936087
# expected=127.0, predicted=75.74993419680833
# expected=145.0, predicted=142.84395282916412
# expected=197.0, predicted=117.21012687337716
# expected=167.0, predicted=174.6936428571429
# expected=131.0, predicted=135.05220942109938
# expected=170.0, predicted=106.83271731699254
# expected=154.0, predicted=125.8904782106782
# expected=65.0, predicted=130.750199287919
# expected=74.0, predicted=97.32419643826402
# expected=148.0, predicted=78.17142819574786
# expected=118.0, predicted=125.32937518337044
# expected=83.0, predicted=110.05272066169839
# expected=109.0, predicted=87.85688426823128
# expected=73.0, predicted=82.57014975847265
# expected=80.0, predicted=85.26233368097266
# expected=68.0, predicted=82.19481996334109
# expected=65.0, predicted=73.80388790259315
# expected=88.0, predicted=78.69697355558094
# expected=130.0, predicted=84.60325011062528
# expected=112.0, predicted=121.83055090100065
# expected=76.0, predicted=86.01132566986284
# expected=72.0, predicted=73.46240918154881
# expected=72.0, predicted=75.70550481710323
# expected=73.0, predicted=81.69034797140725
# expected=93.0, predicted=77.1252445752437
# expected=89.0, predicted=88.5564699010048
# expected=104.0, predicted=82.7269828108272
# expected=103.0, predicted=88.49948469915549
# expected=109.0, predicted=86.47661583859455
# expected=118.0, predicted=90.24772664655694
# expected=103.0, predicted=106.94174127759817
# expected=112.0, predicted=87.20779744039606
# expected=100.0, predicted=94.9976744568505
# expected=69.0, predicted=88.07600095067392
# expected=63.0, predicted=78.03621517792324
# expected=65.0, predicted=61.97382746939986
# expected=45.0, predicted=73.95659474634817
# expected=79.0, predicted=65.88533705474475
# expected=99.0, predicted=82.47911810201892
# expected=86.0, predicted=84.02485736279972
# expected=72.0, predicted=75.42400244824374
# expected=55.0, predicted=76.59398597217366
# expected=64.0, predicted=64.58536019248817
# expected=24.0, predicted=66.18008490854159
# expected=162.0, predicted=53.10040388236348
# expected=26.0, predicted=146.25516502726987
# expected=32.0, predicted=76.06120757762919
# expected=96.0, predicted=69.4660139978066
# expected=116.0, predicted=71.51847713517272
# expected=69.0, predicted=88.24037312046167
# expected=72.0, predicted=73.09335157926071
# expected=2.0, predicted=74.33839653429429
# expected=136.0, predicted=52.53575131543611
# expected=105.0, predicted=84.66425257014252
# expected=114.0, predicted=75.86565428845587
# expected=120.0, predicted=65.64426384675755
# expected=34.0, predicted=91.74015995808065
# expected=113.0, predicted=42.07331282229174
# expected=71.0, predicted=94.3138387952184
# expected=41.0, predicted=72.70963210257253
# expected=18.0, predicted=62.82096891439992
# expected=62.0, predicted=52.17636269751083
# expected=138.0, predicted=53.097072486049555
# expected=22.0, predicted=79.66592141479813
# expected=106.0, predicted=44.17302381613279
# expected=89.0, predicted=54.0628248590426
# expected=65.0, predicted=72.47958229536147
# expected=53.0, predicted=72.04329894988999
# expected=78.0, predicted=59.8431900769896
# expected=59.0, predicted=69.78767728573402
# expected=54.0, predicted=67.31791880907267
# expected=45.0, predicted=63.050566388341096
# expected=82.0, predicted=53.447208766511686
# expected=60.0, predicted=85.330068401615
# expected=89.0, predicted=62.31628453240769
# expected=80.0, predicted=86.4928085951215
# expected=48.0, predicted=73.39676258604707
# expected=47.0, predicted=61.60220386824678
# expected=62.0, predicted=63.113928970569575
# expected=91.0, predicted=65.00733927462048
# expected=89.0, predicted=90.57231989902745
# expected=92.0, predicted=79.6533832811087
# expected=99.0, predicted=86.81795959679333
# expected=39.0, predicted=89.48007776668486
# expected=30.0, predicted=41.51217117892004
# expected=59.0, predicted=52.15467945808145
# expected=85.0, predicted=65.90677267328807
# expected=58.0, predicted=90.1226098280157
# expected=47.0, predicted=56.76543662016824
# expected=48.0, predicted=49.3496476079707
# expected=98.0, predicted=51.46011197538661

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 22.786836722763585
# RMSE: 30.712500931212418
# MAPE: 46.10668682746716

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(train_index, [x[-1] for x in train], color='black', label='Train')
plt.plot(test_index, y, color='blue', label='Test')
plt.plot(test_index, yhat, color='magenta', label='Predict')
plt.plot(forecast_index, forecast, color='cyan', label='Predict 90 days')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 7:3')
plt.show()

# %%
plt.figure(figsize=(14, 7))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['orange', 'green', 'red']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 7:3')
plt.show()
