# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'hanoi_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.7

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_12620\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=25.4, predicted=36.38521593200738
# expected=21.2, predicted=23.820746722949885
# expected=17.0, predicted=20.51335992326761
# expected=16.2, predicted=16.557221626984123
# expected=34.2, predicted=16.094617183540667
# expected=50.6, predicted=40.15521027970054
# expected=64.4, predicted=57.74428916083914
# expected=75.8, predicted=69.49581812546477
# expected=76.0, predicted=79.43401938339439
# expected=67.8, predicted=78.65832034684993
# expected=60.0, predicted=58.957254022644065
# expected=54.0, predicted=54.3253113179821
# expected=47.6, predicted=53.11246940912474
# expected=43.8, predicted=44.61924377367365
# expected=37.6, predicted=43.5002216782795
# expected=33.6, predicted=34.505032192836154
# expected=32.6, predicted=32.21106408411316
# expected=39.2, predicted=33.622242438882395
# expected=48.8, predicted=45.11545700278822
# expected=55.4, predicted=53.39478497970913
# expected=56.4, predicted=62.640685056715775
# expected=56.0, predicted=57.18868042977287
# expected=51.6, predicted=53.88322446637309
# expected=42.2, predicted=46.94507928637342
# expected=34.0, predicted=40.953912306512365
# expected=32.0, predicted=35.039083615316876
# expected=27.8, predicted=32.13224334531007
# expected=19.4, predicted=29.439682780492085
# expected=18.6, predicted=18.160740978012768
# expected=22.0, predicted=18.150099457144325
# expected=22.4, predicted=24.204929635737855
# expected=22.6, predicted=25.232791019435513
# expected=33.6, predicted=25.22788054736392
# expected=43.4, predicted=40.385782789065445
# expected=45.8, predicted=49.11836852173943
# expected=49.6, predicted=47.07744592643696
# expected=54.2, predicted=51.024047663579466
# expected=54.0, predicted=59.94420902783265
# expected=52.6, predicted=52.767644413283726
# expected=53.8, predicted=46.909901996112986
# expected=54.6, predicted=51.23280276363584
# expected=57.8, predicted=53.59123318321304
# expected=60.8, predicted=53.5452191188597
# expected=54.2, predicted=58.31595465091608
# expected=47.2, predicted=54.25641335452919
# expected=47.0, predicted=42.44616294895696
# expected=49.2, predicted=42.183401066274584
# expected=44.6, predicted=49.56620122874126
# expected=52.6, predicted=44.809854087898515
# expected=58.2, predicted=52.97280952059995
# expected=55.6, predicted=57.194194712988335
# expected=48.8, predicted=55.84289346448365
# expected=43.6, predicted=43.3699994595582
# expected=33.2, predicted=41.898264214066955
# expected=27.4, predicted=34.85576614945652
# expected=30.2, predicted=24.467429840316022
# expected=41.8, predicted=33.02217569049787
# expected=63.0, predicted=52.180933414669425
# expected=88.0, predicted=69.97077604803296
# expected=116.8, predicted=93.15427459893051
# expected=130.8, predicted=118.21080627177695
# expected=146.6, predicted=132.31694473304466
# expected=151.4, predicted=145.7349886087768
# expected=142.0, predicted=147.726838095238
# expected=136.6, predicted=131.8711111111111
# expected=151.4, predicted=134.1948902597402
# expected=155.8, predicted=146.01765238095223
# expected=160.8, predicted=139.1583333333334
# expected=171.0, predicted=144.06214285714282
# expected=163.2, predicted=155.22299999999993
# expected=145.4, predicted=156.40500000000011
# expected=133.6, predicted=142.12455555555553
# expected=119.4, predicted=117.23362272727276
# expected=99.8, predicted=115.2563777777777
# expected=100.6, predicted=96.4368015873016
# expected=100.6, predicted=101.88204567099572
# expected=105.4, predicted=101.56872024642028
# expected=119.4, predicted=106.13315325061645
# expected=148.8, predicted=120.17947811796044
# expected=169.8, predicted=151.61706666666657
# expected=178.4, predicted=165.01579999999987
# expected=160.0, predicted=172.11799999999985
# expected=147.0, predicted=156.5699999999999
# expected=136.2, predicted=144.21617647058827
# expected=120.2, predicted=121.9546142857143
# expected=111.4, predicted=114.02371501831496
# expected=127.8, predicted=99.72587857142852
# expected=142.8, predicted=124.55075357142856
# expected=145.2, predicted=136.7444836134454
# expected=147.0, predicted=146.46056666666672
# expected=147.0, predicted=149.37009393939397
# expected=133.6, predicted=145.83500000000004
# expected=111.8, predicted=123.70604494949497
# expected=104.8, predicted=104.65798571428572
# expected=98.6, predicted=99.14936790890269
# expected=91.6, predicted=97.66455757575764
# expected=99.2, predicted=89.41698174603178
# expected=95.0, predicted=102.45236269841273
# expected=82.4, predicted=96.00654292929295
# expected=71.8, predicted=78.26379235674719
# expected=71.0, predicted=70.25669355851079
# expected=64.4, predicted=69.84365511738936
# expected=67.2, predicted=65.09042144351248
# expected=75.8, predicted=68.48894954522837
# expected=91.4, predicted=80.93182556756348
# expected=113.6, predicted=110.90826666666673
# expected=121.8, predicted=117.76366666666668
# expected=136.6, predicted=129.14590476190475
# expected=140.8, predicted=137.89616277056274
# expected=144.6, predicted=133.88498333333328
# expected=128.6, predicted=149.54555038733196
# expected=122.6, predicted=116.00378663101601
# expected=103.0, predicted=120.85955957901744
# expected=92.8, predicted=91.33422048981721
# expected=87.6, predicted=83.17795015841646
# expected=99.6, predicted=78.17977267904504
# expected=110.0, predicted=98.94456277611278
# expected=125.2, predicted=109.12495217560217
# expected=147.8, predicted=126.28297352092358
# expected=157.6, predicted=146.18346067821068
# expected=151.4, predicted=154.10182222222227
# expected=154.6, predicted=148.39109761904754
# expected=158.6, predicted=153.1693666666666
# expected=141.6, predicted=157.62242164502166
# expected=124.8, predicted=125.68792892156877
# expected=128.8, predicted=117.48754234826403
# expected=122.0, predicted=121.58144581986632
# expected=114.2, predicted=120.37492754614662
# expected=119.0, predicted=105.67620046904314
# expected=114.8, predicted=117.61815952380952
# expected=108.8, predicted=113.69468499278487
# expected=109.4, predicted=107.80379390054394
# expected=103.8, predicted=112.08492191142192
# expected=92.4, predicted=103.21234808145073
# expected=91.8, predicted=85.7514111111111
# expected=80.2, predicted=92.05407580812907
# expected=66.2, predicted=77.34340682667008
# expected=68.4, predicted=65.8481926036359
# expected=81.8, predicted=69.52007316775102
# expected=92.4, predicted=87.36621973338296
# expected=104.4, predicted=108.98754065934074
# expected=109.2, predicted=106.19293475135973
# expected=103.0, predicted=107.29869882232465
# expected=87.4, predicted=97.41195243836619
# expected=77.4, predicted=81.69606884226882
# expected=67.2, predicted=73.58019401807343
# expected=65.0, predicted=67.00856660901044
# expected=80.8, predicted=64.44926791791099
# expected=90.8, predicted=87.20086469769765
# expected=91.2, predicted=105.86983552754435
# expected=91.8, predicted=96.88955156534283
# expected=95.0, predicted=92.690964452012
# expected=92.2, predicted=91.62649551782152
# expected=92.4, predicted=86.5756627735812
# expected=96.8, predicted=89.79482383005598
# expected=103.0, predicted=97.14428194207672
# expected=105.6, predicted=100.78378519879391
# expected=101.2, predicted=102.30768983613336
# expected=100.4, predicted=94.46590772894606
# expected=101.0, predicted=97.16251213009211
# expected=92.6, predicted=100.40915778151843
# expected=85.2, predicted=85.7280688186813
# expected=86.4, predicted=73.18899327731091
# expected=86.0, predicted=83.32523589207715
# expected=87.2, predicted=82.80618228246641
# expected=91.8, predicted=84.03583439006678
# expected=43.2, predicted=48.08553185277835
# expected=37.6, predicted=43.79000601296287
# expected=39.2, predicted=40.4961755474091
# expected=50.2, predicted=43.55562737396249
# expected=58.6, predicted=57.554254522310494
# expected=58.4, predicted=68.26863602658189
# expected=59.6, predicted=60.81832852448244
# expected=64.2, predicted=60.64977888737983
# expected=68.0, predicted=65.99701009861425
# expected=66.6, predicted=67.49402886884232
# expected=75.2, predicted=64.04147494482837
# expected=84.8, predicted=79.86091935470323
# expected=86.6, predicted=81.34062908729024
# expected=79.8, predicted=82.57088936354978
# expected=79.2, predicted=72.24170506722352
# expected=75.8, predicted=73.80540516410349
# expected=65.8, predicted=72.57669625015751
# expected=60.4, predicted=62.55491642705229
# expected=56.2, predicted=57.53241619117176
# expected=56.0, predicted=55.290586212237756
# expected=55.4, predicted=56.20535836449776
# expected=63.2, predicted=53.08815895640956
# expected=69.8, predicted=65.86428544338844
# expected=69.8, predicted=72.36992529466707
# expected=78.0, predicted=69.10493947108601
# expected=92.0, predicted=81.6543486018486
# expected=104.0, predicted=100.90797611225842
# expected=111.2, predicted=102.50421450772599
# expected=115.2, predicted=112.82977190071882
# expected=103.6, predicted=112.87237342918519
# expected=93.4, predicted=95.07027890593241
# expected=88.8, predicted=79.64238496620338
# expected=89.0, predicted=79.04004774827514
# expected=104.6, predicted=87.65880374510742
# expected=114.4, predicted=106.66074378574638
# expected=130.2, predicted=116.51108753731651
# expected=122.2, predicted=130.7641550006761
# expected=109.0, predicted=120.39869426249126
# expected=89.4, predicted=101.82454968087467
# expected=92.4, predicted=83.70700305065307
# expected=86.2, predicted=94.75904132801782
# expected=99.2, predicted=79.39432268484009
# expected=105.4, predicted=105.22654957405852
# expected=105.8, predicted=111.77153667312217
# expected=93.6, predicted=104.99163593365284
# expected=81.4, predicted=82.48879136479707
# expected=62.0, predicted=75.29596199269568
# expected=63.8, predicted=56.12272259476059
# expected=69.4, predicted=66.93995409409925
# expected=74.2, predicted=71.82649450080234
# expected=73.4, predicted=82.18513423657988
# expected=78.0, predicted=75.85247049638147
# expected=61.4, predicted=83.27134205820944
# expected=52.8, predicted=63.492196011327394
# expected=58.8, predicted=49.10979476690993
# expected=59.4, predicted=66.53536490447563
# expected=59.0, predicted=65.37474057302998
# expected=82.2, predicted=63.16054338020291
# expected=104.8, predicted=87.93578372578186
# expected=117.0, predicted=109.41374607378981
# expected=105.4, predicted=125.95273571428572
# expected=129.6, predicted=95.43100951504636
# expected=132.0, predicted=128.53976543477606
# expected=132.0, predicted=120.11442729890885
# expected=126.6, predicted=117.92183752081255
# expected=153.2, predicted=121.1425584517959
# expected=147.8, predicted=148.41952738095236
# expected=150.2, predicted=145.02950396825403
# expected=157.6, predicted=148.5089290764791
# expected=164.0, predicted=151.9261473415474
# expected=149.6, predicted=156.8600568627451
# expected=138.2, predicted=150.107549108408
# expected=126.8, predicted=125.92469107164875
# expected=103.2, predicted=118.15833044744228
# expected=91.2, predicted=97.43702953190879
# expected=100.0, predicted=85.93937571113098
# expected=103.2, predicted=102.79598416028419
# expected=108.4, predicted=105.1586609310186
# expected=122.8, predicted=111.2509399432647
# expected=116.2, predicted=128.29956785214782
# expected=112.0, predicted=110.2661454148817
# expected=108.6, predicted=109.11066308519408
# expected=97.8, predicted=106.33611595056766
# expected=87.0, predicted=94.58705132043399
# expected=86.2, predicted=80.37473904869641
# expected=83.2, predicted=86.7241679256473
# expected=71.8, predicted=79.89486832851618
# expected=78.6, predicted=68.77518257423861
# expected=72.6, predicted=81.39766131017578
# expected=69.0, predicted=73.09279978412557
# expected=74.4, predicted=69.70771027775851
# expected=85.0, predicted=79.43734528527118
# expected=89.2, predicted=83.13849032338727
# expected=109.2, predicted=99.59793361317296
# expected=111.6, predicted=116.40186751162769
# expected=106.8, predicted=117.11688560328565
# expected=92.0, predicted=107.84661588654949
# expected=80.6, predicted=87.6503656380086
# expected=85.6, predicted=68.384047789317
# expected=110.2, predicted=82.83041931030589
# expected=118.6, predicted=114.1199232207851
# expected=141.8, predicted=124.61047327599661
# expected=146.0, predicted=140.01360850085587
# expected=123.6, predicted=147.06609321234325
# expected=109.6, predicted=121.83931730183114
# expected=116.4, predicted=96.10980747863245
# expected=109.6, predicted=110.65378275351017
# expected=109.0, predicted=109.89590240426806
# expected=113.0, predicted=104.31724576109673
# expected=105.0, predicted=112.7336445704574
# expected=91.2, predicted=99.71841049939002
# expected=80.2, predicted=89.29056123886113
# expected=67.4, predicted=70.39654362588988
# expected=65.8, predicted=64.44242742953197
# expected=72.6, predicted=67.19064061134034
# expected=77.6, predicted=80.09501889285586
# expected=87.4, predicted=82.68722109324877
# expected=103.6, predicted=91.57505619779626
# expected=98.4, predicted=109.3464970161074
# expected=96.8, predicted=96.9429335264263
# expected=79.8, predicted=97.93468129370343
# expected=73.6, predicted=69.16909554684625
# expected=71.8, predicted=71.08707900306939
# expected=83.2, predicted=70.69392299540074
# expected=75.4, predicted=85.91761504275537
# expected=88.8, predicted=73.69516242687989
# expected=98.2, predicted=94.06578905278167
# expected=100.0, predicted=103.14805982789144
# expected=95.2, predicted=98.22270445966022
# expected=104.8, predicted=89.82307106419525
# expected=118.8, predicted=107.93298663495484
# expected=130.6, predicted=130.47761581276347
# expected=142.2, predicted=128.49629303751797
# expected=153.4, predicted=145.4425225857477
# expected=142.8, predicted=153.68187883227884
# expected=122.8, predicted=138.20607125603877
# expected=101.0, predicted=115.14990436507938
# expected=82.8, predicted=93.43838197975646
# expected=69.0, predicted=74.39021854650231
# expected=68.0, predicted=68.25742394095693
# expected=69.0, predicted=67.82346799539094
# expected=84.2, predicted=71.37972839687535
# expected=86.6, predicted=88.40679373187402
# expected=94.0, predicted=88.75639738523464
# expected=94.8, predicted=96.87533557036706
# expected=93.6, predicted=88.69132444526265
# expected=81.6, predicted=89.2843683597737
# expected=87.0, predicted=72.75698017705903
# expected=82.2, predicted=89.070374138328
# expected=83.2, predicted=79.69812746794238
# expected=82.8, predicted=80.21752158398375
# expected=81.4, predicted=79.0519689312773
# expected=73.4, predicted=80.61233845388332
# expected=69.6, predicted=72.8706373271915
# expected=75.2, predicted=70.90564016717754
# expected=71.4, predicted=79.64278710737604
# expected=64.0, predicted=72.32128057351514
# expected=60.8, predicted=66.19360583798714
# expected=56.2, predicted=63.17233906645687
# expected=54.2, predicted=59.85416039498715
# expected=57.6, predicted=57.526502400811424
# expected=59.2, predicted=60.43057990006512
# expected=63.6, predicted=63.13690520018976
# expected=79.6, predicted=68.22761163778888
# expected=91.4, predicted=92.0555414164533
# expected=119.8, predicted=103.82512703495331
# expected=144.0, predicted=128.0704730268938
# expected=153.4, predicted=147.55530375852902
# expected=162.0, predicted=150.4979044072594
# expected=163.8, predicted=155.68283460265226
# expected=137.4, predicted=158.14465396825383
# expected=118.8, predicted=131.45827472527472
# expected=122.2, predicted=115.73609300144301
# expected=111.8, predicted=120.4555316133866
# expected=97.6, predicted=103.23684727041946
# expected=106.4, predicted=91.64002482898827
# expected=106.2, predicted=107.7965946042846
# expected=92.6, predicted=103.64478806582304
# expected=82.6, predicted=87.38617013522013
# expected=79.0, predicted=74.96119415231394
# expected=74.8, predicted=72.84655511317291
# expected=86.2, predicted=73.62156719384407
# expected=92.6, predicted=90.0726406440805
# expected=94.2, predicted=100.12187318091532
# expected=95.6, predicted=90.89046306461569
# expected=92.4, predicted=94.24009831574271
# expected=81.0, predicted=85.14839666351573
# expected=77.2, predicted=75.59215709667386
# expected=79.8, predicted=73.91070282031313
# expected=86.2, predicted=77.18773645966455
# expected=92.4, predicted=86.6195232517479
# expected=99.6, predicted=96.09538675816275
# expected=104.6, predicted=96.42177897351056
# expected=107.4, predicted=109.91764389505293
# expected=109.0, predicted=104.16023477734254
# expected=108.4, predicted=108.79160964996636
# expected=100.4, predicted=107.6176847433835
# expected=89.4, predicted=93.56283889555401
# expected=81.8, predicted=86.30853198289813
# expected=68.4, predicted=79.2044780204087
# expected=64.2, predicted=68.56194391293734
# expected=70.2, predicted=66.40541687019362
# expected=74.8, predicted=74.18295896927314
# expected=76.2, predicted=79.88253220905474
# expected=78.2, predicted=78.06382936615218
# expected=75.2, predicted=78.64652602492042
# expected=60.2, predicted=77.67034233650443
# expected=75.4, predicted=58.74446612887442
# expected=66.2, predicted=81.90473069582225
# expected=61.6, predicted=65.39660458992708
# expected=68.0, predicted=66.31178439996853
# expected=86.4, predicted=69.46180324477098
# expected=67.8, predicted=92.32032171255815
# expected=77.0, predicted=67.03422126623217
# expected=71.0, predicted=79.53150411919928
# expected=79.0, predicted=71.85565011081997
# expected=76.8, predicted=76.57835057852938
# expected=85.8, predicted=75.39525408581385
# expected=95.4, predicted=84.75577088301971
# expected=101.8, predicted=100.71904446060829
# expected=97.2, predicted=97.36643440170941
# expected=90.4, predicted=95.49083251450982
# expected=75.8, predicted=86.95517367509989
# expected=55.4, predicted=66.28037039815375
# expected=61.0, predicted=52.51645031056774
# expected=66.0, predicted=62.658131190788225
# expected=56.2, predicted=66.22565754318468
# expected=69.2, predicted=57.1080087959591
# expected=83.4, predicted=77.4254369038876
# expected=84.0, predicted=84.82273053428928
# expected=67.0, predicted=81.3966097325287
# expected=78.2, predicted=64.41036722688092
# expected=68.8, predicted=79.09652265505304
# expected=61.8, predicted=70.84055995568006
# expected=57.8, predicted=63.460148012264206
# expected=63.6, predicted=57.586765376303894
# expected=60.0, predicted=67.09817302922806
# expected=66.0, predicted=60.04805709937023
# expected=71.2, predicted=67.88937996978646
# expected=71.8, predicted=75.93151420738494
# expected=64.8, predicted=74.8673729031151
# expected=65.2, predicted=66.4902513743503
# expected=65.6, predicted=66.07009201764062
# expected=67.4, predicted=65.55401918724365
# expected=76.2, predicted=66.59215296131111
# expected=86.6, predicted=79.6328086364303
# expected=82.0, predicted=87.16898548298663
# expected=69.8, predicted=76.91877236006194
# expected=63.8, predicted=69.01632168129596
# expected=62.4, predicted=64.30958708791105
# expected=54.2, predicted=59.14148527166245
# expected=55.8, predicted=53.697358763226404
# expected=59.4, predicted=57.36419343447344
# expected=67.2, predicted=61.52335069209837

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_12620\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 6.567879734934742
# RMSE: 8.520425634053849
# MAPE: 8.248679168156094
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
# forecast_series = pd.Series(forecast)
# forecast_smoothed = smoothed(forecast_series)
# forecast_smoothed = forecast_smoothed.to_numpy()

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 7:3')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 7:3')
plt.show()
