# %%
import pandas as pd
import numpy as np
from pandas import concat
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from matplotlib import pyplot as plt

# %%
# Function to convert time series data to supervised learning format
def series_to_supervised(data, In=30, Out=1, dropnan=True):
    df = pd.DataFrame(data)
    columns = []
    for i in range(In, 0, -1):
        columns.append(df.shift(i))
    for i in range(0, Out):
        columns.append(df.shift(-i))
    agg = concat(columns, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# Function to split the data into train and test sets
def train_test_split(data, n):
    return data[:-n, :], data[-n:, :]

# Function to make a one-step forecast with Random Forest
def random_forest_forecast(train, test_x):
    train = np.asarray(train)
    train_x, train_y = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)  # Optimization parameters
    model.fit(train_x, train_y)
    yhat = model.predict([test_x])
    return yhat[0]

# Function for walk-forward validation
def walk_forward_validation(train, test):
    predictions = []
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
        print(f'expected={test_y}, predicted={yhat}')
    
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions, history

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Forecasting the next 90 days
def forecast_next_days(data, n_days):
    predictions = []
    train, test = train_test_split(data, n_days)
    history = [x for x in train]
    for i in range(len(test)):
        test_x, test_y = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, test_x)
        predictions.append(yhat)
        history.append(test[i])
    return predictions

# %%
# Load the dataset
file_path = 'hanoi_quality.csv'  # Adjust the file path as needed
series_all = pd.read_csv(file_path, header=0, index_col=0, parse_dates=True)
series = series_all['pm25']
len_data = len(series)
n_in = 30
n_out = 1
ratio = 0.8

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    series_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    series_smoothed_interpolated = series_smoothed.interpolate()

    # Fill remaining NaN values
    series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return series_smoothed_filled

# %%
series_smoothed = smoothed(series)
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_2380\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
len(series_smoothed)
# Out:
# 1920

# %%
# Convert the PM2.5 series to supervised learning
data = series_to_supervised(series_smoothed.values, In=n_in, Out=n_out)

# %%
len_test = len(data)-(int(len_data*ratio)-n_in)
train, test = train_test_split(data, len_test)

# %%
# Perform walk-forward validation on the test set
mae, y, yhat, history = walk_forward_validation(train, test)
# Out:
# expected=47.8, predicted=46.73842575481733
# expected=52.8, predicted=47.718570589763175
# expected=65.2, predicted=51.35632754320162
# expected=82.6, predicted=70.55506257299773
# expected=90.6, predicted=85.54301252069568
# expected=98.0, predicted=100.01728566988567
# expected=103.4, predicted=100.79807004074357
# expected=101.8, predicted=100.96378514811919
# expected=95.6, predicted=97.71559682212586
# expected=94.4, predicted=88.31744458599533
# expected=85.4, predicted=84.97802555084756
# expected=78.2, predicted=74.09248015740545
# expected=69.0, predicted=71.2510823455906
# expected=60.0, predicted=68.71147928458345
# expected=54.4, predicted=58.3839094260843
# expected=56.4, predicted=54.616581422921534
# expected=62.4, predicted=54.79153052320532
# expected=71.6, predicted=63.08140153732616
# expected=78.8, predicted=71.70228469138098
# expected=80.8, predicted=85.94571312840257
# expected=82.0, predicted=77.57752415633439
# expected=81.4, predicted=78.31292352893058
# expected=77.8, predicted=80.40725197679582
# expected=76.4, predicted=76.48450232476586
# expected=84.8, predicted=75.83921044216457
# expected=79.2, predicted=82.82684186409637
# expected=80.4, predicted=74.4510713231193
# expected=88.0, predicted=78.55295012259523
# expected=93.2, predicted=90.71180503120338
# expected=86.0, predicted=93.1812301968474
# expected=85.0, predicted=76.00905444219998
# expected=77.4, predicted=77.98033546036328
# expected=66.0, predicted=71.99786242455099
# expected=55.2, predicted=63.92917261603292
# expected=47.8, predicted=53.94283751744997
# expected=50.2, predicted=45.1159530880478
# expected=53.2, predicted=54.14213830757762
# expected=54.0, predicted=49.38066852639141
# expected=60.2, predicted=54.63976341564331
# expected=61.8, predicted=64.15391754273733
# expected=60.0, predicted=63.74012056167132
# expected=51.8, predicted=60.90740701065646
# expected=51.4, predicted=48.17603370313149
# expected=47.2, predicted=49.88764257865787
# expected=44.6, predicted=46.287153685236
# expected=43.8, predicted=45.05098439982455
# expected=48.8, predicted=44.897356692332686
# expected=49.0, predicted=49.94416763034376
# expected=48.8, predicted=49.36164952618446
# expected=54.4, predicted=48.3304585564646
# expected=57.6, predicted=58.04534371297694
# expected=57.8, predicted=56.68903057314324
# expected=53.8, predicted=56.884921191413106
# expected=49.4, predicted=52.10564147083896
# expected=43.6, predicted=47.45104216184167
# expected=38.2, predicted=43.869185684430924
# expected=37.2, predicted=36.473288264626774
# expected=38.6, predicted=38.05913641481769
# expected=40.2, predicted=40.56178357295987
# expected=44.4, predicted=40.37637817253556
# expected=48.8, predicted=47.431947029257046
# expected=53.2, predicted=50.15732363529874
# expected=59.4, predicted=51.64016940098276
# expected=72.0, predicted=59.72592560590008
# expected=77.2, predicted=74.74154553380032
# expected=78.8, predicted=81.66127049428829
# expected=81.4, predicted=76.57057729553826
# expected=80.4, predicted=81.23878333056467
# expected=69.0, predicted=79.24883921398524
# expected=59.2, predicted=63.829938116828025
# expected=55.6, predicted=53.94530261728337
# expected=47.2, predicted=52.96909423101126
# expected=43.4, predicted=43.7739849913639
# expected=49.0, predicted=42.357713191801146
# expected=55.2, predicted=50.32181158542194
# expected=62.2, predicted=58.159759028248246
# expected=68.6, predicted=64.05167705946286
# expected=69.6, predicted=70.4378448317021
# expected=65.4, predicted=70.16496163817378
# expected=66.0, predicted=63.83051876738026
# expected=62.2, predicted=66.20278179331767
# expected=56.6, predicted=56.57435664667335
# expected=55.0, predicted=53.49827970172711
# expected=52.6, predicted=53.139559896288795
# expected=49.2, predicted=48.06674594163617
# expected=48.2, predicted=47.09203960081443
# expected=53.2, predicted=47.07796525619899
# expected=58.0, predicted=54.575581152567636
# expected=68.2, predicted=57.483649548706
# expected=72.8, predicted=68.61860522869004
# expected=77.2, predicted=75.40902976458139
# expected=74.4, predicted=78.42563783017218
# expected=70.8, predicted=73.956676411631
# expected=68.0, predicted=68.76748632011378
# expected=70.6, predicted=60.56932130624368
# expected=68.2, predicted=71.69876042659153
# expected=75.8, predicted=63.924439625424085
# expected=75.6, predicted=79.19280346508613
# expected=73.0, predicted=76.7555246121536
# expected=68.4, predicted=73.69571495762429
# expected=69.8, predicted=67.25917396550139
# expected=63.2, predicted=69.72248332289684
# expected=67.6, predicted=61.050976251826285
# expected=64.2, predicted=66.62454257448036
# expected=65.8, predicted=64.42670057000117
# expected=60.8, predicted=66.84627596582715
# expected=61.4, predicted=60.2681125534571
# expected=56.2, predicted=62.0500778610584
# expected=63.8, predicted=53.64051252417344
# expected=70.4, predicted=67.62587870776602
# expected=82.2, predicted=72.63449915902582
# expected=86.0, predicted=82.44184692296295
# expected=82.8, predicted=83.97522384926056
# expected=76.6, predicted=79.63833298664393
# expected=75.4, predicted=74.76625974489194
# expected=73.0, predicted=73.93139027729691
# expected=68.6, predicted=73.43234048483832
# expected=75.2, predicted=66.75471531365143
# expected=83.4, predicted=77.83029513636237
# expected=81.8, predicted=81.5112441156956
# expected=82.0, predicted=78.34724991594078
# expected=78.8, predicted=78.79559960990925
# expected=71.0, predicted=75.84212012987764
# expected=61.6, predicted=68.1181544563927
# expected=59.0, predicted=59.17025435326854
# expected=56.0, predicted=61.600008754565344
# expected=60.4, predicted=54.642782528599646
# expected=64.2, predicted=62.947799018083124
# expected=60.2, predicted=67.60088562508965
# expected=51.8, predicted=60.167120870669194
# expected=43.2, predicted=47.767202434395756
# expected=37.6, predicted=43.45420637975353
# expected=39.2, predicted=41.329005844455644
# expected=50.2, predicted=42.82078743894631
# expected=58.6, predicted=56.125919621977026
# expected=58.4, predicted=66.36575314216307
# expected=59.6, predicted=60.63446668684053
# expected=64.2, predicted=59.30866158683468
# expected=68.0, predicted=67.19607701703755
# expected=66.6, predicted=68.31304660369767
# expected=75.2, predicted=63.697263471484796
# expected=84.8, predicted=79.2005521216493
# expected=86.6, predicted=80.85818724728284
# expected=79.8, predicted=81.64448135956346
# expected=79.2, predicted=71.09958995964774
# expected=75.8, predicted=73.89129126885487
# expected=65.8, predicted=72.56125051708145
# expected=60.4, predicted=62.68765659222835
# expected=56.2, predicted=58.09388247168687
# expected=56.0, predicted=56.81167360957168
# expected=55.4, predicted=54.5975727684082
# expected=63.2, predicted=53.95096911286165
# expected=69.8, predicted=66.15098609194216
# expected=69.8, predicted=73.08398109164109
# expected=78.0, predicted=70.57225522192817
# expected=92.0, predicted=81.24757349597624
# expected=104.0, predicted=102.6992082706767
# expected=111.2, predicted=102.80098981607766
# expected=115.2, predicted=113.37979067233555
# expected=103.6, predicted=113.75910454969868
# expected=93.4, predicted=96.44695096073518
# expected=88.8, predicted=81.26943221100748
# expected=89.0, predicted=79.17883703693967
# expected=104.6, predicted=86.67876435718782
# expected=114.4, predicted=105.56973862987773
# expected=130.2, predicted=114.76774357682217
# expected=122.2, predicted=135.2969200387847
# expected=109.0, predicted=119.0977942612943
# expected=89.4, predicted=101.44924366744362
# expected=92.4, predicted=83.09742774504822
# expected=86.2, predicted=94.89342371843844
# expected=99.2, predicted=80.43538395558772
# expected=105.4, predicted=104.90228505749104
# expected=105.8, predicted=110.46328984361311
# expected=93.6, predicted=104.37236337391624
# expected=81.4, predicted=81.64081544535175
# expected=62.0, predicted=74.85663666752035
# expected=63.8, predicted=58.071470547820496
# expected=69.4, predicted=65.36430712554792
# expected=74.2, predicted=71.8139685084925
# expected=73.4, predicted=80.87325717203835
# expected=78.0, predicted=75.64894010438303
# expected=61.4, predicted=81.9620923308451
# expected=52.8, predicted=62.78626085110138
# expected=58.8, predicted=49.69146147394209
# expected=59.4, predicted=67.00027557108898
# expected=59.0, predicted=64.04957712339018
# expected=82.2, predicted=62.636836082361604
# expected=104.8, predicted=87.79978432956386
# expected=117.0, predicted=108.92442508208167
# expected=105.4, predicted=123.26431561071689
# expected=129.6, predicted=98.72119005983696
# expected=132.0, predicted=128.20923153136718
# expected=132.0, predicted=119.6925448051948
# expected=126.6, predicted=117.53899322344321
# expected=153.2, predicted=123.1899577068357
# expected=147.8, predicted=150.5915597402597
# expected=150.2, predicted=145.87580788246848
# expected=157.6, predicted=148.2462495060495
# expected=164.0, predicted=153.41287703962703
# expected=149.6, predicted=156.10465634920638
# expected=138.2, predicted=149.46873333333338
# expected=126.8, predicted=125.37316354113722
# expected=103.2, predicted=118.88930222743298
# expected=91.2, predicted=97.39289728634789
# expected=100.0, predicted=83.97769040561832
# expected=103.2, predicted=103.05189918413724
# expected=108.4, predicted=103.94873617871843
# expected=122.8, predicted=111.25557571156907
# expected=116.2, predicted=126.79126582255027
# expected=112.0, predicted=108.063882360398
# expected=108.6, predicted=108.78831264103623
# expected=97.8, predicted=104.58335494726654
# expected=87.0, predicted=94.36494623883738
# expected=86.2, predicted=78.96584076792772
# expected=83.2, predicted=86.51873279612536
# expected=71.8, predicted=82.54267971872464
# expected=78.6, predicted=69.69233123728748
# expected=72.6, predicted=80.35853525818234
# expected=69.0, predicted=74.42686921642425
# expected=74.4, predicted=68.60342744936335
# expected=85.0, predicted=78.90161387133384
# expected=89.2, predicted=84.60475643675443
# expected=109.2, predicted=99.20227652376609
# expected=111.6, predicted=117.17726669719178
# expected=106.8, predicted=117.06519591892693
# expected=92.0, predicted=104.56639123392948
# expected=80.6, predicted=89.30080838847755
# expected=85.6, predicted=69.28994394560708
# expected=110.2, predicted=81.78730502233024
# expected=118.6, predicted=114.81677734437602
# expected=141.8, predicted=126.2752381797379
# expected=146.0, predicted=139.4004594741859
# expected=123.6, predicted=146.92576139362197
# expected=109.6, predicted=120.30742425001898
# expected=116.4, predicted=95.68297448674683
# expected=109.6, predicted=113.20497090514402
# expected=109.0, predicted=109.72746120329904
# expected=113.0, predicted=103.38970397455573
# expected=105.0, predicted=113.25111909487099
# expected=91.2, predicted=100.40148018040273
# expected=80.2, predicted=86.84307759294713
# expected=67.4, predicted=70.98402016764598
# expected=65.8, predicted=64.49319351807638
# expected=72.6, predicted=67.37060316203889
# expected=77.6, predicted=81.61048125513388
# expected=87.4, predicted=82.60741376588561
# expected=103.6, predicted=91.52624201640556
# expected=98.4, predicted=109.8923681557005
# expected=96.8, predicted=98.69207596861344
# expected=79.8, predicted=95.322449380001
# expected=73.6, predicted=69.44999389102365
# expected=71.8, predicted=71.4251268567764
# expected=83.2, predicted=70.57779165672025
# expected=75.4, predicted=85.54014575272922
# expected=88.8, predicted=75.53801415928693
# expected=98.2, predicted=94.5981512567294
# expected=100.0, predicted=102.79308328951745
# expected=95.2, predicted=97.95493545518494
# expected=104.8, predicted=88.64669795678348
# expected=118.8, predicted=105.60628445099721
# expected=130.6, predicted=130.02696528973954
# expected=142.2, predicted=127.93859333881254
# expected=153.4, predicted=142.4734346320347
# expected=142.8, predicted=154.23693015873013
# expected=122.8, predicted=139.5406816004274
# expected=101.0, predicted=115.43491240981244
# expected=82.8, predicted=94.13588783285346
# expected=69.0, predicted=74.68978506162121
# expected=68.0, predicted=66.9443781242666
# expected=69.0, predicted=66.69356513250858
# expected=84.2, predicted=70.92513052144974
# expected=86.6, predicted=88.17698044053527
# expected=94.0, predicted=90.33117264758025
# expected=94.8, predicted=95.00534187728498
# expected=93.6, predicted=90.88150009974991
# expected=81.6, predicted=88.71209024461464
# expected=87.0, predicted=72.758643877501
# expected=82.2, predicted=87.74402713382001
# expected=83.2, predicted=78.63390217473906
# expected=82.8, predicted=81.48364294535799
# expected=81.4, predicted=78.99954042012058
# expected=73.4, predicted=79.78159346207754
# expected=69.6, predicted=73.03770443921668
# expected=75.2, predicted=69.90178985904288
# expected=71.4, predicted=78.439079512469
# expected=64.0, predicted=72.90135185233682
# expected=60.8, predicted=65.23837017055074
# expected=56.2, predicted=61.916682616409
# expected=54.2, predicted=59.484474614092825
# expected=57.6, predicted=55.94240952482578
# expected=59.2, predicted=61.470892708790046
# expected=63.6, predicted=62.19971080006641
# expected=79.6, predicted=67.44025481899685
# expected=91.4, predicted=91.15907963698618
# expected=119.8, predicted=104.25232948149461
# expected=144.0, predicted=129.22757029914533
# expected=153.4, predicted=148.27909269847794
# expected=162.0, predicted=150.1623873949579
# expected=163.8, predicted=153.63930867928363
# expected=137.4, predicted=159.47210283050276
# expected=118.8, predicted=131.48075341880343
# expected=122.2, predicted=116.39139991611546
# expected=111.8, predicted=121.5413281987019
# expected=97.6, predicted=105.78773304695302
# expected=106.4, predicted=94.27289242375272
# expected=106.2, predicted=106.70291884670183
# expected=92.6, predicted=106.39109125980295
# expected=82.6, predicted=87.2778799137193
# expected=79.0, predicted=75.75119326265246
# expected=74.8, predicted=73.69182830303536
# expected=86.2, predicted=74.4041926752319
# expected=92.6, predicted=92.88327738613252
# expected=94.2, predicted=100.65349191482383
# expected=95.6, predicted=91.9962865022616
# expected=92.4, predicted=92.67843340391781
# expected=81.0, predicted=86.9239529644293
# expected=77.2, predicted=74.64228756977307
# expected=79.8, predicted=75.12630433487168
# expected=86.2, predicted=76.98506461684623
# expected=92.4, predicted=87.97946264191067
# expected=99.6, predicted=95.27912072312394
# expected=104.6, predicted=98.18637881423963
# expected=107.4, predicted=110.01689479833892
# expected=109.0, predicted=101.6211445063077
# expected=108.4, predicted=108.36022662788785
# expected=100.4, predicted=106.6239099997775
# expected=89.4, predicted=93.60683727472296
# expected=81.8, predicted=86.41926178214206
# expected=68.4, predicted=80.60393088277264
# expected=64.2, predicted=68.37097581323556
# expected=70.2, predicted=66.65069225867015
# expected=74.8, predicted=74.3452806506569
# expected=76.2, predicted=78.83581092300474
# expected=78.2, predicted=79.10693708998126
# expected=75.2, predicted=79.19098634789655
# expected=60.2, predicted=76.54207057000983
# expected=75.4, predicted=59.23237991486991
# expected=66.2, predicted=85.08254963034533
# expected=61.6, predicted=66.17126161240793
# expected=68.0, predicted=64.47776580562864
# expected=86.4, predicted=70.5814189532542
# expected=67.8, predicted=92.57092385804121
# expected=77.0, predicted=66.75209294083183
# expected=71.0, predicted=81.752888211933
# expected=79.0, predicted=72.58196623051242
# expected=76.8, predicted=77.29588535518684
# expected=85.8, predicted=75.51979154818382
# expected=95.4, predicted=84.14599013583882
# expected=101.8, predicted=100.34324864197666
# expected=97.2, predicted=99.6719804663134
# expected=90.4, predicted=94.7125952993777
# expected=75.8, predicted=86.9101508172851
# expected=55.4, predicted=67.52247033266977
# expected=61.0, predicted=52.03645011034846
# expected=66.0, predicted=62.35970814266454
# expected=56.2, predicted=68.14444564181376
# expected=69.2, predicted=56.97451263713537
# expected=83.4, predicted=76.74826747462554
# expected=84.0, predicted=82.8834839550717
# expected=67.0, predicted=81.31260659689168
# expected=78.2, predicted=64.10562412597797
# expected=68.8, predicted=79.25941269973134
# expected=61.8, predicted=70.86451137439458
# expected=57.8, predicted=63.676493367979276
# expected=63.6, predicted=58.41544346865168
# expected=60.0, predicted=68.23539910865837
# expected=66.0, predicted=60.11684615590279
# expected=71.2, predicted=67.11001512912088
# expected=71.8, predicted=74.5162429818769
# expected=64.8, predicted=74.35010528620235
# expected=65.2, predicted=66.30415109978816
# expected=65.6, predicted=66.20579611964676
# expected=67.4, predicted=64.54367480633611
# expected=76.2, predicted=66.23240692602724
# expected=86.6, predicted=78.94976567103477
# expected=82.0, predicted=86.09195915330703
# expected=69.8, predicted=76.66431148189845
# expected=63.8, predicted=68.71715370681056
# expected=62.4, predicted=62.293014891118325
# expected=54.2, predicted=58.513740397008625
# expected=55.8, predicted=54.53198785679829
# expected=59.4, predicted=58.23335213084137
# expected=67.2, predicted=61.84388998792131

# %%
print('MAE:', mae)
# Calculate RMSE
rmse = mean_squared_error(y, yhat, squared=False)
print('RMSE:', rmse)
mape = mean_absolute_percentage_error(y, yhat)
print('MAPE:', mape)
# Out:
# MAE: 6.387316474684372
# RMSE: 8.230597473068732
# MAPE: 7.912242978396371
# c:\Users\21521\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Fit the model on the entire dataset with optimization parameters
model = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
model.fit(data[:, :-1], data[:, -1])
# Forecast the next 90 days
n_days = 90
forecast = forecast_next_days(data, n_days)

# %%
yhat_series = pd.Series(yhat)
yhat_smoothed = smoothed(yhat_series)
yhat_smoothed = yhat_smoothed.to_numpy()
# Out:
# C:\Users\21521\AppData\Local\Temp\ipykernel_2380\3312313537.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   series_smoothed_filled = series_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)

# %%
train = np.concatenate((train[0][0:30], np.array([x[30] for x in train]).T))

# %%
# forecast_series = pd.Series(forecast)
# forecast_smoothed = smoothed(forecast_series)
# forecast_smoothed = forecast_smoothed.to_numpy()

# %%
# Prepare data for plotting
train_index = range(len(train))
test_index = range(len(train), len(train) + len(test))
forecast_index = range(len(train) + len(test), len(train) + len(test) + n_days)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_index, train, color='blue', label='Train')
plt.plot(test_index, y, color='orange', label='Test')
plt.plot(test_index, yhat, color='green', label='Predict')
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('indexs')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 8:2')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Split forecast into 3 segments
segment_size = 30
forecast_segments = [forecast[i*segment_size:(i+1)*segment_size] for i in range(3)]
colors = ['red', 'purple', 'brown']  # Màu cho từng phần
for i, segment in enumerate(forecast_segments):
    plt.plot(forecast_index[i*segment_size:(i+1)*segment_size], segment, color=colors[i], label=f'Predict Days {i*segment_size+1}-{(i+1)*segment_size}')

plt.xlabel('Days')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Random Forest - Hà Nội - 8:2')
plt.show()
