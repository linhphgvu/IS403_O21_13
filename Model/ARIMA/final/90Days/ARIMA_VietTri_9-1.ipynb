# %%
# 1. Các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
# 2.Load Dataset
data = pd.read_csv("viettri_quality.csv")
data
# Out:
#            date  pm25  pm10  o3  no2  so2  co
# 0      3/1/2019    44    17  29    2    9   4
# 1      3/2/2019    65    37  27    4   12   4
# 2      3/3/2019    81    38   2    1    1   2
# 3      3/4/2019    51    24  21    4    8   1
# 4      3/5/2019    43     7  23    1   12   4
# ...         ...   ...   ...  ..  ...  ...  ..
# 1915  5/28/2024    38    24  35    1   15   5
# 1916  5/29/2024    38    17  41    7   15  10
# 1917  5/30/2024    28     8  11    1   15   1
# 1918  5/31/2024    12    12  16    1   16   7
# 1919   6/1/2024    21    28  15    1   17   7
#
# [1920 rows x 7 columns]

# %%
#kích thước dữ liệu
data.shape
data.info()
#Mô tả bộ dữ liệu
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1920 non-null   object
#  1   pm25    1920 non-null   int64
#  2   pm10    1920 non-null   int64
#  3   o3      1920 non-null   int64
#  4   no2     1920 non-null   int64
#  5   so2     1920 non-null   int64
#  6   co      1920 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 105.1+ KB
#               pm25         pm10           o3          no2          so2  \
# count  1920.000000  1920.000000  1920.000000  1920.000000  1920.000000
# mean     42.395313    22.470833    17.391667     7.528125     9.497917
# std      31.665288    16.124166    12.907283     4.971229     6.526731
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      19.000000    10.000000     8.750000     3.000000     4.000000
# 50%      35.000000    20.000000    15.000000     7.000000     9.000000
# 75%      59.000000    32.000000    24.000000    11.000000    14.000000
# max     178.000000    94.000000   114.000000    35.000000    27.000000
#
#                 co
# count  1920.000000
# mean      3.961979
# std       2.516048
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      22.000000

# %%
#Chọn thuộc tính
data = data[['pm25']]
data = data.dropna() 
data = data.reset_index(drop=True) 
data
# Out:
#       pm25
# 0       44
# 1       65
# 2       81
# 3       51
# 4       43
# ...    ...
# 1915    38
# 1916    38
# 1917    28
# 1918    12
# 1919    21
#
# [1920 rows x 1 columns]

# %%
data.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# 2. Đọc file dữ liệu và chia train test theo tỉ lệ 7:3
train_size = int(0.9 * len(data))
test_size = int(0.1 * len(data))

# Chia dữ liệu thành các tập
train_data = data[:train_size]
test_data = data[train_size:]

# Kiểm tra kích thước của từng tập
print("Train data size:", len(train_data))
print("Test data size:", len(test_data))
# Out:
# Train data size: 1728
# Test data size: 192

# %%
# 3. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['pm25'])

# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)

# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=16111.825, Time=1.79 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16790.775, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16445.312, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16157.448, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16788.777, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16109.845, Time=1.53 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=16124.907, Time=0.51 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=16117.201, Time=0.45 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=16111.825, Time=1.71 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=16114.834, Time=0.76 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=16111.406, Time=0.73 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=16113.421, Time=2.84 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=16107.845, Time=0.85 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=16122.908, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=16115.201, Time=0.29 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=16109.825, Time=0.93 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=16109.825, Time=1.00 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=16155.450, Time=0.17 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=16112.834, Time=0.34 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=16109.407, Time=0.49 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=16111.421, Time=1.10 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 16.434 seconds
# ARIMA(order=(1, 1, 2), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# 4. Quá trình testing 
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(n_periods=len(y_test))

# %%
# 4. Quá trình tạo index predict 30 ngày tiếp theo
last_index =  data.index[-1]
last_data = pd.RangeIndex(start=last_index + 1, stop=last_index+31, step=1)

# Tạo mảng 90 ngày 
x_next_30_days = np.array(range(last_index+1, last_index+91)).reshape(-1, 1)

# Dự đoán 90 ngày tiếp theo
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# # In ra dự đoán giá trong 90 ngày tiếp theo
print('Predicted closing prices for the next 90 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 90 days:
# [67.64650124 62.3845181  59.28831027 57.46646808 56.39447642 55.76370492
#  55.39255215 55.17416184 55.04565862 54.97004593 54.92555461 54.89937544
#  54.88397133 54.87490738 54.86957406 54.86643587 54.86458933 54.8635028
#  54.86286348 54.8624873  54.86226595 54.8621357  54.86205906 54.86201397
#  54.86198743 54.86197182 54.86196263 54.86195723 54.86195405 54.86195218
#  54.86195107 54.86195043 54.86195005 54.86194982 54.86194969 54.86194961
#  54.86194957 54.86194954 54.86194952 54.86194951 54.86194951 54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495
#  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495  54.8619495 ]

# %%
# 5. Tính RMSE
test_rmse = np.sqrt(np.mean((y_test - y_pred)**2))
print('Testing RMSE:', test_rmse)

# 6. Tính MAPE
test_mape = np.mean(np.abs((y_test - y_pred)/y_test))*100
print('\nTesting MAPE:', test_mape)

# 7. Tính MAE
test_mae = np.mean(np.abs(y_test - y_pred))
print("\nMAE:", test_mae)
# Out:
# Testing RMSE: 25.083959954451
#
# Testing MAPE: 113.11952313601917
#
# MAE: 20.451657490688344

# %%
test_data.index
# Out:
# RangeIndex(start=1728, stop=1920, step=1)

# %%
# 9.Vẽ hình
plt.plot(train_data.index, train_data)
plt.plot(test_data.index, test_data)
plt.plot(test_data.index, y_pred)


last_data = pd.RangeIndex(start=last_index+1, stop=last_index+31, step=1)
plt.plot(last_data,y_next_30_days[0:30])

last_data = pd.RangeIndex(start=last_index+31, stop=last_index+61, step=1)
plt.plot(last_data,y_next_30_days[30:60])

last_data = pd.RangeIndex(start=last_index+61, stop=last_index+91, step=1)
plt.plot(last_data,y_next_30_days[60:90])
plt.legend(['Train','Test','Predict','Predict30days', 'Predict60days', 'Predict90days'])
plt.title('ARIMA 9-1 (Viet Tri PM2.5)')
plt.ylabel('PM2.5')
plt.show()


#DỰ đians 90 ngày
last_data = pd.RangeIndex(start=last_index+1, stop=last_index+31, step=1)
plt.plot(last_data,y_next_30_days[0:30])

last_data = pd.RangeIndex(start=last_index+31, stop=last_index+61, step=1)
plt.plot(last_data,y_next_30_days[30:60])

last_data = pd.RangeIndex(start=last_index+61, stop=last_index+91, step=1)
plt.plot(last_data,y_next_30_days[60:90])
plt.legend(['Predict30days', 'Predict60days', 'Predict90days'])
plt.title('ARIMA 9-1 (Viet Tri PM2.5)')
plt.ylabel('PM2.5')
plt.show()
