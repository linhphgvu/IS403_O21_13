# %%
# 1. Các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# %%
# 2.Load Dataset
data = pd.read_csv("viettri_quality.csv")
data
# Out:
#            date  pm25  pm10  o3  no2  so2  co
# 0      3/1/2019    44    17  29    2    9   4
# 1      3/2/2019    65    37  27    4   12   4
# 2      3/3/2019    81    38   2    1    1   2
# 3      3/4/2019    51    24  21    4    8   1
# 4      3/5/2019    43     7  23    1   12   4
# ...         ...   ...   ...  ..  ...  ...  ..
# 1915  5/28/2024    38    24  35    1   15   5
# 1916  5/29/2024    38    17  41    7   15  10
# 1917  5/30/2024    28     8  11    1   15   1
# 1918  5/31/2024    12    12  16    1   16   7
# 1919   6/1/2024    21    28  15    1   17   7
#
# [1920 rows x 7 columns]

# %%
#kích thước dữ liệu
data.shape
data.info()
#Mô tả bộ dữ liệu
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1920 non-null   object
#  1   pm25    1920 non-null   int64
#  2   pm10    1920 non-null   int64
#  3   o3      1920 non-null   int64
#  4   no2     1920 non-null   int64
#  5   so2     1920 non-null   int64
#  6   co      1920 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 105.1+ KB
#               pm25         pm10           o3          no2          so2  \
# count  1920.000000  1920.000000  1920.000000  1920.000000  1920.000000
# mean     42.395313    22.470833    17.391667     7.528125     9.497917
# std      31.665288    16.124166    12.907283     4.971229     6.526731
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      19.000000    10.000000     8.750000     3.000000     4.000000
# 50%      35.000000    20.000000    15.000000     7.000000     9.000000
# 75%      59.000000    32.000000    24.000000    11.000000    14.000000
# max     178.000000    94.000000   114.000000    35.000000    27.000000
#
#                 co
# count  1920.000000
# mean      3.961979
# std       2.516048
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      22.000000

# %%
#Chọn thuộc tính
data = data[['pm25']]
data = data.dropna() 
data = data.reset_index(drop=True) 
data
# Out:
#       pm25
# 0       44
# 1       65
# 2       81
# 3       51
# 4       43
# ...    ...
# 1915    38
# 1916    38
# 1917    28
# 1918    12
# 1919    21
#
# [1920 rows x 1 columns]

# %%
def smoothed(data):
    # Apply moving average filter to smooth the forecasted values
    window_size = 5  # You can adjust the window size as needed
    forecast_smoothed = data.rolling(window=window_size).mean()

    # Interpolate NaN values resulting from the moving average
    forecast_smoothed_interpolated = forecast_smoothed.interpolate()

    # Fill remaining NaN values
    forecast_smoothed_filled = forecast_smoothed_interpolated.fillna(method='bfill')  # or 'ffill', or use fillna(value=0)
    
    return forecast_smoothed_filled

# Example usage
data = smoothed(data)

# %%
data.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# 2. Đọc file dữ liệu và chia train test theo tỉ lệ 7:3
train_size = int(0.9 * len(data))
test_size = int(0.1 * len(data))

# Chia dữ liệu thành các tập
train_data = data[:train_size]
test_data = data[train_size:]

# Kiểm tra kích thước của từng tập
print("Train data size:", len(train_data))
print("Test data size:", len(test_data))
# Out:
# Train data size: 1728
# Test data size: 192

# %%
# 3. Quá trình Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['pm25'])

# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)

# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=9.81 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=11681.914, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=11553.880, Time=0.65 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11575.154, Time=0.78 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=11679.915, Time=0.19 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=11549.475, Time=0.88 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=11550.673, Time=0.99 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=11511.852, Time=2.70 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11551.156, Time=0.80 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=11509.739, Time=5.35 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=11406.611, Time=4.96 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=11543.743, Time=1.39 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=11077.207, Time=3.12 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=11090.704, Time=2.48 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=11069.216, Time=5.53 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=10.05 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=8.36 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=6.77 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=11067.216, Time=2.33 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=inf, Time=5.58 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=11075.207, Time=1.08 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=inf, Time=6.20 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=11404.611, Time=1.66 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=inf, Time=6.59 sec
#
# Best model:  ARIMA(5,1,2)(0,0,0)[0]
# Total fit time: 88.409 seconds
# ARIMA(order=(5, 1, 2), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# 4. Quá trình testing 
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(n_periods=len(y_test))

# %%
y_pred = pd.DataFrame(y_pred, columns=['pm25'])
y_pred = smoothed(y_pred)
y_pred = y_pred.to_numpy()

# %%
# 4. Quá trình tạo index predict 90 ngày tiếp theo
last_index =  data.index[-1]
last_data = pd.RangeIndex(start=last_index + 1, stop=last_index+91, step=1)

# Tạo mảng 90 ngày 
x_next_90_days = np.array(range(last_index+1, last_index+91)).reshape(-1, 1)

# Dự đoán 90 ngày tiếp theo
y_next_90_days = model.predict(n_periods=len(x_next_90_days))

# # In ra dự đoán giá trong 90 ngày tiếp theo
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 90 days:
# [70.00472796 70.02668204 71.38811207 66.71030784 58.96742744 57.33519433
#  56.86926725 55.37601135 57.0502251  60.87424759 61.86282841 62.24551782
#  63.36902966 62.89991261 61.0626416  60.52602715 60.30300774 59.57642468
#  59.6172758  60.47805903 60.74802513 60.85290353 61.28311736 61.36053287
#  60.96655595 60.8387372  60.8006617  60.56123782 60.47486936 60.65131032
#  60.70872021 60.71543349 60.8422682  60.90790161 60.83045125 60.80585037
#  60.81091032 60.74656297 60.70351261 60.73690846 60.74704584 60.73939068
#  60.77071328 60.79675092 60.78256211 60.77847432 60.78519833 60.77059528
#  60.75565572 60.76162208 60.76329884 60.7583903  60.76486992 60.77312589
#  60.77062761 60.76987898 60.77311996 60.77042136 60.76598593 60.76703562
#  60.76742516 60.76542235 60.76644553 60.76877685 60.76833073 60.76809344
#  60.76927203 60.76894597 60.76774144 60.76793435 60.76809319 60.76742615
#  60.76748789 60.76810196 60.76801709 60.76790785 60.76827315 60.76829585
#  60.76798599 60.76802364 60.7680979  60.76790361 60.76786462 60.7680198
#  60.76800331 60.76795417 60.76805475 60.7680882  60.7680109  60.76801776]

# %%
# 5. Tính RMSE
test_rmse = np.sqrt(np.mean((y_test - y_pred)**2))
print('Testing RMSE:', test_rmse)

# 6. Tính MAPE
test_mape = np.mean(np.abs((y_test - y_pred)/y_test))*100
print('\nTesting MAPE:', test_mape)

# 7. Tính MAE
test_mae = np.mean(np.abs(y_test - y_pred))
print("\nMAE:", test_mae)
# Out:
# Testing RMSE: 20.45626114741551
#
# Testing MAPE: 44.109401271844966
#
# MAE: 16.515685508681845

# %%
test_data.index
# Out:
# RangeIndex(start=1728, stop=1920, step=1)

# %%
# 9.Vẽ hình
plt.figure(figsize=(10, 6))
plt.plot(train_data.index, train_data)
plt.plot(test_data.index, test_data)
plt.plot(test_data.index, y_pred)


last_data = pd.RangeIndex(start=last_index+1, stop=last_index+31, step=1)
plt.plot(last_data,y_next_90_days[0:30])

last_data = pd.RangeIndex(start=last_index+31, stop=last_index+61, step=1)
plt.plot(last_data,y_next_90_days[30:60])

last_data = pd.RangeIndex(start=last_index+61, stop=last_index+91, step=1)
plt.plot(last_data,y_next_90_days[60:90])
plt.legend(['Train','Test','Predict','Predict30days', 'Predict60days', 'Predict90days'])
plt.title('ARIMA 9-1 (Viet Tri PM2.5)')
plt.ylabel('PM2.5')
plt.show()


#DỰ đians 90 ngày
plt.figure(figsize=(10, 6))
last_data = pd.RangeIndex(start=last_index+1, stop=last_index+31, step=1)
plt.plot(last_data,y_next_90_days[0:30])

last_data = pd.RangeIndex(start=last_index+31, stop=last_index+61, step=1)
plt.plot(last_data,y_next_90_days[30:60])

last_data = pd.RangeIndex(start=last_index+61, stop=last_index+91, step=1)
plt.plot(last_data,y_next_90_days[60:90])
plt.legend(['Predict30days', 'Predict60days', 'Predict90days'])
plt.title('ARIMA 9-1 (Viet Tri PM2.5)')
plt.ylabel('PM2.5')
plt.show()
