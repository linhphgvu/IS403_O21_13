# %%
# 1. Các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
# 2.Load Dataset
data = pd.read_csv("viettri_quality.csv")
data
# Out:
#            date  pm25  pm10  o3  no2  so2  co
# 0      3/1/2019    44    17  29    2    9   4
# 1      3/2/2019    65    37  27    4   12   4
# 2      3/3/2019    81    38   2    1    1   2
# 3      3/4/2019    51    24  21    4    8   1
# 4      3/5/2019    43     7  23    1   12   4
# ...         ...   ...   ...  ..  ...  ...  ..
# 1915  5/28/2024    38    24  35    1   15   5
# 1916  5/29/2024    38    17  41    7   15  10
# 1917  5/30/2024    28     8  11    1   15   1
# 1918  5/31/2024    12    12  16    1   16   7
# 1919   6/1/2024    21    28  15    1   17   7
#
# [1920 rows x 7 columns]

# %%
#kích thước dữ liệu
data.shape
data.info()
#Mô tả bộ dữ liệu
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1920 non-null   object
#  1   pm25    1920 non-null   int64
#  2   pm10    1920 non-null   int64
#  3   o3      1920 non-null   int64
#  4   no2     1920 non-null   int64
#  5   so2     1920 non-null   int64
#  6   co      1920 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 105.1+ KB
#               pm25         pm10           o3          no2          so2  \
# count  1920.000000  1920.000000  1920.000000  1920.000000  1920.000000
# mean     42.395313    22.470833    17.391667     7.528125     9.497917
# std      31.665288    16.124166    12.907283     4.971229     6.526731
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      19.000000    10.000000     8.750000     3.000000     4.000000
# 50%      35.000000    20.000000    15.000000     7.000000     9.000000
# 75%      59.000000    32.000000    24.000000    11.000000    14.000000
# max     178.000000    94.000000   114.000000    35.000000    27.000000
#
#                 co
# count  1920.000000
# mean      3.961979
# std       2.516048
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max      22.000000

# %%
#Chọn thuộc tính
data = data[['pm25','pm10']]
data = data.dropna() 
data = data.reset_index(drop=True) 
data
# Out:
#       pm25  pm10
# 0       44    17
# 1       65    37
# 2       81    38
# 3       51    24
# 4       43     7
# ...    ...   ...
# 1915    38    24
# 1916    38    17
# 1917    28     8
# 1918    12    12
# 1919    21    28
#
# [1920 rows x 2 columns]

# %%
data['pm25'].plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# Split the data into training, testing
train_size = int(0.8 * len(data))
test_size = int(0.2 * len(data))

train_data = data[:train_size]
test_data = data[train_size:]

# Kiểm tra kích thước của từng tập
print("Train data size:", len(train_data))
print("Test data size:", len(test_data))
# Out:
# Train data size: 1536
# Test data size: 384

# %%
# 3. Quá trình Training
model = VAR(train_data)
model_fitted = model.fit()

# %%
# 4. Quá trình testing 
# Dự đoán cho cả 'pm25' và 'o3'
y_pred = model_fitted.forecast(train_data.values[-model_fitted.k_ar:], steps=len(test_data))

# %%
# 5. Quá trình tạo index predict 30 ngày tiếp theo
last_index = data.index[-1]
next_30_days_index = pd.RangeIndex(start=last_index + 1, stop=last_index + 31, step=1)

# Dự đoán cho 30 ngày tiếp theo
y_next_30_days = model_fitted.forecast(model_fitted.endog[-model_fitted.k_ar:], steps=30)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [[28.85285134 15.61539379]
#  [32.8836223  17.20252048]
#  [35.55490709 18.40617845]
#  [37.47848449 19.28075085]
#  [38.87154022 19.91448777]
#  [39.8807665  20.37362829]
#  [40.61193775 20.70627043]
#  [41.1416626  20.94726573]
#  [41.52544198 21.12186397]
#  [41.80348559 21.24835832]
#  [42.00492489 21.34000198]
#  [42.15086527 21.40639673]
#  [42.25659735 21.45449894]
#  [42.33319899 21.48934842]
#  [42.38869597 21.51459645]
#  [42.42890288 21.53288835]
#  [42.4580323  21.54614062]
#  [42.47913623 21.55574173]
#  [42.49442577 21.56269762]
#  [42.50550286 21.56773708]
#  [42.51352809 21.57138811]
#  [42.51934227 21.57403324]
#  [42.52355457 21.5759496 ]
#  [42.52660633 21.57733798]
#  [42.5288173  21.57834385]
#  [42.53041912 21.57907259]
#  [42.53157962 21.57960055]
#  [42.53242039 21.57998305]
#  [42.53302951 21.58026017]
#  [42.53347082 21.58046094]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Tính RMSE
rmse = np.sqrt(mean_squared_error(test_data['pm25'], y_pred[:, 0]))
print('Testing RMSE:', rmse)

# Tính MAE
mae = mean_absolute_error(test_data['pm25'], y_pred[:, 0])
print('\nTesting MAE:', mae)

# Tính MAPE
mape = np.mean(np.abs((test_data['pm25'] - y_pred[:, 0]) / test_data['pm25'])) * 100
print('\nTesting MAPE:', mape)
# Out:
# Testing RMSE: 23.92813325137435
#
# Testing MAE: 19.785147518750726
#
# Testing MAPE: 92.80393870146585

# %%
# 9. Vẽ biểu đồ
# Biểu đồ cho 'pm25'
plt.plot(train_data.index, train_data['pm25'])
plt.plot(test_data.index, test_data['pm25'])
plt.plot(test_data.index, y_pred[:, 0])
plt.plot(next_30_days_index, y_next_30_days[:, 0]) 
plt.legend(['Train', 'Test', 'Predictions','Next30Day'],loc='upper left')
plt.title('VAR 8-2 (Viet Tri PM2.5)')
plt.ylabel('PM2.5')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, y_pred[:, 0]) 
plt.legend(['Prediction PM2.5'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(next_30_days_index, y_next_30_days[:, 0]) 
plt.legend(['PM2.5 Next30Day'])
plt.show()

# %%
test_data.index
# Out:
# RangeIndex(start=1536, stop=1920, step=1)
