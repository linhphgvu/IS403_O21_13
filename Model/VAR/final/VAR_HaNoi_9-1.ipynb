# %%
# 1. Các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
# 2.Load Dataset
data = pd.read_csv("hanoi_quality.csv")
data
# Out:
#            date  pm25  pm10  o3  no2  so2  co
# 0      3/1/2019    76     1  15   36    7   7
# 1      3/2/2019   117    64   4   28    3   5
# 2      3/3/2019    10    64   1   22   16   5
# 3      3/4/2019   118    56  13   22   14   6
# 4      3/5/2019     2    34  15   21    6   6
# ...         ...   ...   ...  ..  ...  ...  ..
# 1915  5/28/2024    85    56  14    1    8   6
# 1916  5/29/2024    58    50  13    1    8   6
# 1917  5/30/2024    47    39  10    1    8   8
# 1918  5/31/2024    48    63  10    1    8   8
# 1919   6/1/2024    98    60  11    1    8   6
#
# [1920 rows x 7 columns]

# %%
#kích thước dữ liệu
data.shape
data.info()
#Mô tả bộ dữ liệu
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1920 non-null   object
#  1   pm25    1920 non-null   int64
#  2   pm10    1920 non-null   int64
#  3   o3      1920 non-null   int64
#  4   no2     1920 non-null   int64
#  5   so2     1920 non-null   int64
#  6   co      1920 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 105.1+ KB
#               pm25         pm10           o3          no2          so2  \
# count  1920.000000  1920.000000  1920.000000  1920.000000  1920.000000
# mean     63.091667    39.147917    16.548958    19.444271    11.690104
# std      40.260213    21.942295    16.580522    10.014321     6.428450
# min       2.000000     1.000000     1.000000     1.000000     1.000000
# 25%      32.000000    22.000000     8.000000    13.000000     7.000000
# 50%      54.500000    36.000000    14.000000    19.000000    11.000000
# 75%      88.000000    54.000000    21.000000    27.000000    17.000000
# max     217.000000   121.000000   441.000000    53.000000    43.000000
#
#                 co
# count  1920.000000
# mean      7.580208
# std       2.986652
# min       1.000000
# 25%       5.000000
# 50%       7.000000
# 75%       9.000000
# max      21.000000

# %%
#Chọn thuộc tính
data = data[['pm25','pm10']]
data = data.dropna() 
data = data.reset_index(drop=True) 
data
# Out:
#       pm25  pm10
# 0       76     1
# 1      117    64
# 2       10    64
# 3      118    56
# 4        2    34
# ...    ...   ...
# 1915    85    56
# 1916    58    50
# 1917    47    39
# 1918    48    63
# 1919    98    60
#
# [1920 rows x 2 columns]

# %%
data['pm25'].plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# Split the data into training, testing
train_size = int(0.9 * len(data))
test_size = int(0.1 * len(data))

train_data = data[:train_size]
test_data = data[train_size:]

# Kiểm tra kích thước của từng tập
print("Train data size:", len(train_data))
print("Test data size:", len(test_data))
# Out:
# Train data size: 1728
# Test data size: 192

# %%
# 3. Quá trình Training
model = VAR(train_data)
model_fitted = model.fit()

# %%
# 4. Quá trình testing 
# Dự đoán cho cả 'pm25' và 'o3'
y_pred = model_fitted.forecast(train_data.values[-model_fitted.k_ar:], steps=len(test_data))

# %%
# 5. Quá trình tạo index predict 30 ngày tiếp theo
last_index = data.index[-1]
next_30_days_index = pd.RangeIndex(start=last_index + 1, stop=last_index + 31, step=1)

# Dự đoán cho 30 ngày tiếp theo
y_next_30_days = model_fitted.forecast(model_fitted.endog[-model_fitted.k_ar:], steps=30)

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [[147.19998182  72.78519452]
#  [126.9676062   65.72097811]
#  [112.81207037  59.89418216]
#  [101.90048304  55.23538958]
#  [ 93.29881601  51.53411199]
#  [ 86.48534071  48.5974664 ]
#  [ 81.0828162   46.26814258]
#  [ 76.79814115  44.42065028]
#  [ 73.39986534  42.95533856]
#  [ 70.70458787  41.79315085]
#  [ 68.56687584  40.87138144]
#  [ 66.87138633  40.14029578]
#  [ 65.52663788  39.56044771]
#  [ 64.46007368  39.10055113]
#  [ 63.61414654  38.73579204]
#  [ 62.94321392  38.44648961]
#  [ 62.41107519  38.21703434]
#  [ 61.98901847  38.03504582]
#  [ 61.65427141  37.89070474]
#  [ 61.38877251  37.77622309]
#  [ 61.17819661  37.68542393]
#  [ 61.01118193  37.61340812]
#  [ 60.8787171   37.55629002]
#  [ 60.77365489  37.51098778]
#  [ 60.69032659  37.47505708]
#  [ 60.62423618  37.44655926]
#  [ 60.5718177   37.4239567 ]
#  [ 60.53024289  37.40602987]
#  [ 60.49726853  37.39181151]
#  [ 60.47111549  37.38053446]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Tính RMSE
rmse = np.sqrt(mean_squared_error(test_data['pm25'], y_pred[:, 0]))
print('Testing RMSE:', rmse)

# Tính MAE
mae = mean_absolute_error(test_data['pm25'], y_pred[:, 0])
print('\nTesting MAE:', mae)

# Tính MAPE
mape = np.mean(np.abs((test_data['pm25'] - y_pred[:, 0]) / test_data['pm25'])) * 100
print('\nTesting MAPE:', mape)
# Out:
# Testing RMSE: 46.09580906525529
#
# Testing MAE: 35.32880680320671
#
# Testing MAPE: 52.6072611820843

# %%
# 9. Vẽ biểu đồ
# Biểu đồ cho 'pm25'
plt.plot(train_data.index, train_data['pm25'])
plt.plot(test_data.index, test_data['pm25'])
plt.plot(test_data.index, y_pred[:, 0])
plt.plot(next_30_days_index, y_next_30_days[:, 0]) 
plt.legend(['Train', 'Test', 'Predictions','Next30Day'],loc='upper left')
plt.title('VAR 9-1 (Ha Noi PM2.5)')
plt.ylabel('PM2.5')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, y_pred[:, 0]) 
plt.legend(['Prediction PM2.5'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(next_30_days_index, y_next_30_days[:, 0]) 
plt.legend(['PM2.5 Next30Day'])
plt.show()

# %%
test_data.index
# Out:
# RangeIndex(start=1728, stop=1920, step=1)
