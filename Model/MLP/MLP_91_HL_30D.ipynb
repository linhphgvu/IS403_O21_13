# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/data/halong_quality.csv', index_col='date')

# %%
data
# Out:
#            pm25  pm10  o3  no2  so2  co
# date
# 3/1/2019      6     6  45    3  500 NaN
# 3/2/2019     59    55   1    6  500 NaN
# 3/3/2019     43    28   5    9  500 NaN
# 3/4/2019     27     3   4   16  500 NaN
# 3/5/2019     48    17  16    1  500 NaN
# ...         ...   ...  ..  ...  ...  ..
# 5/28/2024    64    32  48    9  500 NaN
# 5/29/2024    47    20  23    8  500 NaN
# 5/30/2024    40     6  49    9  500 NaN
# 5/31/2024    12    18  14    8  500 NaN
# 6/1/2024     37    23   9    8  500 NaN
#
# [1920 rows x 6 columns]

# %%
data.fillna(method='ffill', inplace=True)
scaler = MinMaxScaler()
data['pm25'] = scaler.fit_transform(data[['pm25']])

# %%
def create_sequences(data, seq_length=30):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 30
X, y = create_sequences(data['pm25'].values, seq_length)
X = X.reshape((X.shape[0], X.shape[1], 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(seq_length, 1)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_8 (Flatten)         (None, 30)                0
#
#  dense_24 (Dense)            (None, 128)               3968
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dense_26 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12289 (48.00 KB)
# Trainable params: 12289 (48.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 1s 5ms/step - loss: 0.0214 - val_loss: 0.0139
# Epoch 2/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0146
# Epoch 3/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0148
# Epoch 4/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0160 - val_loss: 0.0145
# Epoch 5/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0156 - val_loss: 0.0139
# Epoch 6/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0153 - val_loss: 0.0138
# Epoch 7/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.0157
# Epoch 8/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0147 - val_loss: 0.0151
# Epoch 9/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0141 - val_loss: 0.0145
# Epoch 10/100
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0152
# Epoch 11/100
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0132 - val_loss: 0.0167
# Epoch 12/100
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0128 - val_loss: 0.0148
# Epoch 13/100
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0149
# Epoch 14/100
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0114 - val_loss: 0.0151
# Epoch 15/100
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0160
# Epoch 16/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0161
# Epoch 17/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0156
# Epoch 18/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0161
# Epoch 19/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0156
# Epoch 20/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0155
# Epoch 21/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0149
# Epoch 22/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0157
# Epoch 23/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0165
# Epoch 24/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0160
# Epoch 25/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0163
# Epoch 26/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0157
# Epoch 27/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0166
# Epoch 28/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0163
# Epoch 29/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0165
# Epoch 30/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0160
# Epoch 31/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0164
# Epoch 32/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0168
# Epoch 33/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0165
# Epoch 34/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0163
# Epoch 35/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0166
# Epoch 36/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0037 - val_loss: 0.0152
# Epoch 37/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0165
# Epoch 38/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0032 - val_loss: 0.0172
# Epoch 39/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0158
# Epoch 40/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0162
# Epoch 41/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0163
# Epoch 42/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0160
# Epoch 43/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0028 - val_loss: 0.0175
# Epoch 44/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0167
# Epoch 45/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0164
# Epoch 46/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0170
# Epoch 47/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0166
# Epoch 48/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0162
# Epoch 49/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0179
# Epoch 50/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0168
# Epoch 51/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0171
# Epoch 52/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0165
# Epoch 53/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0176
# Epoch 54/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0166
# Epoch 55/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0172
# Epoch 56/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0169
# Epoch 57/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 58/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0177
# Epoch 59/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0169
# Epoch 60/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0174
# Epoch 61/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0172
# Epoch 62/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0170
# Epoch 63/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0177
# Epoch 64/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 65/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0173
# Epoch 66/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0177
# Epoch 67/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0175
# Epoch 68/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0173
# Epoch 69/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0179
# Epoch 70/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0172
# Epoch 71/100
# 54/54 [==============================] - 0s 3ms/step - loss: 8.4024e-04 - val_loss: 0.0179
# Epoch 72/100
# 54/54 [==============================] - 0s 3ms/step - loss: 8.4898e-04 - val_loss: 0.0187
# Epoch 73/100
# 54/54 [==============================] - 0s 3ms/step - loss: 8.2595e-04 - val_loss: 0.0165
# Epoch 74/100
# 54/54 [==============================] - 0s 3ms/step - loss: 7.8483e-04 - val_loss: 0.0173
# Epoch 75/100
# 54/54 [==============================] - 0s 2ms/step - loss: 8.1899e-04 - val_loss: 0.0172
# Epoch 76/100
# 54/54 [==============================] - 0s 3ms/step - loss: 6.9625e-04 - val_loss: 0.0176
# Epoch 77/100
# 54/54 [==============================] - 0s 3ms/step - loss: 6.5313e-04 - val_loss: 0.0172
# Epoch 78/100
# 54/54 [==============================] - 0s 3ms/step - loss: 6.8731e-04 - val_loss: 0.0177
# Epoch 79/100
# 54/54 [==============================] - 0s 3ms/step - loss: 6.9280e-04 - val_loss: 0.0178
# Epoch 80/100
# 54/54 [==============================] - 0s 3ms/step - loss: 7.5584e-04 - val_loss: 0.0173
# Epoch 81/100
# 54/54 [==============================] - 0s 3ms/step - loss: 7.2368e-04 - val_loss: 0.0183
# Epoch 82/100
# 54/54 [==============================] - 0s 3ms/step - loss: 6.3154e-04 - val_loss: 0.0175
# Epoch 83/100
# 54/54 [==============================] - 0s 3ms/step - loss: 6.5542e-04 - val_loss: 0.0181
# Epoch 84/100
# 54/54 [==============================] - 0s 5ms/step - loss: 7.7462e-04 - val_loss: 0.0178
# Epoch 85/100
# 54/54 [==============================] - 0s 4ms/step - loss: 8.6164e-04 - val_loss: 0.0185
# Epoch 86/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0191
# Epoch 87/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0185
# Epoch 88/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0183
# Epoch 89/100
# 54/54 [==============================] - 0s 4ms/step - loss: 7.3503e-04 - val_loss: 0.0177
# Epoch 90/100
# 54/54 [==============================] - 0s 4ms/step - loss: 7.1470e-04 - val_loss: 0.0175
# Epoch 91/100
# 54/54 [==============================] - 0s 4ms/step - loss: 6.3381e-04 - val_loss: 0.0178
# Epoch 92/100
# 54/54 [==============================] - 0s 4ms/step - loss: 8.1324e-04 - val_loss: 0.0185
# Epoch 93/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0182
# Epoch 94/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0181
# Epoch 95/100
# 54/54 [==============================] - 0s 4ms/step - loss: 9.5438e-04 - val_loss: 0.0186
# Epoch 96/100
# 54/54 [==============================] - 0s 4ms/step - loss: 9.0293e-04 - val_loss: 0.0185
# Epoch 97/100
# 54/54 [==============================] - 0s 5ms/step - loss: 7.8366e-04 - val_loss: 0.0178
# Epoch 98/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0183
# Epoch 99/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0188
# Epoch 100/100
# 54/54 [==============================] - 0s 4ms/step - loss: 8.4997e-04 - val_loss: 0.0181

# %%
# Predict the next 30 days PM2.5 values
last_sequence = X_test[-1]
predictions = []
current_sequence = last_sequence

for _ in range(30):
    next_value = model.predict(current_sequence[np.newaxis, :, :])[0, 0]
    predictions.append(next_value)
    current_sequence = np.append(current_sequence[1:], [[next_value]], axis=0)

predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
print("Next 30 days PM2.5 predictions:", predictions.flatten())
# Out:
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# Next 30 days PM2.5 predictions: [44.358364 45.897427 36.35828  38.230408 35.430027 36.268555 22.504871
#  43.545197 35.13994  31.112219 38.496685 47.84831  27.84295  37.001835
#  41.39255  42.979736 33.90815  38.806175 46.402378 51.577568 41.818314
#  52.056576 34.921696 58.327114 57.36133  25.104383 26.558819 34.567333
#  32.457176 43.857807]

# %%
# Plot the predictions in the original scale
plt.figure(figsize=(10, 5))
plt.plot(predictions)
plt.title('Predicted PM2.5 Values for the Next 30 Days')
plt.xlabel('Days')
plt.ylabel('Predicted PM2.5 Value')
plt.show()
