# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/data/halong_quality.csv', index_col='date')

# %%
data
# Out:
#            pm25  pm10  o3  no2  so2  co
# date
# 3/1/2019      6     6  45    3  500 NaN
# 3/2/2019     59    55   1    6  500 NaN
# 3/3/2019     43    28   5    9  500 NaN
# 3/4/2019     27     3   4   16  500 NaN
# 3/5/2019     48    17  16    1  500 NaN
# ...         ...   ...  ..  ...  ...  ..
# 5/28/2024    64    32  48    9  500 NaN
# 5/29/2024    47    20  23    8  500 NaN
# 5/30/2024    40     6  49    9  500 NaN
# 5/31/2024    12    18  14    8  500 NaN
# 6/1/2024     37    23   9    8  500 NaN
#
# [1920 rows x 6 columns]

# %%
data.fillna(method='ffill', inplace=True)
scaler = MinMaxScaler()
data['pm25'] = scaler.fit_transform(data[['pm25']])

# %%
def create_sequences(data, seq_length=30):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 30
X, y = create_sequences(data['pm25'].values, seq_length)
X = X.reshape((X.shape[0], X.shape[1], 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(seq_length, 1)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 30)                0
#
#  dense_27 (Dense)            (None, 128)               3968
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  dense_29 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12289 (48.00 KB)
# Trainable params: 12289 (48.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 1s 6ms/step - loss: 0.0278 - val_loss: 0.0151
# Epoch 2/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0144
# Epoch 3/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0139
# Epoch 4/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0134
# Epoch 5/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0137
# Epoch 6/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0140
# Epoch 7/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0144
# Epoch 8/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0139
# Epoch 9/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0153 - val_loss: 0.0142
# Epoch 10/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.0141
# Epoch 11/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 12/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0151
# Epoch 13/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0151
# Epoch 14/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.0147
# Epoch 15/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0128 - val_loss: 0.0146
# Epoch 16/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0121 - val_loss: 0.0146
# Epoch 17/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.0153
# Epoch 18/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0165
# Epoch 19/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0106 - val_loss: 0.0160
# Epoch 20/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0157
# Epoch 21/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0158
# Epoch 22/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0181
# Epoch 23/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0159
# Epoch 24/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0170
# Epoch 25/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0161
# Epoch 26/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0167
# Epoch 27/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0168
# Epoch 28/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0178
# Epoch 29/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0169
# Epoch 30/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0171
# Epoch 31/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0058 - val_loss: 0.0177
# Epoch 32/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0174
# Epoch 33/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0178
# Epoch 34/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0179
# Epoch 35/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0047 - val_loss: 0.0183
# Epoch 36/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0044 - val_loss: 0.0180
# Epoch 37/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0041 - val_loss: 0.0183
# Epoch 38/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0189
# Epoch 39/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0195
# Epoch 40/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0187
# Epoch 41/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 0.0190
# Epoch 42/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0188
# Epoch 43/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0189
# Epoch 44/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0190
# Epoch 45/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0195
# Epoch 46/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0191
# Epoch 47/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0200
# Epoch 48/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0188
# Epoch 49/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0203
# Epoch 50/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0197
# Epoch 51/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0198
# Epoch 52/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0198
# Epoch 53/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0193
# Epoch 54/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0195
# Epoch 55/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0201
# Epoch 56/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0199
# Epoch 57/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0197
# Epoch 58/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0196
# Epoch 59/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0200
# Epoch 60/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0201
# Epoch 61/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0198
# Epoch 62/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0199
# Epoch 63/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0197
# Epoch 64/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0204
# Epoch 65/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0196
# Epoch 66/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0200
# Epoch 67/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0199
# Epoch 68/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0202
# Epoch 69/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.3162e-04 - val_loss: 0.0200
# Epoch 70/100
# 48/48 [==============================] - 0s 3ms/step - loss: 8.4972e-04 - val_loss: 0.0205
# Epoch 71/100
# 48/48 [==============================] - 0s 3ms/step - loss: 8.5223e-04 - val_loss: 0.0199
# Epoch 72/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.0766e-04 - val_loss: 0.0207
# Epoch 73/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0205
# Epoch 74/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.7404e-04 - val_loss: 0.0203
# Epoch 75/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0206
# Epoch 76/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.2305e-04 - val_loss: 0.0207
# Epoch 77/100
# 48/48 [==============================] - 0s 3ms/step - loss: 8.7278e-04 - val_loss: 0.0207
# Epoch 78/100
# 48/48 [==============================] - 0s 3ms/step - loss: 7.3663e-04 - val_loss: 0.0205
# Epoch 79/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.3051e-04 - val_loss: 0.0205
# Epoch 80/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.3141e-04 - val_loss: 0.0207
# Epoch 81/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.7849e-04 - val_loss: 0.0210
# Epoch 82/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.5569e-04 - val_loss: 0.0205
# Epoch 83/100
# 48/48 [==============================] - 0s 3ms/step - loss: 7.8533e-04 - val_loss: 0.0209
# Epoch 84/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.6185e-04 - val_loss: 0.0212
# Epoch 85/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.5824e-04 - val_loss: 0.0210
# Epoch 86/100
# 48/48 [==============================] - 0s 3ms/step - loss: 7.8843e-04 - val_loss: 0.0206
# Epoch 87/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.6359e-04 - val_loss: 0.0212
# Epoch 88/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.6671e-04 - val_loss: 0.0209
# Epoch 89/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.3955e-04 - val_loss: 0.0205
# Epoch 90/100
# 48/48 [==============================] - 0s 3ms/step - loss: 7.6926e-04 - val_loss: 0.0211
# Epoch 91/100
# 48/48 [==============================] - 0s 3ms/step - loss: 7.6665e-04 - val_loss: 0.0213
# Epoch 92/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0215
# Epoch 93/100
# 48/48 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0214
# Epoch 94/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0208
# Epoch 95/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.9410e-04 - val_loss: 0.0209
# Epoch 96/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.8567e-04 - val_loss: 0.0217
# Epoch 97/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.9039e-04 - val_loss: 0.0204
# Epoch 98/100
# 48/48 [==============================] - 0s 3ms/step - loss: 8.0316e-04 - val_loss: 0.0212
# Epoch 99/100
# 48/48 [==============================] - 0s 3ms/step - loss: 9.3737e-04 - val_loss: 0.0220
# Epoch 100/100
# 48/48 [==============================] - 0s 3ms/step - loss: 6.6573e-04 - val_loss: 0.0208

# %%
# Predict the next 30 days PM2.5 values
last_sequence = X_test[-1]
predictions = []
current_sequence = last_sequence

for _ in range(30):
    next_value = model.predict(current_sequence[np.newaxis, :, :])[0, 0]
    predictions.append(next_value)
    current_sequence = np.append(current_sequence[1:], [[next_value]], axis=0)

predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
print("Next 30 days PM2.5 predictions:", predictions.flatten())
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# Next 30 days PM2.5 predictions: [35.851467  28.403452  24.735638  37.984406  36.99338   32.57292
#  35.673073  51.15842   23.016634  26.577393  43.73029   29.319248
#  45.982994  27.792158  35.10856   12.611072   9.866853  41.615944
#   9.56646   46.349106  15.27312    9.4549265 13.683816  33.93893
#  49.651546  26.664488  17.337223  25.437132  39.475487  24.899353 ]

# %%
# Plot the predictions in the original scale
plt.figure(figsize=(10, 5))
plt.plot(predictions)
plt.title('Predicted PM2.5 Values for the Next 30 Days')
plt.xlabel('Days')
plt.ylabel('Predicted PM2.5 Value')
plt.show()
