# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/data/halong_quality.csv', index_col='date')

# %%
data
# Out:
#            pm25  pm10  o3  no2  so2  co
# date
# 3/1/2019      6     6  45    3  500 NaN
# 3/2/2019     59    55   1    6  500 NaN
# 3/3/2019     43    28   5    9  500 NaN
# 3/4/2019     27     3   4   16  500 NaN
# 3/5/2019     48    17  16    1  500 NaN
# ...         ...   ...  ..  ...  ...  ..
# 5/28/2024    64    32  48    9  500 NaN
# 5/29/2024    47    20  23    8  500 NaN
# 5/30/2024    40     6  49    9  500 NaN
# 5/31/2024    12    18  14    8  500 NaN
# 6/1/2024     37    23   9    8  500 NaN
#
# [1920 rows x 6 columns]

# %%
data.fillna(method='ffill', inplace=True)
scaler = MinMaxScaler()
data['pm25'] = scaler.fit_transform(data[['pm25']])

# %%
def create_sequences(data, seq_length=30):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 30
X, y = create_sequences(data['pm25'].values, seq_length)
X = X.reshape((X.shape[0], X.shape[1], 1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(seq_length, 1)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_11 (Flatten)        (None, 30)                0
#
#  dense_33 (Dense)            (None, 128)               3968
#
#  dense_34 (Dense)            (None, 64)                8256
#
#  dense_35 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12289 (48.00 KB)
# Trainable params: 12289 (48.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 7ms/step - loss: 0.0323 - val_loss: 0.0168
# Epoch 2/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0157
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0161
# Epoch 4/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0160
# Epoch 5/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 6/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 7/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0159 - val_loss: 0.0165
# Epoch 8/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0154 - val_loss: 0.0164
# Epoch 9/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0149 - val_loss: 0.0163
# Epoch 10/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0145 - val_loss: 0.0166
# Epoch 11/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0137 - val_loss: 0.0163
# Epoch 12/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0136 - val_loss: 0.0168
# Epoch 13/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0131 - val_loss: 0.0170
# Epoch 14/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.0177
# Epoch 15/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0174
# Epoch 16/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0172
# Epoch 17/100
# 42/42 [==============================] - 1s 16ms/step - loss: 0.0110 - val_loss: 0.0197
# Epoch 18/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0183
# Epoch 19/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0180
# Epoch 20/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0181
# Epoch 21/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0095 - val_loss: 0.0187
# Epoch 22/100
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0089 - val_loss: 0.0199
# Epoch 23/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0189
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0193
# Epoch 25/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 0.0192
# Epoch 26/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0194
# Epoch 27/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0230
# Epoch 28/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0206
# Epoch 29/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0199
# Epoch 30/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0207
# Epoch 31/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0220
# Epoch 32/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0208
# Epoch 33/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0211
# Epoch 34/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0214
# Epoch 35/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0209
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.0211
# Epoch 37/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.0221
# Epoch 38/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0222
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0036 - val_loss: 0.0230
# Epoch 40/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0035 - val_loss: 0.0231
# Epoch 41/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0222
# Epoch 42/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0239
# Epoch 43/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0246
# Epoch 44/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0231
# Epoch 45/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 0.0230
# Epoch 46/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0026 - val_loss: 0.0230
# Epoch 47/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0027 - val_loss: 0.0231
# Epoch 48/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0232
# Epoch 49/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.0236
# Epoch 50/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0233
# Epoch 51/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0245
# Epoch 52/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0233
# Epoch 53/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0236
# Epoch 54/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0234
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0245
# Epoch 56/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0242
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0241
# Epoch 58/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0241
# Epoch 59/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0242
# Epoch 60/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0244
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0249
# Epoch 62/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0251
# Epoch 63/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0245
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0238
# Epoch 65/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0246
# Epoch 66/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0245
# Epoch 67/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0247
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0248
# Epoch 69/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0243
# Epoch 70/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0261
# Epoch 71/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0251
# Epoch 72/100
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0249
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.7326e-04 - val_loss: 0.0247
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 9.4302e-04 - val_loss: 0.0261
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.4622e-04 - val_loss: 0.0248
# Epoch 76/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.2973e-04 - val_loss: 0.0253
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 7.3087e-04 - val_loss: 0.0254
# Epoch 78/100
# 42/42 [==============================] - 0s 3ms/step - loss: 6.6417e-04 - val_loss: 0.0252
# Epoch 79/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.5485e-04 - val_loss: 0.0258
# Epoch 80/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.8270e-04 - val_loss: 0.0252
# Epoch 81/100
# 42/42 [==============================] - 0s 4ms/step - loss: 7.9714e-04 - val_loss: 0.0250
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 7.2286e-04 - val_loss: 0.0264
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 8.3043e-04 - val_loss: 0.0255
# Epoch 84/100
# 42/42 [==============================] - 0s 3ms/step - loss: 7.0873e-04 - val_loss: 0.0268
# Epoch 85/100
# 42/42 [==============================] - 0s 4ms/step - loss: 8.6651e-04 - val_loss: 0.0257
# Epoch 86/100
# 42/42 [==============================] - 0s 6ms/step - loss: 6.9784e-04 - val_loss: 0.0261
# Epoch 87/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.7032e-04 - val_loss: 0.0260
# Epoch 88/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.3214e-04 - val_loss: 0.0252
# Epoch 89/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.7638e-04 - val_loss: 0.0251
# Epoch 90/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.6016e-04 - val_loss: 0.0254
# Epoch 91/100
# 42/42 [==============================] - 0s 5ms/step - loss: 6.5243e-04 - val_loss: 0.0257
# Epoch 92/100
# 42/42 [==============================] - 0s 5ms/step - loss: 7.6776e-04 - val_loss: 0.0264
# Epoch 93/100
# 42/42 [==============================] - 0s 4ms/step - loss: 6.1149e-04 - val_loss: 0.0256
# Epoch 94/100
# 42/42 [==============================] - 0s 5ms/step - loss: 5.6864e-04 - val_loss: 0.0260
# Epoch 95/100
# 42/42 [==============================] - 0s 4ms/step - loss: 5.5170e-04 - val_loss: 0.0250
# Epoch 96/100
# 42/42 [==============================] - 0s 5ms/step - loss: 5.6036e-04 - val_loss: 0.0263
# Epoch 97/100
# 42/42 [==============================] - 0s 6ms/step - loss: 6.3123e-04 - val_loss: 0.0263
# Epoch 98/100
# 42/42 [==============================] - 0s 6ms/step - loss: 8.7692e-04 - val_loss: 0.0262
# Epoch 99/100
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0247
# Epoch 100/100
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0257

# %%
# Predict the next 30 days PM2.5 values
last_sequence = X_test[-1]
predictions = []
current_sequence = last_sequence

for _ in range(30):
    next_value = model.predict(current_sequence[np.newaxis, :, :])[0, 0]
    predictions.append(next_value)
    current_sequence = np.append(current_sequence[1:], [[next_value]], axis=0)

predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
print("Next 30 days PM2.5 predictions:", predictions.flatten())
# Out:
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# Next 30 days PM2.5 predictions: [24.400427 52.833847 20.392523 23.858004 32.953075 41.20801  20.440702
#  27.072268 22.61229  39.982113 41.52678  38.31022  38.115997 12.423367
#  14.876923 44.78852  13.099854 23.508833 27.031322 52.855236 30.03158
#  31.498533 23.31601  41.876553 40.18127  37.629772 42.970512 28.978727
#  19.392721 38.262524]

# %%
# Plot the predictions in the original scale
plt.figure(figsize=(10, 5))
plt.plot(predictions)
plt.title('Predicted PM2.5 Values for the Next 30 Days')
plt.xlabel('Days')
plt.ylabel('Predicted PM2.5 Value')
plt.show()
