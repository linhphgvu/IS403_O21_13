# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/My Drive/data/hanoi_quality.csv', index_col='date')

# %%
data.head()
# Out:
#               pm25  pm10  o3  no2  so2  co
# date
# 3/1/2019  0.344186     1  15   36    7   7
# 3/2/2019  0.534884    64   4   28    3   5
# 3/3/2019  0.037209    64   1   22   16   5
# 3/4/2019  0.539535    56  13   22   14   6
# 3/5/2019  0.000000    34  15   21    6   6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['pm25'].plot(kind='hist', bins=20, title='pm25')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['pm10'].plot(kind='hist', bins=20, title='pm10')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['o3'].plot(kind='hist', bins=20, title='o3')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['no2'].plot(kind='hist', bins=20, title='no2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='pm25', y='pm10', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='pm10', y='o3', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='o3', y='no2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='no2', y='so2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['pm25'].plot(kind='line', figsize=(8, 4), title='pm25')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['pm10'].plot(kind='line', figsize=(8, 4), title='pm10')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['o3'].plot(kind='line', figsize=(8, 4), title='o3')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['no2'].plot(kind='line', figsize=(8, 4), title='no2')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data['pm25'] = scaler.fit_transform(data[['pm25']])

# %%
def create_sequences(data, seq_length):
    xs = []
    ys = []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

SEQ_LENGTH = 30
X, y = create_sequences(data['pm25'].values, SEQ_LENGTH)

# %%
split = int(len(X) * 0.7)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
model = Sequential()
model.add(GRU(50, return_sequences=False, input_shape=(SEQ_LENGTH, 1)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 34/34 [==============================] - 4s 45ms/step - loss: 0.0373 - val_loss: 0.0134
# Epoch 2/100
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0202 - val_loss: 0.0126
# Epoch 3/100
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0185 - val_loss: 0.0118
# Epoch 4/100
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0175 - val_loss: 0.0110
# Epoch 5/100
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0168 - val_loss: 0.0105
# Epoch 6/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0167 - val_loss: 0.0105
# Epoch 7/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0162 - val_loss: 0.0100
# Epoch 8/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0158 - val_loss: 0.0098
# Epoch 9/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0160 - val_loss: 0.0096
# Epoch 10/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0154 - val_loss: 0.0095
# Epoch 11/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0151 - val_loss: 0.0095
# Epoch 12/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0151 - val_loss: 0.0094
# Epoch 13/100
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0154 - val_loss: 0.0095
# Epoch 14/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0149 - val_loss: 0.0094
# Epoch 15/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0155 - val_loss: 0.0094
# Epoch 16/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0152 - val_loss: 0.0094
# Epoch 17/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0149 - val_loss: 0.0094
# Epoch 18/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0149 - val_loss: 0.0095
# Epoch 19/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0148 - val_loss: 0.0095
# Epoch 20/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0149 - val_loss: 0.0093
# Epoch 21/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0147 - val_loss: 0.0098
# Epoch 22/100
# 34/34 [==============================] - 1s 20ms/step - loss: 0.0162 - val_loss: 0.0093
# Epoch 23/100
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0148 - val_loss: 0.0095
# Epoch 24/100
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0147 - val_loss: 0.0094
# Epoch 25/100
# 34/34 [==============================] - 1s 25ms/step - loss: 0.0149 - val_loss: 0.0098
# Epoch 26/100
# 34/34 [==============================] - 1s 28ms/step - loss: 0.0150 - val_loss: 0.0093
# Epoch 27/100
# 34/34 [==============================] - 1s 21ms/step - loss: 0.0147 - val_loss: 0.0094
# Epoch 28/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0147 - val_loss: 0.0093
# Epoch 29/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0148 - val_loss: 0.0098
# Epoch 30/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0146 - val_loss: 0.0092
# Epoch 31/100
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0150 - val_loss: 0.0093
# Epoch 32/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0148 - val_loss: 0.0093
# Epoch 33/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0146 - val_loss: 0.0094
# Epoch 34/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0148 - val_loss: 0.0094
# Epoch 35/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0151 - val_loss: 0.0095
# Epoch 36/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0147 - val_loss: 0.0093
# Epoch 37/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0147 - val_loss: 0.0094
# Epoch 38/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0147 - val_loss: 0.0092
# Epoch 39/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0149 - val_loss: 0.0094
# Epoch 40/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0147 - val_loss: 0.0097

# %%
y_pred = model.predict(X_test)
# Out:
# 18/18 [==============================] - 1s 5ms/step

# %%
y_pred_inverse = scaler.inverse_transform(y_pred)
y_test_inverse = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
mse = np.mean((y_pred_inverse - y_test_inverse) ** 2)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.019689815468915243

# %%
last_sequence = data['pm25'].values[-SEQ_LENGTH:]
next_30_days = []

for _ in range(30):
    last_sequence_reshaped = last_sequence.reshape(1, SEQ_LENGTH)
    print(f'Predicting with input shape: {last_sequence_reshaped.shape}')
    pred = model.predict(last_sequence_reshaped)
    next_30_days.append(pred[0, 0])
    last_sequence = np.append(last_sequence[1:], pred)
# Out:
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 28ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 26ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 26ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 29ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 24ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 23ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 24ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 24ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 23ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 23ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 24ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 20ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 20ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 27ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 24ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 22ms/step
# Predicting with input shape: (1, 30)
# 1/1 [==============================] - 0s 21ms/step

# %%
import matplotlib.pyplot as plt
# Convert the predictions back to the original scale
scaler.fit(data['pm25'].values.reshape(-1, 1))
next_30_days_original_scale = scaler.inverse_transform(np.array(next_30_days).reshape(-1, 1))

# Plot the predictions in the original scale
plt.figure(figsize=(10, 5))
plt.plot(next_30_days_original_scale)
plt.title('Predicted PM2.5 Values for the Next 30 Days (Original Scale)')
plt.xlabel('Days')
plt.ylabel('Predicted PM2.5 Value')
plt.show()
